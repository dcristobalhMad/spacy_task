# %% [markdown]
# **Universidad Internacional de La Rioja (UNIR) - Máster Universitario en Inteligencia Artificial - Procesamiento del Lenguaje Natural**

# %% [markdown]
# ***
# Datos del alumno (Nombre y Apellidos): Diego Cristóbal Herreros
#
# Fecha: 27 Abril 2024
# ***

# %% [markdown]
# <span style="font-size: 20pt; font-weight: bold; color: #0098cd;">Trabajo: Named-Entity Recognition</span>
#
# **Objetivos**
#
# Con esta actividad se tratará de que el alumno se familiarice con el manejo de la librería spacy, así como con los conceptos básicos de manejo de las técnicas NER
#
# **Descripción**
#
# En esta actividad debes procesar de forma automática un texto en lenguaje natural para detectar características básicas en el mismo, y para identificar y etiquetar las ocurrencias de conceptos como localización, moneda, empresas, etc.
#
# En la primera parte del ejercicio se proporciona un código fuente a través del cual se lee un archivo de texto y se realiza un preprocesado del mismo. En esta parte el alumno tan sólo debe ejecutar y entender el código proporcionado.
#
# En la segunda parte del ejercicio se plantean una serie de preguntas que deben ser respondidas por el alumno. Cada pregunta deberá responderse con un fragmento de código fuente que esté acompañado de la explicación correspondiente. Para elaborar el código solicitado, el alumno deberá visitar la documentación de la librería spacy, cuyos enlaces se proporcionarán donde corresponda.

# %% [markdown]
# # Parte 1: carga y preprocesamiento del texto a analizar

# %% [markdown]
# Observa las diferentes librerías que se están importando.

# %%
import pathlib
import spacy
from spacy import displacy
import en_core_web_sm

# %% [markdown]
# El siguiente código simplemente carga y preprocesa el texto. Para ello, lo primero que hace es cargar un modelo de lenguaje previamente entrenado. En este caso, se utiliza <i>en_core_web_sm</i>:
#
# https://spacy.io/models/en#en_core_web_sm
#
# Al cargar el modelo de lenguaje se genera un <i>Pipeline</i>, que nos permite realizar las diferentes tareas. En este caso, vamos a utilizar el pipeline para hacer un preprocesamiento básico, que consiste en tokenizar el texto.
#
# Al final del código proporcionado <i>doc</i> representa una versión tokenizada del texto leído.

# %%
nlp = en_core_web_sm.load()
file_name = "barack-obama-speech.txt"
doc = nlp(pathlib.Path(file_name).read_text(encoding="utf-8"))

# %% [markdown]
# ### Playground
#
# La variable <i>doc</i> es un objeto de la clase <i>Doc</i> (https://spacy.io/api/doc)
#
# Visita la documentación de dicha clase y experimenta probando las diferentes funciones y atributos

# %%
# Ver tokens
for token in doc:
    print(token.text, token.pos_, token.lemma_)
# Out:
# “ PUNCT "
# Hello PROPN Hello
# , PUNCT ,
# Chicago PROPN Chicago
# . PUNCT .
#
#  SPACE
#
# If SCONJ if
# there PRON there
# is VERB be
# anyone PRON anyone
# out ADV out
# there ADV there
# who PRON who
# still ADV still
# doubts VERB doubt
# that SCONJ that
# America PROPN America
# is AUX be
# a DET a
# place NOUN place
# where SCONJ where
# all DET all
# things NOUN thing
# are AUX be
# possible ADJ possible
# , PUNCT ,
# who PRON who
# still ADV still
# wonders VERB wonder
# if SCONJ if
# the DET the
# dream NOUN dream
# of ADP of
# our PRON our
# founders NOUN founder
# is AUX be
# alive ADJ alive
# in ADP in
# our PRON our
# time NOUN time
# , PUNCT ,
# who PRON who
# still ADV still
# questions VERB question
# the DET the
# power NOUN power
# of ADP of
# our PRON our
# democracy NOUN democracy
# , PUNCT ,
# tonight NOUN tonight
# is AUX be
# your PRON your
# answer NOUN answer
# . PUNCT .
#
#  SPACE
#
# It PRON it
# ’s VERB ’
# the DET the
# answer NOUN answer
# told VERB tell
# by ADP by
# lines NOUN line
# that PRON that
# stretched VERB stretch
# around ADP around
# schools NOUN school
# and CCONJ and
# churches NOUN church
# in ADP in
# numbers NOUN number
# this DET this
# nation NOUN nation
# has AUX have
# never ADV never
# seen VERB see
# , PUNCT ,
# by ADP by
# people NOUN people
# who PRON who
# waited VERB wait
# three NUM three
# hours NOUN hour
# and CCONJ and
# four NUM four
# hours NOUN hour
# , PUNCT ,
# many ADJ many
# for ADP for
# the DET the
# first ADJ first
# time NOUN time
# in ADP in
# their PRON their
# lives NOUN life
# , PUNCT ,
# because SCONJ because
# they PRON they
# believed VERB believe
# that SCONJ that
# this DET this
# time NOUN time
# must AUX must
# be AUX be
# different ADJ different
# , PUNCT ,
# that SCONJ that
# their PRON their
# voices NOUN voice
# could AUX could
# be AUX be
# that DET that
# difference NOUN difference
# . PUNCT .
#
#  SPACE
#
# It PRON it
# ’s VERB ’
# the DET the
# answer NOUN answer
# spoken VERB speak
# by ADP by
# young ADJ young
# and CCONJ and
# old ADJ old
# , PUNCT ,
# rich ADJ rich
# and CCONJ and
# poor ADJ poor
# , PUNCT ,
# Democrat PROPN Democrat
# and CCONJ and
# Republican PROPN Republican
# , PUNCT ,
# black ADJ black
# , PUNCT ,
# white ADJ white
# , PUNCT ,
# Hispanic ADJ hispanic
# , PUNCT ,
# Asian ADJ asian
# , PUNCT ,
# Native PROPN Native
# American PROPN American
# , PUNCT ,
# gay ADJ gay
# , PUNCT ,
# straight ADJ straight
# , PUNCT ,
# disabled ADJ disabled
# and CCONJ and
# not PART not
# disabled ADJ disabled
# . PUNCT .
# Americans NOUN american
# who PRON who
# sent VERB send
# a DET a
# message NOUN message
# to ADP to
# the DET the
# world NOUN world
# that SCONJ that
# we PRON we
# have AUX have
# never ADV never
# been AUX be
# just ADV just
# a DET a
# collection NOUN collection
# of ADP of
# individuals NOUN individual
# or CCONJ or
# a DET a
# collection NOUN collection
# of ADP of
# red ADJ red
# states NOUN state
# and CCONJ and
# blue ADJ blue
# states NOUN state
# . PUNCT .
#
#  SPACE
#
# We PRON we
# are AUX be
# , PUNCT ,
# and CCONJ and
# always ADV always
# will AUX will
# be AUX be
# , PUNCT ,
# the DET the
# United PROPN United
# States PROPN States
# of ADP of
# America PROPN America
# . PUNCT .
#
#  SPACE
#
# It PRON it
# ’s VERB ’
# the DET the
# answer NOUN answer
# that PRON that
# led VERB lead
# those PRON those
# who PRON who
# ’ve AUX ’ve
# been AUX been
# told VERB tell
# for ADP for
# so ADV so
# long ADV long
# by ADP by
# so ADV so
# many ADJ many
# to PART to
# be AUX be
# cynical ADJ cynical
# and CCONJ and
# fearful ADJ fearful
# and CCONJ and
# doubtful ADJ doubtful
# about ADP about
# what PRON what
# we PRON we
# can AUX can
# achieve VERB achieve
# to PART to
# put VERB put
# their PRON their
# hands NOUN hand
# on ADP on
# the DET the
# arc NOUN arc
# of ADP of
# history NOUN history
# and CCONJ and
# bend VERB bend
# it PRON it
# once ADV once
# more ADV more
# toward ADP toward
# the DET the
# hope NOUN hope
# of ADP of
# a DET a
# better ADJ well
# day NOUN day
# . PUNCT .
#
#  SPACE
#
# It PRON it
# ’s AUX ’s
# been AUX be
# a DET a
# long ADJ long
# time NOUN time
# coming VERB come
# , PUNCT ,
# but CCONJ but
# tonight NOUN tonight
# , PUNCT ,
# because SCONJ because
# of ADP of
# what PRON what
# we PRON we
# did AUX do
# on ADP on
# this DET this
# date NOUN date
# in ADP in
# this DET this
# election NOUN election
# at ADP at
# this DET this
# defining VERB define
# moment NOUN moment
# change NOUN change
# has AUX have
# come VERB come
# to ADP to
# America PROPN America
# . PUNCT .
#
#  SPACE
#
# [ PUNCT [
# read VERB read
# more ADJ more
# ] PUNCT ]
#
#
#  SPACE
#
#
# We PRON we
# did AUX do
# n’t PART not
# start VERB start
# with ADP with
# much ADJ much
# money NOUN money
# or CCONJ or
# many ADJ many
# endorsements NOUN endorsement
# . PUNCT .
# Our PRON our
# campaign NOUN campaign
# was AUX be
# not PART not
# hatched VERB hatch
# in ADP in
# the DET the
# halls NOUN hall
# of ADP of
# Washington PROPN Washington
# . PUNCT .
# It PRON it
# began VERB begin
# in ADP in
# the DET the
# backyards NOUN backyard
# of ADP of
# Des PROPN Des
# Moines PROPN Moines
# and CCONJ and
# the DET the
# living VERB live
# rooms NOUN room
# of ADP of
# Concord PROPN Concord
# and CCONJ and
# the DET the
# front ADJ front
# porches NOUN porch
# of ADP of
# Charleston PROPN Charleston
# . PUNCT .
# It PRON it
# was AUX be
# built VERB build
# by ADP by
# working VERB work
# men NOUN man
# and CCONJ and
# women NOUN woman
# who PRON who
# dug VERB dig
# into ADP into
# what PRON what
# little ADJ little
# savings NOUN saving
# they PRON they
# had VERB have
# to PART to
# give VERB give
# $ SYM $
# 5 NUM 5
# and CCONJ and
# $ SYM $
# 10 NUM 10
# and CCONJ and
# $ SYM $
# 20 NUM 20
# to ADP to
# the DET the
# cause NOUN cause
# . PUNCT .
#
#  SPACE
#
# It PRON it
# grew VERB grow
# strength NOUN strength
# from ADP from
# the DET the
# young ADJ young
# people NOUN people
# who PRON who
# rejected VERB reject
# the DET the
# myth NOUN myth
# of ADP of
# their PRON their
# generation NOUN generation
# ’s PART ’s
# apathy ADJ apathy
# who PRON who
# left VERB leave
# their PRON their
# homes NOUN home
# and CCONJ and
# their PRON their
# families NOUN family
# for ADP for
# jobs NOUN job
# that PRON that
# offered VERB offer
# little ADJ little
# pay NOUN pay
# and CCONJ and
# less ADJ less
# sleep NOUN sleep
# . PUNCT .
#
#  SPACE
#
# It PRON it
# drew VERB draw
# strength NOUN strength
# from ADP from
# the DET the
# not PART not
# - PUNCT -
# so ADV so
# - PUNCT -
# young ADJ young
# people NOUN people
# who PRON who
# braved VERB brave
# the DET the
# bitter ADJ bitter
# cold NOUN cold
# and CCONJ and
# scorching VERB scorch
# heat NOUN heat
# to PART to
# knock VERB knock
# on ADP on
# doors NOUN door
# of ADP of
# perfect ADJ perfect
# strangers NOUN stranger
# , PUNCT ,
# and CCONJ and
# from ADP from
# the DET the
# millions NOUN million
# of ADP of
# Americans PROPN Americans
# who PRON who
# volunteered VERB volunteer
# and CCONJ and
# organized VERB organize
# and CCONJ and
# proved VERB prove
# that SCONJ that
# more ADJ more
# than ADP than
# two NUM two
# centuries NOUN century
# later ADV later
# a DET a
# government NOUN government
# of ADP of
# the DET the
# people NOUN people
# , PUNCT ,
# by ADP by
# the DET the
# people NOUN people
# , PUNCT ,
# and CCONJ and
# for ADP for
# the DET the
# people NOUN people
# has AUX have
# not PART not
# perished VERB perish
# from ADP from
# the DET the
# Earth PROPN Earth
# . PUNCT .
#
#  SPACE
#
# This PRON this
# is AUX be
# your PRON your
# victory NOUN victory
# . PUNCT .
#
#  SPACE
#
# And CCONJ and
# I PRON I
# know VERB know
# you PRON you
# did AUX do
# n’t PART not
# do VERB do
# this PRON this
# just ADV just
# to PART to
# win VERB win
# an DET an
# election NOUN election
# . PUNCT .
# And CCONJ and
# I PRON I
# know VERB know
# you PRON you
# did AUX do
# n’t PART not
# do VERB do
# it PRON it
# for ADP for
# me PRON I
# . PUNCT .
#
#  SPACE
#
# You PRON you
# did VERB do
# it PRON it
# because SCONJ because
# you PRON you
# understand VERB understand
# the DET the
# enormity NOUN enormity
# of ADP of
# the DET the
# task NOUN task
# that PRON that
# lies VERB lie
# ahead ADV ahead
# . PUNCT .
# For ADP for
# even ADV even
# as SCONJ as
# we PRON we
# celebrate VERB celebrate
# tonight NOUN tonight
# , PUNCT ,
# we PRON we
# know VERB know
# the DET the
# challenges NOUN challenge
# that PRON that
# tomorrow NOUN tomorrow
# will AUX will
# bring VERB bring
# are AUX be
# the DET the
# greatest ADJ great
# of ADP of
# our PRON our
# lifetime NOUN lifetime
# — PUNCT —
# two NUM two
# wars NOUN war
# , PUNCT ,
# a DET a
# planet NOUN planet
# in ADP in
# peril NOUN peril
# , PUNCT ,
# the DET the
# worst ADJ bad
# financial ADJ financial
# crisis NOUN crisis
# in ADP in
# a DET a
# century NOUN century
# . PUNCT .
#
#  SPACE
#
# Even ADV even
# as SCONJ as
# we PRON we
# stand VERB stand
# here ADV here
# tonight NOUN tonight
# , PUNCT ,
# we PRON we
# know VERB know
# there PRON there
# are VERB be
# brave ADJ brave
# Americans PROPN Americans
# waking VERB wake
# up ADP up
# in ADP in
# the DET the
# deserts NOUN desert
# of ADP of
# Iraq PROPN Iraq
# and CCONJ and
# the DET the
# mountains NOUN mountain
# of ADP of
# Afghanistan PROPN Afghanistan
# to PART to
# risk VERB risk
# their PRON their
# lives NOUN life
# for ADP for
# us PRON we
# . PUNCT .
#
#  SPACE
#
# There PRON there
# are VERB be
# mothers NOUN mother
# and CCONJ and
# fathers NOUN father
# who PRON who
# will AUX will
# lie VERB lie
# awake ADJ awake
# after SCONJ after
# the DET the
# children NOUN child
# fall VERB fall
# asleep ADJ asleep
# and CCONJ and
# wonder VERB wonder
# how SCONJ how
# they PRON they
# ’ll AUX ’ll
# make VERB make
# the DET the
# mortgage NOUN mortgage
# or CCONJ or
# pay VERB pay
# their PRON their
# doctors NOUN doctor
# ’ PART ’
# bills NOUN bill
# or CCONJ or
# save VERB save
# enough ADJ enough
# for ADP for
# their PRON their
# child NOUN child
# ’s PART ’s
# college NOUN college
# education NOUN education
# . PUNCT .
#
#  SPACE
#
# There PRON there
# ’s VERB ’
# new ADJ new
# energy NOUN energy
# to ADP to
# harness NOUN harness
# , PUNCT ,
# new ADJ new
# jobs NOUN job
# to PART to
# be AUX be
# created VERB create
# , PUNCT ,
# new ADJ new
# schools NOUN school
# to PART to
# build VERB build
# , PUNCT ,
# and CCONJ and
# threats NOUN threat
# to PART to
# meet VERB meet
# , PUNCT ,
# alliances NOUN alliance
# to PART to
# repair VERB repair
# . PUNCT .
#
#  SPACE
#
# The DET the
# road NOUN road
# ahead ADV ahead
# will AUX will
# be AUX be
# long ADJ long
# . PUNCT .
# Our PRON our
# climb NOUN climb
# will AUX will
# be AUX be
# steep ADJ steep
# . PUNCT .
# We PRON we
# may AUX may
# not PART not
# get VERB get
# there ADV there
# in ADP in
# one NUM one
# year NOUN year
# or CCONJ or
# even ADV even
# in ADP in
# one NUM one
# term NOUN term
# . PUNCT .
# But CCONJ but
# , PUNCT ,
# America PROPN America
# , PUNCT ,
# I PRON I
# have AUX have
# never ADV never
# been AUX be
# more ADV more
# hopeful ADJ hopeful
# than SCONJ than
# I PRON I
# am AUX be
# tonight NOUN tonight
# that SCONJ that
# we PRON we
# will AUX will
# get VERB get
# there ADV there
# . PUNCT .
#
#  SPACE
#
# I PRON I
# promise VERB promise
# you PRON you
# , PUNCT ,
# we PRON we
# as ADP as
# a DET a
# people NOUN people
# will AUX will
# get VERB get
# there ADV there
# . PUNCT .
#
#  SPACE
#
# There PRON there
# will AUX will
# be AUX be
# setbacks NOUN setback
# and CCONJ and
# false ADJ false
# starts NOUN start
# . PUNCT .
# There PRON there
# are VERB be
# many ADJ many
# who PRON who
# wo AUX will
# n’t PART not
# agree VERB agree
# with ADP with
# every DET every
# decision NOUN decision
# or CCONJ or
# policy NOUN policy
# I PRON I
# make VERB make
# as ADP as
# president NOUN president
# . PUNCT .
# And CCONJ and
# we PRON we
# know VERB know
# the DET the
# government NOUN government
# ca AUX can
# n’t PART not
# solve VERB solve
# every DET every
# problem NOUN problem
# . PUNCT .
#
#  SPACE
#
# But CCONJ but
# I PRON I
# will AUX will
# always ADV always
# be AUX be
# honest ADJ honest
# with ADP with
# you PRON you
# about ADP about
# the DET the
# challenges NOUN challenge
# we PRON we
# face VERB face
# . PUNCT .
# I PRON I
# will AUX will
# listen VERB listen
# to ADP to
# you PRON you
# , PUNCT ,
# especially ADV especially
# when SCONJ when
# we PRON we
# disagree VERB disagree
# . PUNCT .
# And CCONJ and
# , PUNCT ,
# above ADP above
# all PRON all
# , PUNCT ,
# I PRON I
# will AUX will
# ask VERB ask
# you PRON you
# to PART to
# join VERB join
# in ADP in
# the DET the
# work NOUN work
# of ADP of
# remaking VERB remake
# this DET this
# nation NOUN nation
# , PUNCT ,
# the DET the
# only ADJ only
# way NOUN way
# it PRON it
# ’s AUX ’s
# been AUX be
# done VERB do
# in ADP in
# America PROPN America
# for ADP for
# 221 NUM 221
# years NOUN year
# — PUNCT —
# block NOUN block
# by ADP by
# block NOUN block
# , PUNCT ,
# brick NOUN brick
# by ADP by
# brick NOUN brick
# , PUNCT ,
# calloused ADJ calloused
# hand NOUN hand
# by ADP by
# calloused ADJ calloused
# hand NOUN hand
# . PUNCT .
#
#  SPACE
#
# What PRON what
# began VERB begin
# 21 NUM 21
# months NOUN month
# ago ADV ago
# in ADP in
# the DET the
# depths NOUN depth
# of ADP of
# winter NOUN winter
# can AUX can
# not PART not
# end VERB end
# on ADP on
# this DET this
# autumn NOUN autumn
# night NOUN night
# . PUNCT .
#
#  SPACE
#
# This DET this
# victory NOUN victory
# alone ADV alone
# is AUX be
# not PART not
# the DET the
# change NOUN change
# we PRON we
# seek VERB seek
# . PUNCT .
# It PRON it
# is AUX be
# only ADV only
# the DET the
# chance NOUN chance
# for SCONJ for
# us PRON we
# to PART to
# make VERB make
# that DET that
# change NOUN change
# . PUNCT .
# And CCONJ and
# that PRON that
# can AUX can
# not PART not
# happen VERB happen
# if SCONJ if
# we PRON we
# go VERB go
# back ADV back
# to ADP to
# the DET the
# way NOUN way
# things NOUN thing
# were AUX be
# . PUNCT .
#
#  SPACE
#
# It PRON it
# ca AUX can
# n’t PART not
# happen VERB happen
# without ADP without
# you PRON you
# , PUNCT ,
# without ADP without
# a DET a
# new ADJ new
# spirit NOUN spirit
# of ADP of
# service NOUN service
# , PUNCT ,
# a DET a
# new ADJ new
# spirit NOUN spirit
# of ADP of
# sacrifice NOUN sacrifice
# . PUNCT .
#
#  SPACE
#
# So ADV so
# let VERB let
# us PRON we
# summon VERB summon
# a DET a
# new ADJ new
# spirit NOUN spirit
# of ADP of
# patriotism NOUN patriotism
# , PUNCT ,
# of ADP of
# responsibility NOUN responsibility
# , PUNCT ,
# where SCONJ where
# each PRON each
# of ADP of
# us PRON we
# resolves NOUN resolve
# to PART to
# pitch VERB pitch
# in ADP in
# and CCONJ and
# work VERB work
# harder ADV hard
# and CCONJ and
# look VERB look
# after ADP after
# not PART not
# only ADV only
# ourselves PRON ourselves
# but CCONJ but
# each DET each
# other ADJ other
# . PUNCT .
#
#  SPACE
#
# Let VERB let
# us PRON we
# remember VERB remember
# that SCONJ that
# , PUNCT ,
# if SCONJ if
# this DET this
# financial ADJ financial
# crisis NOUN crisis
# taught VERB teach
# us PRON we
# anything PRON anything
# , PUNCT ,
# it PRON it
# ’s VERB ’
# that SCONJ that
# we PRON we
# can AUX can
# not PART not
# have VERB have
# a DET a
# thriving ADJ thriving
# Wall PROPN Wall
# Street PROPN Street
# while SCONJ while
# Main PROPN Main
# Street PROPN Street
# suffers VERB suffer
# . PUNCT .
#
#  SPACE
#
# In ADP in
# this DET this
# country NOUN country
# , PUNCT ,
# we PRON we
# rise VERB rise
# or CCONJ or
# fall VERB fall
# as ADP as
# one NUM one
# nation NOUN nation
# , PUNCT ,
# as ADP as
# one NUM one
# people NOUN people
# . PUNCT .
# Let VERB let
# ’s PRON ’s
# resist VERB resist
# the DET the
# temptation NOUN temptation
# to PART to
# fall VERB fall
# back ADV back
# on ADP on
# the DET the
# same ADJ same
# partisanship NOUN partisanship
# and CCONJ and
# pettiness NOUN pettiness
# and CCONJ and
# immaturity NOUN immaturity
# that PRON that
# has AUX have
# poisoned VERB poison
# our PRON our
# politics NOUN politic
# for ADP for
# so ADV so
# long ADV long
# . PUNCT .
#
#  SPACE
#
# Let VERB let
# ’s PRON ’s
# remember VERB remember
# that SCONJ that
# it PRON it
# was AUX be
# a DET a
# man NOUN man
# from ADP from
# this DET this
# state NOUN state
# who PRON who
# first ADV first
# carried VERB carry
# the DET the
# banner NOUN banner
# of ADP of
# the DET the
# Republican PROPN Republican
# Party PROPN Party
# to ADP to
# the DET the
# White PROPN White
# House PROPN House
# , PUNCT ,
# a DET a
# party NOUN party
# founded VERB found
# on ADP on
# the DET the
# values NOUN value
# of ADP of
# self NOUN self
# - PUNCT -
# reliance NOUN reliance
# and CCONJ and
# individual ADJ individual
# liberty NOUN liberty
# and CCONJ and
# national ADJ national
# unity NOUN unity
# . PUNCT .
#
#  SPACE
#
# Those PRON those
# are AUX be
# values NOUN value
# that PRON that
# we PRON we
# all PRON all
# share VERB share
# . PUNCT .
# And CCONJ and
# while SCONJ while
# the DET the
# Democratic PROPN Democratic
# Party PROPN Party
# has AUX have
# won VERB win
# a DET a
# great ADJ great
# victory NOUN victory
# tonight NOUN tonight
# , PUNCT ,
# we PRON we
# do VERB do
# so ADV so
# with ADP with
# a DET a
# measure NOUN measure
# of ADP of
# humility NOUN humility
# and CCONJ and
# determination NOUN determination
# to PART to
# heal VERB heal
# the DET the
# divides NOUN divide
# that PRON that
# have AUX have
# held VERB hold
# back ADP back
# our PRON our
# progress NOUN progress
# . PUNCT .
#
#  SPACE
#
# As SCONJ as
# Lincoln PROPN Lincoln
# said VERB say
# to ADP to
# a DET a
# nation NOUN nation
# far ADV far
# more ADV more
# divided ADJ divided
# than ADP than
# ours NOUN our
# , PUNCT ,
# we PRON we
# are AUX be
# not PART not
# enemies NOUN enemy
# but CCONJ but
# friends NOUN friend
# . PUNCT .
# Though SCONJ though
# passion NOUN passion
# may AUX may
# have AUX have
# strained VERB strain
# , PUNCT ,
# it PRON it
# must AUX must
# not PART not
# break VERB break
# our PRON our
# bonds NOUN bond
# of ADP of
# affection NOUN affection
# . PUNCT .
#
#  SPACE
#
# And CCONJ and
# to ADP to
# those DET those
# Americans PROPN Americans
# whose DET whose
# support NOUN support
# I PRON I
# have VERB have
# yet ADV yet
# to PART to
# earn VERB earn
# , PUNCT ,
# I PRON I
# may AUX may
# not PART not
# have AUX have
# won VERB win
# your PRON your
# vote NOUN vote
# tonight NOUN tonight
# , PUNCT ,
# but CCONJ but
# I PRON I
# hear VERB hear
# your PRON your
# voices NOUN voice
# . PUNCT .
# I PRON I
# need VERB need
# your PRON your
# help NOUN help
# . PUNCT .
# And CCONJ and
# I PRON I
# will AUX will
# be AUX be
# your PRON your
# president NOUN president
# , PUNCT ,
# too ADV too
# . PUNCT .
#
#  SPACE
#
# And CCONJ and
# to ADP to
# all DET all
# those PRON those
# watching VERB watch
# tonight NOUN tonight
# from ADP from
# beyond ADP beyond
# our PRON our
# shores NOUN shore
# , PUNCT ,
# from ADP from
# parliaments NOUN parliament
# and CCONJ and
# palaces NOUN palace
# , PUNCT ,
# to ADP to
# those PRON those
# who PRON who
# are AUX be
# huddled VERB huddle
# around ADP around
# radios NOUN radio
# in ADP in
# the DET the
# forgotten VERB forget
# corners NOUN corner
# of ADP of
# the DET the
# world NOUN world
# , PUNCT ,
# our PRON our
# stories NOUN story
# are AUX be
# singular ADJ singular
# , PUNCT ,
# but CCONJ but
# our PRON our
# destiny NOUN destiny
# is AUX be
# shared VERB share
# , PUNCT ,
# and CCONJ and
# a DET a
# new ADJ new
# dawn NOUN dawn
# of ADP of
# American ADJ american
# leadership NOUN leadership
# is AUX be
# at ADP at
# hand NOUN hand
# . PUNCT .
#
#  SPACE
#
# To ADP to
# those PRON those
# — PUNCT —
# to ADP to
# those PRON those
# who PRON who
# would AUX would
# tear VERB tear
# the DET the
# world NOUN world
# down ADV down
# : PUNCT :
# We PRON we
# will AUX will
# defeat VERB defeat
# you PRON you
# . PUNCT .
# To ADP to
# those PRON those
# who PRON who
# seek VERB seek
# peace NOUN peace
# and CCONJ and
# security NOUN security
# : PUNCT :
# We PRON we
# support VERB support
# you PRON you
# . PUNCT .
# And CCONJ and
# to ADP to
# all DET all
# those PRON those
# who PRON who
# have AUX have
# wondered VERB wonder
# if SCONJ if
# America PROPN America
# ’s PART ’s
# beacon NOUN beacon
# still ADV still
# burns VERB burn
# as ADP as
# bright ADJ bright
# : PUNCT :
# Tonight NOUN tonight
# we PRON we
# proved VERB prove
# once ADV once
# more ADJ more
# that SCONJ that
# the DET the
# true ADJ true
# strength NOUN strength
# of ADP of
# our PRON our
# nation NOUN nation
# comes VERB come
# not PART not
# from ADP from
# the DET the
# might NOUN might
# of ADP of
# our PRON our
# arms NOUN arm
# or CCONJ or
# the DET the
# scale NOUN scale
# of ADP of
# our PRON our
# wealth NOUN wealth
# , PUNCT ,
# but CCONJ but
# from ADP from
# the DET the
# enduring VERB endure
# power NOUN power
# of ADP of
# our PRON our
# ideals NOUN ideal
# : PUNCT :
# democracy NOUN democracy
# , PUNCT ,
# liberty NOUN liberty
# , PUNCT ,
# opportunity NOUN opportunity
# and CCONJ and
# unyielding VERB unyielde
# hope NOUN hope
# . PUNCT .
#
#  SPACE
#
# That PRON that
# ’s VERB ’
# the DET the
# true ADJ true
# genius NOUN genius
# of ADP of
# America PROPN America
# : PUNCT :
# that SCONJ that
# America PROPN America
# can AUX can
# change VERB change
# . PUNCT .
# Our PRON our
# union NOUN union
# can AUX can
# be AUX be
# perfected VERB perfect
# . PUNCT .
# What PRON what
# we PRON we
# ’ve AUX ’ve
# already ADV already
# achieved VERB achieve
# gives VERB give
# us PRON we
# hope NOUN hope
# for ADP for
# what PRON what
# we PRON we
# can AUX can
# and CCONJ and
# must AUX must
# achieve VERB achieve
# tomorrow NOUN tomorrow
# . PUNCT .
#
#  SPACE
#
# This DET this
# election NOUN election
# had VERB have
# many ADJ many
# firsts NOUN first
# and CCONJ and
# many ADJ many
# stories NOUN story
# that PRON that
# will AUX will
# be AUX be
# told VERB tell
# for ADP for
# generations NOUN generation
# . PUNCT .
# But CCONJ but
# one NOUN one
# that PRON that
# ’s VERB ’
# on ADP on
# my PRON my
# mind NOUN mind
# tonight NOUN tonight
# ’s VERB ’
# about ADP about
# a DET a
# woman NOUN woman
# who PRON who
# cast VERB cast
# her PRON her
# ballot NOUN ballot
# in ADP in
# Atlanta PROPN Atlanta
# . PUNCT .
# She PRON she
# ’s VERB ’
# a DET a
# lot NOUN lot
# like ADP like
# the DET the
# millions NOUN million
# of ADP of
# others NOUN other
# who PRON who
# stood VERB stand
# in ADP in
# line NOUN line
# to PART to
# make VERB make
# their PRON their
# voice NOUN voice
# heard VERB hear
# in ADP in
# this DET this
# election NOUN election
# except SCONJ except
# for ADP for
# one NUM one
# thing NOUN thing
# : PUNCT :
# Ann PROPN Ann
# Nixon PROPN Nixon
# Cooper PROPN Cooper
# is AUX be
# 106 NUM 106
# years NOUN year
# old ADJ old
# . PUNCT .
#
#  SPACE
#
# She PRON she
# was AUX be
# born VERB bear
# just ADV just
# a DET a
# generation NOUN generation
# past ADJ past
# slavery NOUN slavery
# ; PUNCT ;
# a DET a
# time NOUN time
# when SCONJ when
# there PRON there
# were VERB be
# no DET no
# cars NOUN car
# on ADP on
# the DET the
# road NOUN road
# or CCONJ or
# planes NOUN plane
# in ADP in
# the DET the
# sky NOUN sky
# ; PUNCT ;
# when SCONJ when
# someone PRON someone
# like ADP like
# her PRON she
# could AUX could
# n’t PART not
# vote VERB vote
# for ADP for
# two NUM two
# reasons NOUN reason
# — PUNCT —
# because SCONJ because
# she PRON she
# was AUX be
# a DET a
# woman NOUN woman
# and CCONJ and
# because SCONJ because
# of ADP of
# the DET the
# color NOUN color
# of ADP of
# her PRON her
# skin NOUN skin
# . PUNCT .
#
#  SPACE
#
# And CCONJ and
# tonight NOUN tonight
# , PUNCT ,
# I PRON I
# think VERB think
# about ADP about
# all PRON all
# that PRON that
# she PRON she
# ’s AUX ’s
# seen VERB see
# throughout ADP throughout
# her PRON her
# century NOUN century
# in ADP in
# America PROPN America
# — PUNCT —
# the DET the
# heartache NOUN heartache
# and CCONJ and
# the DET the
# hope NOUN hope
# ; PUNCT ;
# the DET the
# struggle NOUN struggle
# and CCONJ and
# the DET the
# progress NOUN progress
# ; PUNCT ;
# the DET the
# times NOUN time
# we PRON we
# were AUX be
# told VERB tell
# that SCONJ that
# we PRON we
# ca AUX can
# n’t NOUN n’t
# , PUNCT ,
# and CCONJ and
# the DET the
# people NOUN people
# who PRON who
# pressed VERB press
# on ADP on
# with ADP with
# that DET that
# American ADJ american
# creed NOUN creed
# : PUNCT :
# Yes INTJ yes
# we PRON we
# can AUX can
# . PUNCT .
#
#  SPACE
#
# At ADP at
# a DET a
# time NOUN time
# when SCONJ when
# women NOUN woman
# ’s PART ’s
# voices NOUN voice
# were AUX be
# silenced VERB silence
# and CCONJ and
# their PRON their
# hopes NOUN hope
# dismissed VERB dismiss
# , PUNCT ,
# she PRON she
# lived VERB live
# to PART to
# see VERB see
# them PRON they
# stand VERB stand
# up ADP up
# and CCONJ and
# speak VERB speak
# out ADP out
# and CCONJ and
# reach VERB reach
# for ADP for
# the DET the
# ballot NOUN ballot
# . PUNCT .
# Yes INTJ yes
# we PRON we
# can AUX can
# . PUNCT .
#
#  SPACE
#
# When SCONJ when
# there PRON there
# was VERB be
# despair NOUN despair
# in ADP in
# the DET the
# dust NOUN dust
# bowl NOUN bowl
# and CCONJ and
# depression NOUN depression
# across ADP across
# the DET the
# land NOUN land
# , PUNCT ,
# she PRON she
# saw VERB see
# a DET a
# nation NOUN nation
# conquer NOUN conquer
# fear VERB fear
# itself PRON itself
# with ADP with
# a DET a
# New PROPN New
# Deal PROPN Deal
# , PUNCT ,
# new ADJ new
# jobs NOUN job
# , PUNCT ,
# a DET a
# new ADJ new
# sense NOUN sense
# of ADP of
# common ADJ common
# purpose NOUN purpose
# . PUNCT .
# Yes INTJ yes
# we PRON we
# can AUX can
# . PUNCT .
#
#  SPACE
#
# When SCONJ when
# the DET the
# bombs NOUN bomb
# fell VERB fall
# on ADP on
# our PRON our
# harbor NOUN harbor
# and CCONJ and
# tyranny NOUN tyranny
# threatened VERB threaten
# the DET the
# world NOUN world
# , PUNCT ,
# she PRON she
# was AUX be
# there ADV there
# to PART to
# witness VERB witness
# a DET a
# generation NOUN generation
# rise NOUN rise
# to ADP to
# greatness NOUN greatness
# and CCONJ and
# a DET a
# democracy NOUN democracy
# was AUX be
# saved VERB save
# . PUNCT .
# Yes INTJ yes
# we PRON we
# can AUX can
# . PUNCT .
#
#  SPACE
#
# She PRON she
# was AUX be
# there ADV there
# for ADP for
# the DET the
# buses NOUN bus
# in ADP in
# Montgomery PROPN Montgomery
# , PUNCT ,
# the DET the
# hoses NOUN hose
# in ADP in
# Birmingham PROPN Birmingham
# , PUNCT ,
# a DET a
# bridge NOUN bridge
# in ADP in
# Selma PROPN Selma
# , PUNCT ,
# and CCONJ and
# a DET a
# preacher NOUN preacher
# from ADP from
# Atlanta PROPN Atlanta
# who PRON who
# told VERB tell
# a DET a
# people NOUN people
# that SCONJ that
# “ PUNCT "
# We PRON we
# Shall AUX shall
# Overcome VERB overcome
# . PUNCT .
# ” PUNCT "
# Yes INTJ yes
# we PRON we
# can AUX can
# . PUNCT .
#
#  SPACE
#
# A DET a
# man NOUN man
# touched VERB touch
# down ADP down
# on ADP on
# the DET the
# moon NOUN moon
# , PUNCT ,
# a DET a
# wall NOUN wall
# came VERB come
# down ADP down
# in ADP in
# Berlin PROPN Berlin
# , PUNCT ,
# a DET a
# world NOUN world
# was AUX be
# connected VERB connect
# by ADP by
# our PRON our
# own ADJ own
# science NOUN science
# and CCONJ and
# imagination NOUN imagination
# . PUNCT .
#
#  SPACE
#
# And CCONJ and
# this DET this
# year NOUN year
# , PUNCT ,
# in ADP in
# this DET this
# election NOUN election
# , PUNCT ,
# she PRON she
# touched VERB touch
# her PRON her
# finger NOUN finger
# to ADP to
# a DET a
# screen NOUN screen
# , PUNCT ,
# and CCONJ and
# cast VERB cast
# her PRON her
# vote NOUN vote
# , PUNCT ,
# because SCONJ because
# after ADP after
# 106 NUM 106
# years NOUN year
# in ADP in
# America PROPN America
# , PUNCT ,
# through ADP through
# the DET the
# best ADJ good
# of ADP of
# times NOUN time
# and CCONJ and
# the DET the
# darkest NOUN darkest
# of ADP of
# hours NOUN hour
# , PUNCT ,
# she PRON she
# knows VERB know
# how SCONJ how
# America PROPN America
# can AUX can
# change VERB change
# . PUNCT .
#
#  SPACE
#
# Yes INTJ yes
# we PRON we
# can AUX can
# . PUNCT .
#
#  SPACE
#
# America PROPN America
# , PUNCT ,
# we PRON we
# have AUX have
# come VERB come
# so ADV so
# far ADV far
# . PUNCT .
# We PRON we
# have AUX have
# seen VERB see
# so ADV so
# much ADJ much
# . PUNCT .
# But CCONJ but
# there PRON there
# is VERB be
# so ADV so
# much ADV much
# more ADJ more
# to PART to
# do VERB do
# . PUNCT .
# So ADV so
# tonight NOUN tonight
# , PUNCT ,
# let VERB let
# us PRON we
# ask VERB ask
# ourselves PRON ourselves
# — PUNCT —
# if SCONJ if
# our PRON our
# children NOUN child
# should AUX should
# live VERB live
# to PART to
# see VERB see
# the DET the
# next ADJ next
# century NOUN century
# ; PUNCT ;
# if SCONJ if
# my PRON my
# daughters NOUN daughter
# should AUX should
# be AUX be
# so ADV so
# lucky ADJ lucky
# to PART to
# live VERB live
# as ADV as
# long ADV long
# as ADP as
# Ann PROPN Ann
# Nixon PROPN Nixon
# Cooper PROPN Cooper
# , PUNCT ,
# what PRON what
# change NOUN change
# will AUX will
# they PRON they
# see VERB see
# ? PUNCT ?
# What DET what
# progress NOUN progress
# will AUX will
# we PRON we
# have AUX have
# made VERB make
# ? PUNCT ?
#
#  SPACE
#
# This PRON this
# is AUX be
# our PRON our
# chance NOUN chance
# to PART to
# answer VERB answer
# that DET that
# call NOUN call
# . PUNCT .
# This PRON this
# is AUX be
# our PRON our
# moment NOUN moment
# . PUNCT .
#
#  SPACE
#
# This PRON this
# is AUX be
# our PRON our
# time NOUN time
# , PUNCT ,
# to PART to
# put VERB put
# our PRON our
# people NOUN people
# back ADV back
# to ADP to
# work NOUN work
# and CCONJ and
# open ADJ open
# doors NOUN door
# of ADP of
# opportunity NOUN opportunity
# for ADP for
# our PRON our
# kids NOUN kid
# ; PUNCT ;
# to PART to
# restore VERB restore
# prosperity NOUN prosperity
# and CCONJ and
# promote VERB promote
# the DET the
# cause NOUN cause
# of ADP of
# peace NOUN peace
# ; PUNCT ;
# to PART to
# reclaim VERB reclaim
# the DET the
# American ADJ american
# dream NOUN dream
# and CCONJ and
# reaffirm VERB reaffirm
# that DET that
# fundamental ADJ fundamental
# truth NOUN truth
# , PUNCT ,
# that SCONJ that
# , PUNCT ,
# out ADP out
# of ADP of
# many ADJ many
# , PUNCT ,
# we PRON we
# are AUX be
# one NUM one
# ; PUNCT ;
# that SCONJ that
# while SCONJ while
# we PRON we
# breathe VERB breathe
# , PUNCT ,
# we PRON we
# hope VERB hope
# . PUNCT .
# And CCONJ and
# where SCONJ where
# we PRON we
# are AUX be
# met VERB meet
# with ADP with
# cynicism NOUN cynicism
# and CCONJ and
# doubts NOUN doubt
# and CCONJ and
# those PRON those
# who PRON who
# tell VERB tell
# us PRON we
# that SCONJ that
# we PRON we
# ca AUX can
# n’t PART not
# , PUNCT ,
# we PRON we
# will AUX will
# respond VERB respond
# with ADP with
# that DET that
# timeless NOUN timeless
# creed NOUN creed
# that PRON that
# sums VERB sum
# up ADP up
# the DET the
# spirit NOUN spirit
# of ADP of
# a DET a
# people NOUN people
# : PUNCT :
# Yes INTJ yes
# , PUNCT ,
# we PRON we
# can AUX can
# . PUNCT .
# [ X [

# %%
# Ver named entities
for ent in doc.ents:
    print(ent.text, ent.label_)
# Out:
# Chicago GPE
# America GPE
# tonight TIME
# three hours TIME
# four hours TIME
# first ORDINAL
# Democrat NORP
# Republican NORP
# Hispanic NORP
# Asian NORP
# Native American NORP
# Americans NORP
# the United States of America GPE
# tonight TIME
# America GPE
# Washington GPE
# Des Moines GPE
# Concord GPE
# Charleston GPE
# $5 and $10 and $20 MONEY
# millions CARDINAL
# Americans NORP
# more than two centuries later DATE
# Earth LOC
# tonight TIME
# tomorrow DATE
# two CARDINAL
# a century DATE
# tonight TIME
# Americans NORP
# Iraq GPE
# Afghanistan GPE
# one year DATE
# one CARDINAL
# America GPE
# tonight TIME
# America GPE
# 221 years DATE
# 21 months ago DATE
# winter DATE
# this autumn night TIME
# Main Street FAC
# one CARDINAL
# one CARDINAL
# first ORDINAL
# the Republican Party ORG
# the White House ORG
# the Democratic Party ORG
# tonight TIME
# Lincoln ORG
# Americans NORP
# tonight TIME
# tonight TIME
# American NORP
# America GPE
# Tonight TIME
# America GPE
# America GPE
# tomorrow DATE
# tonight TIME
# Atlanta GPE
# millions CARDINAL
# one CARDINAL
# Ann Nixon Cooper PERSON
# 106 years old DATE
# two CARDINAL
# tonight TIME
# America GPE
# American NORP
# Montgomery ORG
# Birmingham GPE
# Selma GPE
# Atlanta GPE
# the moon LOC
# Berlin GPE
# this year DATE
# 106 years DATE
# America GPE
# hours TIME
# America GPE
# America GPE
# tonight TIME
# the next century DATE
# Ann Nixon Cooper PERSON
# American NORP

# %%
# Ver frases
for sent in doc.sents:
    print(sent.text)
# Out:
# “Hello, Chicago.
#
# If there is anyone out there who still doubts that America is a place where all things are possible, who still wonders if the dream of our founders is alive in our time, who still questions the power of our democracy, tonight is your answer.
#
# It’s the answer told by lines that stretched around schools and churches in numbers this nation has never seen, by people who waited three hours and four hours, many for the first time in their lives, because they believed that this time must be different, that their voices could be that difference.
#
# It’s the answer spoken by young and old, rich and poor, Democrat and Republican, black, white, Hispanic, Asian, Native American, gay, straight, disabled and not disabled.
# Americans who sent a message to the world that we have never been just a collection of individuals or a collection of red states and blue states.
#
# We are, and always will be, the United States of America.
#
# It’s the answer that led those who’ve been told for so long by so many to be cynical and fearful and doubtful about what we can achieve to put their hands on the arc of history and bend it once more toward the hope of a better day.
#
# It’s been a long time coming, but tonight, because of what we did on this date in this election at this defining moment change has come to America.
#
# [read more]
#
# We didn’t start with much money or many endorsements.
# Our campaign was not hatched in the halls of Washington.
# It began in the backyards of Des Moines and the living rooms of Concord and the front porches of Charleston.
# It was built by working men and women who dug into what little savings they had to give $5 and $10 and $20 to the cause.
#
# It grew strength from the young people who rejected the myth of their generation’s apathy who left their homes and their families for jobs that offered little pay and less sleep.
#
# It drew strength from the not-so-young people who braved the bitter cold and scorching heat to knock on doors of perfect strangers, and from the millions of Americans who volunteered and organized and proved that more than two centuries later a government of the people, by the people, and for the people has not perished from the Earth.
#
# This is your victory.
#
# And I know you didn’t do this just to win an election.
# And I know you didn’t do it for me.
#
# You did it because you understand the enormity of the task that lies ahead.
# For even as we celebrate tonight, we know the challenges that tomorrow will bring are the greatest of our lifetime — two wars, a planet in peril, the worst financial crisis in a century.
#
# Even as we stand here tonight, we know there are brave Americans waking up in the deserts of Iraq and the mountains of Afghanistan to risk their lives for us.
#
# There are mothers and fathers who will lie awake after the children fall asleep and wonder how they’ll make the mortgage or pay their doctors’ bills or save enough for their child’s college education.
#
# There’s new energy to harness, new jobs to be created, new schools to build, and threats to meet, alliances to repair.
#
# The road ahead will be long.
# Our climb will be steep.
# We may not get there in one year or even in one term.
# But, America, I have never been more hopeful than I am tonight that we will get there.
#
# I promise you, we as a people will get there.
#
# There will be setbacks and false starts.
# There are many who won’t agree with every decision or policy I make as president.
# And we know the government can’t solve every problem.
#
# But I will always be honest with you about the challenges we face.
# I will listen to you, especially when we disagree.
# And, above all, I will ask you to join in the work of remaking this nation, the only way it’s been done in America for 221 years — block by block, brick by brick, calloused hand by calloused hand.
#
# What began 21 months ago in the depths of winter cannot end on this autumn night.
#
# This victory alone is not the change we seek.
# It is only the chance for us to make that change.
# And that cannot happen if we go back to the way things were.
#
# It can’t happen without you, without a new spirit of service, a new spirit of sacrifice.
#
# So let us summon a new spirit of patriotism, of responsibility, where each of us resolves to pitch in and work harder and look after not only ourselves but each other.
#
# Let us remember that, if this financial crisis taught us anything, it’s that we cannot have a thriving Wall Street while Main Street suffers.
#
# In this country, we rise or fall as one nation, as one people.
# Let’s resist the temptation to fall back on the same partisanship and pettiness and immaturity that has poisoned our politics for so long.
#
# Let’s remember that it was a man from this state who first carried the banner of the Republican Party to the White House, a party founded on the values of self-reliance and individual liberty and national unity.
#
# Those are values that we all share.
# And while the Democratic Party has won a great victory tonight, we do so with a measure of humility and determination to heal the divides that have held back our progress.
#
# As Lincoln said to a nation far more divided than ours, we are not enemies but friends.
# Though passion may have strained, it must not break our bonds of affection.
#
# And to those Americans whose support I have yet to earn, I may not have won your vote tonight, but I hear your voices.
# I need your help.
# And I will be your president, too.
#
# And to all those watching tonight from beyond our shores, from parliaments and palaces, to those who are huddled around radios in the forgotten corners of the world, our stories are singular, but our destiny is shared, and a new dawn of American leadership is at hand.
#
# To those — to those who would tear the world down: We will defeat you.
# To those who seek peace and security: We support you.
# And to all those who have wondered if America’s beacon still burns as bright: Tonight we proved once more that the true strength of our nation comes not from the might of our arms or the scale of our wealth, but from the enduring power of our ideals: democracy, liberty, opportunity and unyielding hope.
#
# That’s the true genius of America: that America can change.
# Our union can be perfected.
# What we’ve already achieved gives us hope for what we can and must achieve tomorrow.
#
# This election had many firsts and many stories that will be told for generations.
# But one that’s on my mind tonight’s about a woman who cast her ballot in Atlanta.
# She’s a lot like the millions of others who stood in line to make their voice heard in this election except for one thing: Ann Nixon Cooper is 106 years old.
#
# She was born just a generation past slavery; a time when there were no cars on the road or planes in the sky; when someone like her couldn’t vote for two reasons — because she was a woman and because of the color of her skin.
#
# And tonight, I think about all that she’s seen throughout her century in America — the heartache and the hope; the struggle and the progress; the times we were told that we can’t, and the people who pressed on with that American creed: Yes we can.
#
# At a time when women’s voices were silenced and their hopes dismissed, she lived to see them stand up and speak out and reach for the ballot.
# Yes we can.
#
# When there was despair in the dust bowl and depression across the land, she saw a nation conquer fear itself with a New Deal, new jobs, a new sense of common purpose.
# Yes we can.
#
# When the bombs fell on our harbor and tyranny threatened the world, she was there to witness a generation rise to greatness and a democracy was saved.
# Yes we can.
#
# She was there for the buses in Montgomery, the hoses in Birmingham, a bridge in Selma, and a preacher from Atlanta who told a people that “We Shall Overcome.”
# Yes we can.
#
# A man touched down on the moon, a wall came down in Berlin, a world was connected by our own science and imagination.
#
# And this year, in this election, she touched her finger to a screen, and cast her vote, because after 106 years in America, through the best of times and the darkest of hours, she knows how America can change.
#
# Yes we can.
#
# America, we have come so far.
# We have seen so much.
# But there is so much more to do.
# So tonight, let us ask ourselves — if our children should live to see the next century; if my daughters should be so lucky to live as long as Ann Nixon Cooper, what change will they see?
# What progress will we have made?
#
# This is our chance to answer that call.
# This is our moment.
#
# This is our time, to put our people back to work and open doors of opportunity for our kids; to restore prosperity and promote the cause of peace; to reclaim the American dream and reaffirm that fundamental truth, that, out of many, we are one; that while we breathe, we hope.
# And where we are met with cynicism and doubts and those who tell us that we can’t, we will respond with that timeless creed that sums up the spirit of a people: Yes, we can.
# [

# %%
# Ver tags
for token in doc:
    print(token.text, token.pos_)
# Out:
# “ PUNCT
# Hello PROPN
# , PUNCT
# Chicago PROPN
# . PUNCT
#
#  SPACE
# If SCONJ
# there PRON
# is VERB
# anyone PRON
# out ADV
# there ADV
# who PRON
# still ADV
# doubts VERB
# that SCONJ
# America PROPN
# is AUX
# a DET
# place NOUN
# where SCONJ
# all DET
# things NOUN
# are AUX
# possible ADJ
# , PUNCT
# who PRON
# still ADV
# wonders VERB
# if SCONJ
# the DET
# dream NOUN
# of ADP
# our PRON
# founders NOUN
# is AUX
# alive ADJ
# in ADP
# our PRON
# time NOUN
# , PUNCT
# who PRON
# still ADV
# questions VERB
# the DET
# power NOUN
# of ADP
# our PRON
# democracy NOUN
# , PUNCT
# tonight NOUN
# is AUX
# your PRON
# answer NOUN
# . PUNCT
#
#  SPACE
# It PRON
# ’s VERB
# the DET
# answer NOUN
# told VERB
# by ADP
# lines NOUN
# that PRON
# stretched VERB
# around ADP
# schools NOUN
# and CCONJ
# churches NOUN
# in ADP
# numbers NOUN
# this DET
# nation NOUN
# has AUX
# never ADV
# seen VERB
# , PUNCT
# by ADP
# people NOUN
# who PRON
# waited VERB
# three NUM
# hours NOUN
# and CCONJ
# four NUM
# hours NOUN
# , PUNCT
# many ADJ
# for ADP
# the DET
# first ADJ
# time NOUN
# in ADP
# their PRON
# lives NOUN
# , PUNCT
# because SCONJ
# they PRON
# believed VERB
# that SCONJ
# this DET
# time NOUN
# must AUX
# be AUX
# different ADJ
# , PUNCT
# that SCONJ
# their PRON
# voices NOUN
# could AUX
# be AUX
# that DET
# difference NOUN
# . PUNCT
#
#  SPACE
# It PRON
# ’s VERB
# the DET
# answer NOUN
# spoken VERB
# by ADP
# young ADJ
# and CCONJ
# old ADJ
# , PUNCT
# rich ADJ
# and CCONJ
# poor ADJ
# , PUNCT
# Democrat PROPN
# and CCONJ
# Republican PROPN
# , PUNCT
# black ADJ
# , PUNCT
# white ADJ
# , PUNCT
# Hispanic ADJ
# , PUNCT
# Asian ADJ
# , PUNCT
# Native PROPN
# American PROPN
# , PUNCT
# gay ADJ
# , PUNCT
# straight ADJ
# , PUNCT
# disabled ADJ
# and CCONJ
# not PART
# disabled ADJ
# . PUNCT
# Americans NOUN
# who PRON
# sent VERB
# a DET
# message NOUN
# to ADP
# the DET
# world NOUN
# that SCONJ
# we PRON
# have AUX
# never ADV
# been AUX
# just ADV
# a DET
# collection NOUN
# of ADP
# individuals NOUN
# or CCONJ
# a DET
# collection NOUN
# of ADP
# red ADJ
# states NOUN
# and CCONJ
# blue ADJ
# states NOUN
# . PUNCT
#
#  SPACE
# We PRON
# are AUX
# , PUNCT
# and CCONJ
# always ADV
# will AUX
# be AUX
# , PUNCT
# the DET
# United PROPN
# States PROPN
# of ADP
# America PROPN
# . PUNCT
#
#  SPACE
# It PRON
# ’s VERB
# the DET
# answer NOUN
# that PRON
# led VERB
# those PRON
# who PRON
# ’ve AUX
# been AUX
# told VERB
# for ADP
# so ADV
# long ADV
# by ADP
# so ADV
# many ADJ
# to PART
# be AUX
# cynical ADJ
# and CCONJ
# fearful ADJ
# and CCONJ
# doubtful ADJ
# about ADP
# what PRON
# we PRON
# can AUX
# achieve VERB
# to PART
# put VERB
# their PRON
# hands NOUN
# on ADP
# the DET
# arc NOUN
# of ADP
# history NOUN
# and CCONJ
# bend VERB
# it PRON
# once ADV
# more ADV
# toward ADP
# the DET
# hope NOUN
# of ADP
# a DET
# better ADJ
# day NOUN
# . PUNCT
#
#  SPACE
# It PRON
# ’s AUX
# been AUX
# a DET
# long ADJ
# time NOUN
# coming VERB
# , PUNCT
# but CCONJ
# tonight NOUN
# , PUNCT
# because SCONJ
# of ADP
# what PRON
# we PRON
# did AUX
# on ADP
# this DET
# date NOUN
# in ADP
# this DET
# election NOUN
# at ADP
# this DET
# defining VERB
# moment NOUN
# change NOUN
# has AUX
# come VERB
# to ADP
# America PROPN
# . PUNCT
#
#  SPACE
# [ PUNCT
# read VERB
# more ADJ
# ] PUNCT
#
#
#  SPACE
# We PRON
# did AUX
# n’t PART
# start VERB
# with ADP
# much ADJ
# money NOUN
# or CCONJ
# many ADJ
# endorsements NOUN
# . PUNCT
# Our PRON
# campaign NOUN
# was AUX
# not PART
# hatched VERB
# in ADP
# the DET
# halls NOUN
# of ADP
# Washington PROPN
# . PUNCT
# It PRON
# began VERB
# in ADP
# the DET
# backyards NOUN
# of ADP
# Des PROPN
# Moines PROPN
# and CCONJ
# the DET
# living VERB
# rooms NOUN
# of ADP
# Concord PROPN
# and CCONJ
# the DET
# front ADJ
# porches NOUN
# of ADP
# Charleston PROPN
# . PUNCT
# It PRON
# was AUX
# built VERB
# by ADP
# working VERB
# men NOUN
# and CCONJ
# women NOUN
# who PRON
# dug VERB
# into ADP
# what PRON
# little ADJ
# savings NOUN
# they PRON
# had VERB
# to PART
# give VERB
# $ SYM
# 5 NUM
# and CCONJ
# $ SYM
# 10 NUM
# and CCONJ
# $ SYM
# 20 NUM
# to ADP
# the DET
# cause NOUN
# . PUNCT
#
#  SPACE
# It PRON
# grew VERB
# strength NOUN
# from ADP
# the DET
# young ADJ
# people NOUN
# who PRON
# rejected VERB
# the DET
# myth NOUN
# of ADP
# their PRON
# generation NOUN
# ’s PART
# apathy ADJ
# who PRON
# left VERB
# their PRON
# homes NOUN
# and CCONJ
# their PRON
# families NOUN
# for ADP
# jobs NOUN
# that PRON
# offered VERB
# little ADJ
# pay NOUN
# and CCONJ
# less ADJ
# sleep NOUN
# . PUNCT
#
#  SPACE
# It PRON
# drew VERB
# strength NOUN
# from ADP
# the DET
# not PART
# - PUNCT
# so ADV
# - PUNCT
# young ADJ
# people NOUN
# who PRON
# braved VERB
# the DET
# bitter ADJ
# cold NOUN
# and CCONJ
# scorching VERB
# heat NOUN
# to PART
# knock VERB
# on ADP
# doors NOUN
# of ADP
# perfect ADJ
# strangers NOUN
# , PUNCT
# and CCONJ
# from ADP
# the DET
# millions NOUN
# of ADP
# Americans PROPN
# who PRON
# volunteered VERB
# and CCONJ
# organized VERB
# and CCONJ
# proved VERB
# that SCONJ
# more ADJ
# than ADP
# two NUM
# centuries NOUN
# later ADV
# a DET
# government NOUN
# of ADP
# the DET
# people NOUN
# , PUNCT
# by ADP
# the DET
# people NOUN
# , PUNCT
# and CCONJ
# for ADP
# the DET
# people NOUN
# has AUX
# not PART
# perished VERB
# from ADP
# the DET
# Earth PROPN
# . PUNCT
#
#  SPACE
# This PRON
# is AUX
# your PRON
# victory NOUN
# . PUNCT
#
#  SPACE
# And CCONJ
# I PRON
# know VERB
# you PRON
# did AUX
# n’t PART
# do VERB
# this PRON
# just ADV
# to PART
# win VERB
# an DET
# election NOUN
# . PUNCT
# And CCONJ
# I PRON
# know VERB
# you PRON
# did AUX
# n’t PART
# do VERB
# it PRON
# for ADP
# me PRON
# . PUNCT
#
#  SPACE
# You PRON
# did VERB
# it PRON
# because SCONJ
# you PRON
# understand VERB
# the DET
# enormity NOUN
# of ADP
# the DET
# task NOUN
# that PRON
# lies VERB
# ahead ADV
# . PUNCT
# For ADP
# even ADV
# as SCONJ
# we PRON
# celebrate VERB
# tonight NOUN
# , PUNCT
# we PRON
# know VERB
# the DET
# challenges NOUN
# that PRON
# tomorrow NOUN
# will AUX
# bring VERB
# are AUX
# the DET
# greatest ADJ
# of ADP
# our PRON
# lifetime NOUN
# — PUNCT
# two NUM
# wars NOUN
# , PUNCT
# a DET
# planet NOUN
# in ADP
# peril NOUN
# , PUNCT
# the DET
# worst ADJ
# financial ADJ
# crisis NOUN
# in ADP
# a DET
# century NOUN
# . PUNCT
#
#  SPACE
# Even ADV
# as SCONJ
# we PRON
# stand VERB
# here ADV
# tonight NOUN
# , PUNCT
# we PRON
# know VERB
# there PRON
# are VERB
# brave ADJ
# Americans PROPN
# waking VERB
# up ADP
# in ADP
# the DET
# deserts NOUN
# of ADP
# Iraq PROPN
# and CCONJ
# the DET
# mountains NOUN
# of ADP
# Afghanistan PROPN
# to PART
# risk VERB
# their PRON
# lives NOUN
# for ADP
# us PRON
# . PUNCT
#
#  SPACE
# There PRON
# are VERB
# mothers NOUN
# and CCONJ
# fathers NOUN
# who PRON
# will AUX
# lie VERB
# awake ADJ
# after SCONJ
# the DET
# children NOUN
# fall VERB
# asleep ADJ
# and CCONJ
# wonder VERB
# how SCONJ
# they PRON
# ’ll AUX
# make VERB
# the DET
# mortgage NOUN
# or CCONJ
# pay VERB
# their PRON
# doctors NOUN
# ’ PART
# bills NOUN
# or CCONJ
# save VERB
# enough ADJ
# for ADP
# their PRON
# child NOUN
# ’s PART
# college NOUN
# education NOUN
# . PUNCT
#
#  SPACE
# There PRON
# ’s VERB
# new ADJ
# energy NOUN
# to ADP
# harness NOUN
# , PUNCT
# new ADJ
# jobs NOUN
# to PART
# be AUX
# created VERB
# , PUNCT
# new ADJ
# schools NOUN
# to PART
# build VERB
# , PUNCT
# and CCONJ
# threats NOUN
# to PART
# meet VERB
# , PUNCT
# alliances NOUN
# to PART
# repair VERB
# . PUNCT
#
#  SPACE
# The DET
# road NOUN
# ahead ADV
# will AUX
# be AUX
# long ADJ
# . PUNCT
# Our PRON
# climb NOUN
# will AUX
# be AUX
# steep ADJ
# . PUNCT
# We PRON
# may AUX
# not PART
# get VERB
# there ADV
# in ADP
# one NUM
# year NOUN
# or CCONJ
# even ADV
# in ADP
# one NUM
# term NOUN
# . PUNCT
# But CCONJ
# , PUNCT
# America PROPN
# , PUNCT
# I PRON
# have AUX
# never ADV
# been AUX
# more ADV
# hopeful ADJ
# than SCONJ
# I PRON
# am AUX
# tonight NOUN
# that SCONJ
# we PRON
# will AUX
# get VERB
# there ADV
# . PUNCT
#
#  SPACE
# I PRON
# promise VERB
# you PRON
# , PUNCT
# we PRON
# as ADP
# a DET
# people NOUN
# will AUX
# get VERB
# there ADV
# . PUNCT
#
#  SPACE
# There PRON
# will AUX
# be AUX
# setbacks NOUN
# and CCONJ
# false ADJ
# starts NOUN
# . PUNCT
# There PRON
# are VERB
# many ADJ
# who PRON
# wo AUX
# n’t PART
# agree VERB
# with ADP
# every DET
# decision NOUN
# or CCONJ
# policy NOUN
# I PRON
# make VERB
# as ADP
# president NOUN
# . PUNCT
# And CCONJ
# we PRON
# know VERB
# the DET
# government NOUN
# ca AUX
# n’t PART
# solve VERB
# every DET
# problem NOUN
# . PUNCT
#
#  SPACE
# But CCONJ
# I PRON
# will AUX
# always ADV
# be AUX
# honest ADJ
# with ADP
# you PRON
# about ADP
# the DET
# challenges NOUN
# we PRON
# face VERB
# . PUNCT
# I PRON
# will AUX
# listen VERB
# to ADP
# you PRON
# , PUNCT
# especially ADV
# when SCONJ
# we PRON
# disagree VERB
# . PUNCT
# And CCONJ
# , PUNCT
# above ADP
# all PRON
# , PUNCT
# I PRON
# will AUX
# ask VERB
# you PRON
# to PART
# join VERB
# in ADP
# the DET
# work NOUN
# of ADP
# remaking VERB
# this DET
# nation NOUN
# , PUNCT
# the DET
# only ADJ
# way NOUN
# it PRON
# ’s AUX
# been AUX
# done VERB
# in ADP
# America PROPN
# for ADP
# 221 NUM
# years NOUN
# — PUNCT
# block NOUN
# by ADP
# block NOUN
# , PUNCT
# brick NOUN
# by ADP
# brick NOUN
# , PUNCT
# calloused ADJ
# hand NOUN
# by ADP
# calloused ADJ
# hand NOUN
# . PUNCT
#
#  SPACE
# What PRON
# began VERB
# 21 NUM
# months NOUN
# ago ADV
# in ADP
# the DET
# depths NOUN
# of ADP
# winter NOUN
# can AUX
# not PART
# end VERB
# on ADP
# this DET
# autumn NOUN
# night NOUN
# . PUNCT
#
#  SPACE
# This DET
# victory NOUN
# alone ADV
# is AUX
# not PART
# the DET
# change NOUN
# we PRON
# seek VERB
# . PUNCT
# It PRON
# is AUX
# only ADV
# the DET
# chance NOUN
# for SCONJ
# us PRON
# to PART
# make VERB
# that DET
# change NOUN
# . PUNCT
# And CCONJ
# that PRON
# can AUX
# not PART
# happen VERB
# if SCONJ
# we PRON
# go VERB
# back ADV
# to ADP
# the DET
# way NOUN
# things NOUN
# were AUX
# . PUNCT
#
#  SPACE
# It PRON
# ca AUX
# n’t PART
# happen VERB
# without ADP
# you PRON
# , PUNCT
# without ADP
# a DET
# new ADJ
# spirit NOUN
# of ADP
# service NOUN
# , PUNCT
# a DET
# new ADJ
# spirit NOUN
# of ADP
# sacrifice NOUN
# . PUNCT
#
#  SPACE
# So ADV
# let VERB
# us PRON
# summon VERB
# a DET
# new ADJ
# spirit NOUN
# of ADP
# patriotism NOUN
# , PUNCT
# of ADP
# responsibility NOUN
# , PUNCT
# where SCONJ
# each PRON
# of ADP
# us PRON
# resolves NOUN
# to PART
# pitch VERB
# in ADP
# and CCONJ
# work VERB
# harder ADV
# and CCONJ
# look VERB
# after ADP
# not PART
# only ADV
# ourselves PRON
# but CCONJ
# each DET
# other ADJ
# . PUNCT
#
#  SPACE
# Let VERB
# us PRON
# remember VERB
# that SCONJ
# , PUNCT
# if SCONJ
# this DET
# financial ADJ
# crisis NOUN
# taught VERB
# us PRON
# anything PRON
# , PUNCT
# it PRON
# ’s VERB
# that SCONJ
# we PRON
# can AUX
# not PART
# have VERB
# a DET
# thriving ADJ
# Wall PROPN
# Street PROPN
# while SCONJ
# Main PROPN
# Street PROPN
# suffers VERB
# . PUNCT
#
#  SPACE
# In ADP
# this DET
# country NOUN
# , PUNCT
# we PRON
# rise VERB
# or CCONJ
# fall VERB
# as ADP
# one NUM
# nation NOUN
# , PUNCT
# as ADP
# one NUM
# people NOUN
# . PUNCT
# Let VERB
# ’s PRON
# resist VERB
# the DET
# temptation NOUN
# to PART
# fall VERB
# back ADV
# on ADP
# the DET
# same ADJ
# partisanship NOUN
# and CCONJ
# pettiness NOUN
# and CCONJ
# immaturity NOUN
# that PRON
# has AUX
# poisoned VERB
# our PRON
# politics NOUN
# for ADP
# so ADV
# long ADV
# . PUNCT
#
#  SPACE
# Let VERB
# ’s PRON
# remember VERB
# that SCONJ
# it PRON
# was AUX
# a DET
# man NOUN
# from ADP
# this DET
# state NOUN
# who PRON
# first ADV
# carried VERB
# the DET
# banner NOUN
# of ADP
# the DET
# Republican PROPN
# Party PROPN
# to ADP
# the DET
# White PROPN
# House PROPN
# , PUNCT
# a DET
# party NOUN
# founded VERB
# on ADP
# the DET
# values NOUN
# of ADP
# self NOUN
# - PUNCT
# reliance NOUN
# and CCONJ
# individual ADJ
# liberty NOUN
# and CCONJ
# national ADJ
# unity NOUN
# . PUNCT
#
#  SPACE
# Those PRON
# are AUX
# values NOUN
# that PRON
# we PRON
# all PRON
# share VERB
# . PUNCT
# And CCONJ
# while SCONJ
# the DET
# Democratic PROPN
# Party PROPN
# has AUX
# won VERB
# a DET
# great ADJ
# victory NOUN
# tonight NOUN
# , PUNCT
# we PRON
# do VERB
# so ADV
# with ADP
# a DET
# measure NOUN
# of ADP
# humility NOUN
# and CCONJ
# determination NOUN
# to PART
# heal VERB
# the DET
# divides NOUN
# that PRON
# have AUX
# held VERB
# back ADP
# our PRON
# progress NOUN
# . PUNCT
#
#  SPACE
# As SCONJ
# Lincoln PROPN
# said VERB
# to ADP
# a DET
# nation NOUN
# far ADV
# more ADV
# divided ADJ
# than ADP
# ours NOUN
# , PUNCT
# we PRON
# are AUX
# not PART
# enemies NOUN
# but CCONJ
# friends NOUN
# . PUNCT
# Though SCONJ
# passion NOUN
# may AUX
# have AUX
# strained VERB
# , PUNCT
# it PRON
# must AUX
# not PART
# break VERB
# our PRON
# bonds NOUN
# of ADP
# affection NOUN
# . PUNCT
#
#  SPACE
# And CCONJ
# to ADP
# those DET
# Americans PROPN
# whose DET
# support NOUN
# I PRON
# have VERB
# yet ADV
# to PART
# earn VERB
# , PUNCT
# I PRON
# may AUX
# not PART
# have AUX
# won VERB
# your PRON
# vote NOUN
# tonight NOUN
# , PUNCT
# but CCONJ
# I PRON
# hear VERB
# your PRON
# voices NOUN
# . PUNCT
# I PRON
# need VERB
# your PRON
# help NOUN
# . PUNCT
# And CCONJ
# I PRON
# will AUX
# be AUX
# your PRON
# president NOUN
# , PUNCT
# too ADV
# . PUNCT
#
#  SPACE
# And CCONJ
# to ADP
# all DET
# those PRON
# watching VERB
# tonight NOUN
# from ADP
# beyond ADP
# our PRON
# shores NOUN
# , PUNCT
# from ADP
# parliaments NOUN
# and CCONJ
# palaces NOUN
# , PUNCT
# to ADP
# those PRON
# who PRON
# are AUX
# huddled VERB
# around ADP
# radios NOUN
# in ADP
# the DET
# forgotten VERB
# corners NOUN
# of ADP
# the DET
# world NOUN
# , PUNCT
# our PRON
# stories NOUN
# are AUX
# singular ADJ
# , PUNCT
# but CCONJ
# our PRON
# destiny NOUN
# is AUX
# shared VERB
# , PUNCT
# and CCONJ
# a DET
# new ADJ
# dawn NOUN
# of ADP
# American ADJ
# leadership NOUN
# is AUX
# at ADP
# hand NOUN
# . PUNCT
#
#  SPACE
# To ADP
# those PRON
# — PUNCT
# to ADP
# those PRON
# who PRON
# would AUX
# tear VERB
# the DET
# world NOUN
# down ADV
# : PUNCT
# We PRON
# will AUX
# defeat VERB
# you PRON
# . PUNCT
# To ADP
# those PRON
# who PRON
# seek VERB
# peace NOUN
# and CCONJ
# security NOUN
# : PUNCT
# We PRON
# support VERB
# you PRON
# . PUNCT
# And CCONJ
# to ADP
# all DET
# those PRON
# who PRON
# have AUX
# wondered VERB
# if SCONJ
# America PROPN
# ’s PART
# beacon NOUN
# still ADV
# burns VERB
# as ADP
# bright ADJ
# : PUNCT
# Tonight NOUN
# we PRON
# proved VERB
# once ADV
# more ADJ
# that SCONJ
# the DET
# true ADJ
# strength NOUN
# of ADP
# our PRON
# nation NOUN
# comes VERB
# not PART
# from ADP
# the DET
# might NOUN
# of ADP
# our PRON
# arms NOUN
# or CCONJ
# the DET
# scale NOUN
# of ADP
# our PRON
# wealth NOUN
# , PUNCT
# but CCONJ
# from ADP
# the DET
# enduring VERB
# power NOUN
# of ADP
# our PRON
# ideals NOUN
# : PUNCT
# democracy NOUN
# , PUNCT
# liberty NOUN
# , PUNCT
# opportunity NOUN
# and CCONJ
# unyielding VERB
# hope NOUN
# . PUNCT
#
#  SPACE
# That PRON
# ’s VERB
# the DET
# true ADJ
# genius NOUN
# of ADP
# America PROPN
# : PUNCT
# that SCONJ
# America PROPN
# can AUX
# change VERB
# . PUNCT
# Our PRON
# union NOUN
# can AUX
# be AUX
# perfected VERB
# . PUNCT
# What PRON
# we PRON
# ’ve AUX
# already ADV
# achieved VERB
# gives VERB
# us PRON
# hope NOUN
# for ADP
# what PRON
# we PRON
# can AUX
# and CCONJ
# must AUX
# achieve VERB
# tomorrow NOUN
# . PUNCT
#
#  SPACE
# This DET
# election NOUN
# had VERB
# many ADJ
# firsts NOUN
# and CCONJ
# many ADJ
# stories NOUN
# that PRON
# will AUX
# be AUX
# told VERB
# for ADP
# generations NOUN
# . PUNCT
# But CCONJ
# one NOUN
# that PRON
# ’s VERB
# on ADP
# my PRON
# mind NOUN
# tonight NOUN
# ’s VERB
# about ADP
# a DET
# woman NOUN
# who PRON
# cast VERB
# her PRON
# ballot NOUN
# in ADP
# Atlanta PROPN
# . PUNCT
# She PRON
# ’s VERB
# a DET
# lot NOUN
# like ADP
# the DET
# millions NOUN
# of ADP
# others NOUN
# who PRON
# stood VERB
# in ADP
# line NOUN
# to PART
# make VERB
# their PRON
# voice NOUN
# heard VERB
# in ADP
# this DET
# election NOUN
# except SCONJ
# for ADP
# one NUM
# thing NOUN
# : PUNCT
# Ann PROPN
# Nixon PROPN
# Cooper PROPN
# is AUX
# 106 NUM
# years NOUN
# old ADJ
# . PUNCT
#
#  SPACE
# She PRON
# was AUX
# born VERB
# just ADV
# a DET
# generation NOUN
# past ADJ
# slavery NOUN
# ; PUNCT
# a DET
# time NOUN
# when SCONJ
# there PRON
# were VERB
# no DET
# cars NOUN
# on ADP
# the DET
# road NOUN
# or CCONJ
# planes NOUN
# in ADP
# the DET
# sky NOUN
# ; PUNCT
# when SCONJ
# someone PRON
# like ADP
# her PRON
# could AUX
# n’t PART
# vote VERB
# for ADP
# two NUM
# reasons NOUN
# — PUNCT
# because SCONJ
# she PRON
# was AUX
# a DET
# woman NOUN
# and CCONJ
# because SCONJ
# of ADP
# the DET
# color NOUN
# of ADP
# her PRON
# skin NOUN
# . PUNCT
#
#  SPACE
# And CCONJ
# tonight NOUN
# , PUNCT
# I PRON
# think VERB
# about ADP
# all PRON
# that PRON
# she PRON
# ’s AUX
# seen VERB
# throughout ADP
# her PRON
# century NOUN
# in ADP
# America PROPN
# — PUNCT
# the DET
# heartache NOUN
# and CCONJ
# the DET
# hope NOUN
# ; PUNCT
# the DET
# struggle NOUN
# and CCONJ
# the DET
# progress NOUN
# ; PUNCT
# the DET
# times NOUN
# we PRON
# were AUX
# told VERB
# that SCONJ
# we PRON
# ca AUX
# n’t NOUN
# , PUNCT
# and CCONJ
# the DET
# people NOUN
# who PRON
# pressed VERB
# on ADP
# with ADP
# that DET
# American ADJ
# creed NOUN
# : PUNCT
# Yes INTJ
# we PRON
# can AUX
# . PUNCT
#
#  SPACE
# At ADP
# a DET
# time NOUN
# when SCONJ
# women NOUN
# ’s PART
# voices NOUN
# were AUX
# silenced VERB
# and CCONJ
# their PRON
# hopes NOUN
# dismissed VERB
# , PUNCT
# she PRON
# lived VERB
# to PART
# see VERB
# them PRON
# stand VERB
# up ADP
# and CCONJ
# speak VERB
# out ADP
# and CCONJ
# reach VERB
# for ADP
# the DET
# ballot NOUN
# . PUNCT
# Yes INTJ
# we PRON
# can AUX
# . PUNCT
#
#  SPACE
# When SCONJ
# there PRON
# was VERB
# despair NOUN
# in ADP
# the DET
# dust NOUN
# bowl NOUN
# and CCONJ
# depression NOUN
# across ADP
# the DET
# land NOUN
# , PUNCT
# she PRON
# saw VERB
# a DET
# nation NOUN
# conquer NOUN
# fear VERB
# itself PRON
# with ADP
# a DET
# New PROPN
# Deal PROPN
# , PUNCT
# new ADJ
# jobs NOUN
# , PUNCT
# a DET
# new ADJ
# sense NOUN
# of ADP
# common ADJ
# purpose NOUN
# . PUNCT
# Yes INTJ
# we PRON
# can AUX
# . PUNCT
#
#  SPACE
# When SCONJ
# the DET
# bombs NOUN
# fell VERB
# on ADP
# our PRON
# harbor NOUN
# and CCONJ
# tyranny NOUN
# threatened VERB
# the DET
# world NOUN
# , PUNCT
# she PRON
# was AUX
# there ADV
# to PART
# witness VERB
# a DET
# generation NOUN
# rise NOUN
# to ADP
# greatness NOUN
# and CCONJ
# a DET
# democracy NOUN
# was AUX
# saved VERB
# . PUNCT
# Yes INTJ
# we PRON
# can AUX
# . PUNCT
#
#  SPACE
# She PRON
# was AUX
# there ADV
# for ADP
# the DET
# buses NOUN
# in ADP
# Montgomery PROPN
# , PUNCT
# the DET
# hoses NOUN
# in ADP
# Birmingham PROPN
# , PUNCT
# a DET
# bridge NOUN
# in ADP
# Selma PROPN
# , PUNCT
# and CCONJ
# a DET
# preacher NOUN
# from ADP
# Atlanta PROPN
# who PRON
# told VERB
# a DET
# people NOUN
# that SCONJ
# “ PUNCT
# We PRON
# Shall AUX
# Overcome VERB
# . PUNCT
# ” PUNCT
# Yes INTJ
# we PRON
# can AUX
# . PUNCT
#
#  SPACE
# A DET
# man NOUN
# touched VERB
# down ADP
# on ADP
# the DET
# moon NOUN
# , PUNCT
# a DET
# wall NOUN
# came VERB
# down ADP
# in ADP
# Berlin PROPN
# , PUNCT
# a DET
# world NOUN
# was AUX
# connected VERB
# by ADP
# our PRON
# own ADJ
# science NOUN
# and CCONJ
# imagination NOUN
# . PUNCT
#
#  SPACE
# And CCONJ
# this DET
# year NOUN
# , PUNCT
# in ADP
# this DET
# election NOUN
# , PUNCT
# she PRON
# touched VERB
# her PRON
# finger NOUN
# to ADP
# a DET
# screen NOUN
# , PUNCT
# and CCONJ
# cast VERB
# her PRON
# vote NOUN
# , PUNCT
# because SCONJ
# after ADP
# 106 NUM
# years NOUN
# in ADP
# America PROPN
# , PUNCT
# through ADP
# the DET
# best ADJ
# of ADP
# times NOUN
# and CCONJ
# the DET
# darkest NOUN
# of ADP
# hours NOUN
# , PUNCT
# she PRON
# knows VERB
# how SCONJ
# America PROPN
# can AUX
# change VERB
# . PUNCT
#
#  SPACE
# Yes INTJ
# we PRON
# can AUX
# . PUNCT
#
#  SPACE
# America PROPN
# , PUNCT
# we PRON
# have AUX
# come VERB
# so ADV
# far ADV
# . PUNCT
# We PRON
# have AUX
# seen VERB
# so ADV
# much ADJ
# . PUNCT
# But CCONJ
# there PRON
# is VERB
# so ADV
# much ADV
# more ADJ
# to PART
# do VERB
# . PUNCT
# So ADV
# tonight NOUN
# , PUNCT
# let VERB
# us PRON
# ask VERB
# ourselves PRON
# — PUNCT
# if SCONJ
# our PRON
# children NOUN
# should AUX
# live VERB
# to PART
# see VERB
# the DET
# next ADJ
# century NOUN
# ; PUNCT
# if SCONJ
# my PRON
# daughters NOUN
# should AUX
# be AUX
# so ADV
# lucky ADJ
# to PART
# live VERB
# as ADV
# long ADV
# as ADP
# Ann PROPN
# Nixon PROPN
# Cooper PROPN
# , PUNCT
# what PRON
# change NOUN
# will AUX
# they PRON
# see VERB
# ? PUNCT
# What DET
# progress NOUN
# will AUX
# we PRON
# have AUX
# made VERB
# ? PUNCT
#
#  SPACE
# This PRON
# is AUX
# our PRON
# chance NOUN
# to PART
# answer VERB
# that DET
# call NOUN
# . PUNCT
# This PRON
# is AUX
# our PRON
# moment NOUN
# . PUNCT
#
#  SPACE
# This PRON
# is AUX
# our PRON
# time NOUN
# , PUNCT
# to PART
# put VERB
# our PRON
# people NOUN
# back ADV
# to ADP
# work NOUN
# and CCONJ
# open ADJ
# doors NOUN
# of ADP
# opportunity NOUN
# for ADP
# our PRON
# kids NOUN
# ; PUNCT
# to PART
# restore VERB
# prosperity NOUN
# and CCONJ
# promote VERB
# the DET
# cause NOUN
# of ADP
# peace NOUN
# ; PUNCT
# to PART
# reclaim VERB
# the DET
# American ADJ
# dream NOUN
# and CCONJ
# reaffirm VERB
# that DET
# fundamental ADJ
# truth NOUN
# , PUNCT
# that SCONJ
# , PUNCT
# out ADP
# of ADP
# many ADJ
# , PUNCT
# we PRON
# are AUX
# one NUM
# ; PUNCT
# that SCONJ
# while SCONJ
# we PRON
# breathe VERB
# , PUNCT
# we PRON
# hope VERB
# . PUNCT
# And CCONJ
# where SCONJ
# we PRON
# are AUX
# met VERB
# with ADP
# cynicism NOUN
# and CCONJ
# doubts NOUN
# and CCONJ
# those PRON
# who PRON
# tell VERB
# us PRON
# that SCONJ
# we PRON
# ca AUX
# n’t PART
# , PUNCT
# we PRON
# will AUX
# respond VERB
# with ADP
# that DET
# timeless NOUN
# creed NOUN
# that PRON
# sums VERB
# up ADP
# the DET
# spirit NOUN
# of ADP
# a DET
# people NOUN
# : PUNCT
# Yes INTJ
# , PUNCT
# we PRON
# can AUX
# . PUNCT
# [ X

# %% [markdown]
# # Parte 2: preguntas

# %% [markdown]
# Para responder a cada una de las preguntas planteadas deberás aportar tanto el código fuente con el cual puedes conseguir la respuesta, como una explicación válida de la respuesta y de la forma de obtenerla.

# %% [markdown]
# <span style="font-size: 14pt; font-weight: bold; color: #0098cd;">Pregunta 1.</span>
# <span style="font-size: 14pt; font-weight: bold; color: #0098cd;">¿Cuántas palabras tiene el texto?</span>

# %%
# Inicializa el contador
contador = 0

# Se itera sobre los tokens del documento
for token in doc:
    # Se comprueba que no es un signo y se añade +1 al contador
    if not token.is_punct:
        contador += 1

print("Número de palabras en el texto:", contador)
# Out:
# Número de palabras en el texto: 1732

# %% [markdown]
# <b>Incluye aquí, debajo de la línea, la explicación de tu respuesta</b>
# <hr>

# %% [markdown]
# Se inicia un contador y a partir de ahí se seleccionan los tokens que no son un signo y se añaden al contador

# %% [markdown]
# <span style="font-size: 14pt; font-weight: bold; color: #0098cd;">Pregunta 2.</span>
# <span style="font-size: 14pt; font-weight: bold; color: #0098cd;">¿Cuántas oraciones tiene el texto?</span>

# %%
# Se inicia otro contador para obtener la cantidad de frases en el texto
contador = 0

# Se itera sobre el texto obteniendo las frases
for _ in doc.sents:
    contador += 1

print("Número de oraciones en el texto:", contador)
# Out:
# Número de oraciones en el texto: 83

# %% [markdown]
# <b>Incluye aquí, debajo de la línea, la explicación de tu respuesta</b>
# <hr>

# %% [markdown]
# Se inicia un contador como el de antes y se itera en el texto sobre todas las frases gracias a la función sents, cada vez que se itera se añade +1 al contador

# %% [markdown]
# <span style="font-size: 14pt; font-weight: bold; color: #0098cd;">Pregunta 3.</span>
# <span style="font-size: 14pt; font-weight: bold; color: #0098cd;">¿Cuál el número de palabras de la oración más grande? ¿Cual es dicha oración?</span>

# %%
# Inicializo el contador de palabras y una variable tipo string vacia
contador = 0
sentencia_mas_larga = ""

# Se itera sobre las oraciones del documento y se obtienen la mas larga
for i in doc.sents:
    numero_palabras = sum(1 for token in i if not token.is_punct)
    if numero_palabras > contador:
        contador = numero_palabras
        sentencia_mas_larga = i.text

print("Oración mas grande ({} palabras):".format(contador))
print(sentencia_mas_larga)
# Out:
# Oración mas grande (61 palabras):
# It drew strength from the not-so-young people who braved the bitter cold and scorching heat to knock on doors of perfect strangers, and from the millions of Americans who volunteered and organized and proved that more than two centuries later a government of the people, by the people, and for the people has not perished from the Earth.

# %% [markdown]
# <b>Incluye aquí, debajo de la línea, la explicación de tu respuesta</b>
# <hr>

# %% [markdown]
# Inicializo un contador de palabras y la variable que albergará la oración más larga. Utilizo un bucle for para recorrer el documento y contar las palabras con el bucle que hemos hecho anteriormente iterando palabras en la frase recorrida. Luego en el output, saco el número de palabras de la frase mas larga y la frase mas larga.

# %% [markdown]
# <span style="font-size: 14pt; font-weight: bold; color: #0098cd;">Pregunta 4.</span>
# <span style="font-size: 14pt; font-weight: bold; color: #0098cd;">¿Cómo puedes obtener el lema, el sufijo y el análisis morfológico de cada token?</span>
#
# Recomendación: si no lo has hecho ya, visita la documentación de la clase <i>Token</i>: https://spacy.io/api/token

# %%
for token in doc:
    print("Token:", token.text)
    print("Lema:", token.lemma_)
    print("Sufijo:", token.suffix_)
    print("Análisis morfológico:", token.morph)

    # Añade un salto de linea en cada token
    print()
# Out:
# Token: “
# Lema: "
# Sufijo: “
# Análisis morfológico: PunctSide=Ini|PunctType=Quot
#
# Token: Hello
# Lema: Hello
# Sufijo: llo
# Análisis morfológico: Number=Sing
#
# Token: ,
# Lema: ,
# Sufijo: ,
# Análisis morfológico: PunctType=Comm
#
# Token: Chicago
# Lema: Chicago
# Sufijo: ago
# Análisis morfológico: Number=Sing
#
# Token: .
# Lema: .
# Sufijo: .
# Análisis morfológico: PunctType=Peri
#
# Token:
#
# Lema:
#
# Sufijo:
#
# Análisis morfológico:
#
# Token: If
# Lema: if
# Sufijo: If
# Análisis morfológico:
#
# Token: there
# Lema: there
# Sufijo: ere
# Análisis morfológico:
#
# Token: is
# Lema: be
# Sufijo: is
# Análisis morfológico: Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
#
# Token: anyone
# Lema: anyone
# Sufijo: one
# Análisis morfológico: Number=Sing|PronType=Ind
#
# Token: out
# Lema: out
# Sufijo: out
# Análisis morfológico:
#
# Token: there
# Lema: there
# Sufijo: ere
# Análisis morfológico: PronType=Dem
#
# Token: who
# Lema: who
# Sufijo: who
# Análisis morfológico:
#
# Token: still
# Lema: still
# Sufijo: ill
# Análisis morfológico:
#
# Token: doubts
# Lema: doubt
# Sufijo: bts
# Análisis morfológico: Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
#
# Token: that
# Lema: that
# Sufijo: hat
# Análisis morfológico:
#
# Token: America
# Lema: America
# Sufijo: ica
# Análisis morfológico: Number=Sing
#
# Token: is
# Lema: be
# Sufijo: is
# Análisis morfológico: Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
#
# Token: a
# Lema: a
# Sufijo: a
# Análisis morfológico: Definite=Ind|PronType=Art
#
# Token: place
# Lema: place
# Sufijo: ace
# Análisis morfológico: Number=Sing
#
# Token: where
# Lema: where
# Sufijo: ere
# Análisis morfológico:
#
# Token: all
# Lema: all
# Sufijo: all
# Análisis morfológico:
#
# Token: things
# Lema: thing
# Sufijo: ngs
# Análisis morfológico: Number=Plur
#
# Token: are
# Lema: be
# Sufijo: are
# Análisis morfológico: Mood=Ind|Tense=Pres|VerbForm=Fin
#
# Token: possible
# Lema: possible
# Sufijo: ble
# Análisis morfológico: Degree=Pos
#
# Token: ,
# Lema: ,
# Sufijo: ,
# Análisis morfológico: PunctType=Comm
#
# Token: who
# Lema: who
# Sufijo: who
# Análisis morfológico:
#
# Token: still
# Lema: still
# Sufijo: ill
# Análisis morfológico:
#
# Token: wonders
# Lema: wonder
# Sufijo: ers
# Análisis morfológico: Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
#
# Token: if
# Lema: if
# Sufijo: if
# Análisis morfológico:
#
# Token: the
# Lema: the
# Sufijo: the
# Análisis morfológico: Definite=Def|PronType=Art
#
# Token: dream
# Lema: dream
# Sufijo: eam
# Análisis morfológico: Number=Sing
#
# Token: of
# Lema: of
# Sufijo: of
# Análisis morfológico:
#
# Token: our
# Lema: our
# Sufijo: our
# Análisis morfológico: Number=Plur|Person=1|Poss=Yes|PronType=Prs
#
# Token: founders
# Lema: founder
# Sufijo: ers
# Análisis morfológico: Number=Plur
#
# Token: is
# Lema: be
# Sufijo: is
# Análisis morfológico: Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
#
# Token: alive
# Lema: alive
# Sufijo: ive
# Análisis morfológico: Degree=Pos
#
# Token: in
# Lema: in
# Sufijo: in
# Análisis morfológico:
#
# Token: our
# Lema: our
# Sufijo: our
# Análisis morfológico: Number=Plur|Person=1|Poss=Yes|PronType=Prs
#
# Token: time
# Lema: time
# Sufijo: ime
# Análisis morfológico: Number=Sing
#
# Token: ,
# Lema: ,
# Sufijo: ,
# Análisis morfológico: PunctType=Comm
#
# Token: who
# Lema: who
# Sufijo: who
# Análisis morfológico:
#
# Token: still
# Lema: still
# Sufijo: ill
# Análisis morfológico:
#
# Token: questions
# Lema: question
# Sufijo: ons
# Análisis morfológico: Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
#
# Token: the
# Lema: the
# Sufijo: the
# Análisis morfológico: Definite=Def|PronType=Art
#
# Token: power
# Lema: power
# Sufijo: wer
# Análisis morfológico: Number=Sing
#
# Token: of
# Lema: of
# Sufijo: of
# Análisis morfológico:
#
# Token: our
# Lema: our
# Sufijo: our
# Análisis morfológico: Number=Plur|Person=1|Poss=Yes|PronType=Prs
#
# Token: democracy
# Lema: democracy
# Sufijo: acy
# Análisis morfológico: Number=Sing
#
# Token: ,
# Lema: ,
# Sufijo: ,
# Análisis morfológico: PunctType=Comm
#
# Token: tonight
# Lema: tonight
# Sufijo: ght
# Análisis morfológico: Number=Sing
#
# Token: is
# Lema: be
# Sufijo: is
# Análisis morfológico: Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
#
# Token: your
# Lema: your
# Sufijo: our
# Análisis morfológico: Person=2|Poss=Yes|PronType=Prs
#
# Token: answer
# Lema: answer
# Sufijo: wer
# Análisis morfológico: Number=Sing
#
# Token: .
# Lema: .
# Sufijo: .
# Análisis morfológico: PunctType=Peri
#
# Token:
#
# Lema:
#
# Sufijo:
#
# Análisis morfológico:
#
# Token: It
# Lema: it
# Sufijo: It
# Análisis morfológico: Case=Nom|Gender=Neut|Number=Sing|Person=3|PronType=Prs
#
# Token: ’s
# Lema: ’
# Sufijo: ’s
# Análisis morfológico: Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
#
# Token: the
# Lema: the
# Sufijo: the
# Análisis morfológico: Definite=Def|PronType=Art
#
# Token: answer
# Lema: answer
# Sufijo: wer
# Análisis morfológico: Number=Sing
#
# Token: told
# Lema: tell
# Sufijo: old
# Análisis morfológico: Aspect=Perf|Tense=Past|VerbForm=Part
#
# Token: by
# Lema: by
# Sufijo: by
# Análisis morfológico:
#
# Token: lines
# Lema: line
# Sufijo: nes
# Análisis morfológico: Number=Plur
#
# Token: that
# Lema: that
# Sufijo: hat
# Análisis morfológico: PronType=Rel
#
# Token: stretched
# Lema: stretch
# Sufijo: hed
# Análisis morfológico: Tense=Past|VerbForm=Fin
#
# Token: around
# Lema: around
# Sufijo: und
# Análisis morfológico:
#
# Token: schools
# Lema: school
# Sufijo: ols
# Análisis morfológico: Number=Plur
#
# Token: and
# Lema: and
# Sufijo: and
# Análisis morfológico: ConjType=Cmp
#
# Token: churches
# Lema: church
# Sufijo: hes
# Análisis morfológico: Number=Plur
#
# Token: in
# Lema: in
# Sufijo: in
# Análisis morfológico:
#
# Token: numbers
# Lema: number
# Sufijo: ers
# Análisis morfológico: Number=Plur
#
# Token: this
# Lema: this
# Sufijo: his
# Análisis morfológico: Number=Sing|PronType=Dem
#
# Token: nation
# Lema: nation
# Sufijo: ion
# Análisis morfológico: Number=Sing
#
# Token: has
# Lema: have
# Sufijo: has
# Análisis morfológico: Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
#
# Token: never
# Lema: never
# Sufijo: ver
# Análisis morfológico:
#
# Token: seen
# Lema: see
# Sufijo: een
# Análisis morfológico: Aspect=Perf|Tense=Past|VerbForm=Part
#
# Token: ,
# Lema: ,
# Sufijo: ,
# Análisis morfológico: PunctType=Comm
#
# Token: by
# Lema: by
# Sufijo: by
# Análisis morfológico:
#
# Token: people
# Lema: people
# Sufijo: ple
# Análisis morfológico: Number=Plur
#
# Token: who
# Lema: who
# Sufijo: who
# Análisis morfológico:
#
# Token: waited
# Lema: wait
# Sufijo: ted
# Análisis morfológico: Tense=Past|VerbForm=Fin
#
# Token: three
# Lema: three
# Sufijo: ree
# Análisis morfológico: NumType=Card
#
# Token: hours
# Lema: hour
# Sufijo: urs
# Análisis morfológico: Number=Plur
#
# Token: and
# Lema: and
# Sufijo: and
# Análisis morfológico: ConjType=Cmp
#
# Token: four
# Lema: four
# Sufijo: our
# Análisis morfológico: NumType=Card
#
# Token: hours
# Lema: hour
# Sufijo: urs
# Análisis morfológico: Number=Plur
#
# Token: ,
# Lema: ,
# Sufijo: ,
# Análisis morfológico: PunctType=Comm
#
# Token: many
# Lema: many
# Sufijo: any
# Análisis morfológico: Degree=Pos
#
# Token: for
# Lema: for
# Sufijo: for
# Análisis morfológico:
#
# Token: the
# Lema: the
# Sufijo: the
# Análisis morfológico: Definite=Def|PronType=Art
#
# Token: first
# Lema: first
# Sufijo: rst
# Análisis morfológico: Degree=Pos
#
# Token: time
# Lema: time
# Sufijo: ime
# Análisis morfológico: Number=Sing
#
# Token: in
# Lema: in
# Sufijo: in
# Análisis morfológico:
#
# Token: their
# Lema: their
# Sufijo: eir
# Análisis morfológico: Number=Plur|Person=3|Poss=Yes|PronType=Prs
#
# Token: lives
# Lema: life
# Sufijo: ves
# Análisis morfológico: Number=Plur
#
# Token: ,
# Lema: ,
# Sufijo: ,
# Análisis morfológico: PunctType=Comm
#
# Token: because
# Lema: because
# Sufijo: use
# Análisis morfológico:
#
# Token: they
# Lema: they
# Sufijo: hey
# Análisis morfológico: Case=Nom|Number=Plur|Person=3|PronType=Prs
#
# Token: believed
# Lema: believe
# Sufijo: ved
# Análisis morfológico: Tense=Past|VerbForm=Fin
#
# Token: that
# Lema: that
# Sufijo: hat
# Análisis morfológico:
#
# Token: this
# Lema: this
# Sufijo: his
# Análisis morfológico: Number=Sing|PronType=Dem
#
# Token: time
# Lema: time
# Sufijo: ime
# Análisis morfológico: Number=Sing
#
# Token: must
# Lema: must
# Sufijo: ust
# Análisis morfológico: VerbForm=Fin
#
# Token: be
# Lema: be
# Sufijo: be
# Análisis morfológico: VerbForm=Inf
#
# Token: different
# Lema: different
# Sufijo: ent
# Análisis morfológico: Degree=Pos
#
# Token: ,
# Lema: ,
# Sufijo: ,
# Análisis morfológico: PunctType=Comm
#
# Token: that
# Lema: that
# Sufijo: hat
# Análisis morfológico:
#
# Token: their
# Lema: their
# Sufijo: eir
# Análisis morfológico: Number=Plur|Person=3|Poss=Yes|PronType=Prs
#
# Token: voices
# Lema: voice
# Sufijo: ces
# Análisis morfológico: Number=Plur
#
# Token: could
# Lema: could
# Sufijo: uld
# Análisis morfológico: VerbForm=Fin
#
# Token: be
# Lema: be
# Sufijo: be
# Análisis morfológico: VerbForm=Inf
#
# Token: that
# Lema: that
# Sufijo: hat
# Análisis morfológico: Number=Sing|PronType=Dem
#
# Token: difference
# Lema: difference
# Sufijo: nce
# Análisis morfológico: Number=Sing
#
# Token: .
# Lema: .
# Sufijo: .
# Análisis morfológico: PunctType=Peri
#
# Token:
#
# Lema:
#
# Sufijo:
#
# Análisis morfológico:
#
# Token: It
# Lema: it
# Sufijo: It
# Análisis morfológico: Case=Nom|Gender=Neut|Number=Sing|Person=3|PronType=Prs
#
# Token: ’s
# Lema: ’
# Sufijo: ’s
# Análisis morfológico: Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
#
# Token: the
# Lema: the
# Sufijo: the
# Análisis morfológico: Definite=Def|PronType=Art
#
# Token: answer
# Lema: answer
# Sufijo: wer
# Análisis morfológico: Number=Sing
#
# Token: spoken
# Lema: speak
# Sufijo: ken
# Análisis morfológico: Aspect=Perf|Tense=Past|VerbForm=Part
#
# Token: by
# Lema: by
# Sufijo: by
# Análisis morfológico:
#
# Token: young
# Lema: young
# Sufijo: ung
# Análisis morfológico: Degree=Pos
#
# Token: and
# Lema: and
# Sufijo: and
# Análisis morfológico: ConjType=Cmp
#
# Token: old
# Lema: old
# Sufijo: old
# Análisis morfológico: Degree=Pos
#
# Token: ,
# Lema: ,
# Sufijo: ,
# Análisis morfológico: PunctType=Comm
#
# Token: rich
# Lema: rich
# Sufijo: ich
# Análisis morfológico: Degree=Pos
#
# Token: and
# Lema: and
# Sufijo: and
# Análisis morfológico: ConjType=Cmp
#
# Token: poor
# Lema: poor
# Sufijo: oor
# Análisis morfológico: Degree=Pos
#
# Token: ,
# Lema: ,
# Sufijo: ,
# Análisis morfológico: PunctType=Comm
#
# Token: Democrat
# Lema: Democrat
# Sufijo: rat
# Análisis morfológico: Number=Sing
#
# Token: and
# Lema: and
# Sufijo: and
# Análisis morfológico: ConjType=Cmp
#
# Token: Republican
# Lema: Republican
# Sufijo: can
# Análisis morfológico: Number=Sing
#
# Token: ,
# Lema: ,
# Sufijo: ,
# Análisis morfológico: PunctType=Comm
#
# Token: black
# Lema: black
# Sufijo: ack
# Análisis morfológico: Degree=Pos
#
# Token: ,
# Lema: ,
# Sufijo: ,
# Análisis morfológico: PunctType=Comm
#
# Token: white
# Lema: white
# Sufijo: ite
# Análisis morfológico: Degree=Pos
#
# Token: ,
# Lema: ,
# Sufijo: ,
# Análisis morfológico: PunctType=Comm
#
# Token: Hispanic
# Lema: hispanic
# Sufijo: nic
# Análisis morfológico: Degree=Pos
#
# Token: ,
# Lema: ,
# Sufijo: ,
# Análisis morfológico: PunctType=Comm
#
# Token: Asian
# Lema: asian
# Sufijo: ian
# Análisis morfológico: Degree=Pos
#
# Token: ,
# Lema: ,
# Sufijo: ,
# Análisis morfológico: PunctType=Comm
#
# Token: Native
# Lema: Native
# Sufijo: ive
# Análisis morfológico: Number=Sing
#
# Token: American
# Lema: American
# Sufijo: can
# Análisis morfológico: Number=Sing
#
# Token: ,
# Lema: ,
# Sufijo: ,
# Análisis morfológico: PunctType=Comm
#
# Token: gay
# Lema: gay
# Sufijo: gay
# Análisis morfológico: Degree=Pos
#
# Token: ,
# Lema: ,
# Sufijo: ,
# Análisis morfológico: PunctType=Comm
#
# Token: straight
# Lema: straight
# Sufijo: ght
# Análisis morfológico: Degree=Pos
#
# Token: ,
# Lema: ,
# Sufijo: ,
# Análisis morfológico: PunctType=Comm
#
# Token: disabled
# Lema: disabled
# Sufijo: led
# Análisis morfológico: Degree=Pos
#
# Token: and
# Lema: and
# Sufijo: and
# Análisis morfológico: ConjType=Cmp
#
# Token: not
# Lema: not
# Sufijo: not
# Análisis morfológico: Polarity=Neg
#
# Token: disabled
# Lema: disabled
# Sufijo: led
# Análisis morfológico: Degree=Pos
#
# Token: .
# Lema: .
# Sufijo: .
# Análisis morfológico: PunctType=Peri
#
# Token: Americans
# Lema: american
# Sufijo: ans
# Análisis morfológico: Number=Plur
#
# Token: who
# Lema: who
# Sufijo: who
# Análisis morfológico:
#
# Token: sent
# Lema: send
# Sufijo: ent
# Análisis morfológico: Tense=Past|VerbForm=Fin
#
# Token: a
# Lema: a
# Sufijo: a
# Análisis morfológico: Definite=Ind|PronType=Art
#
# Token: message
# Lema: message
# Sufijo: age
# Análisis morfológico: Number=Sing
#
# Token: to
# Lema: to
# Sufijo: to
# Análisis morfológico:
#
# Token: the
# Lema: the
# Sufijo: the
# Análisis morfológico: Definite=Def|PronType=Art
#
# Token: world
# Lema: world
# Sufijo: rld
# Análisis morfológico: Number=Sing
#
# Token: that
# Lema: that
# Sufijo: hat
# Análisis morfológico:
#
# Token: we
# Lema: we
# Sufijo: we
# Análisis morfológico: Case=Nom|Number=Plur|Person=1|PronType=Prs
#
# Token: have
# Lema: have
# Sufijo: ave
# Análisis morfológico: Mood=Ind|Tense=Pres|VerbForm=Fin
#
# Token: never
# Lema: never
# Sufijo: ver
# Análisis morfológico:
#
# Token: been
# Lema: be
# Sufijo: een
# Análisis morfológico: Tense=Past|VerbForm=Part
#
# Token: just
# Lema: just
# Sufijo: ust
# Análisis morfológico:
#
# Token: a
# Lema: a
# Sufijo: a
# Análisis morfológico: Definite=Ind|PronType=Art
#
# Token: collection
# Lema: collection
# Sufijo: ion
# Análisis morfológico: Number=Sing
#
# Token: of
# Lema: of
# Sufijo: of
# Análisis morfológico:
#
# Token: individuals
# Lema: individual
# Sufijo: als
# Análisis morfológico: Number=Plur
#
# Token: or
# Lema: or
# Sufijo: or
# Análisis morfológico: ConjType=Cmp
#
# Token: a
# Lema: a
# Sufijo: a
# Análisis morfológico: Definite=Ind|PronType=Art
#
# Token: collection
# Lema: collection
# Sufijo: ion
# Análisis morfológico: Number=Sing
#
# Token: of
# Lema: of
# Sufijo: of
# Análisis morfológico:
#
# Token: red
# Lema: red
# Sufijo: red
# Análisis morfológico: Degree=Pos
#
# Token: states
# Lema: state
# Sufijo: tes
# Análisis morfológico: Number=Plur
#
# Token: and
# Lema: and
# Sufijo: and
# Análisis morfológico: ConjType=Cmp
#
# Token: blue
# Lema: blue
# Sufijo: lue
# Análisis morfológico: Degree=Pos
#
# Token: states
# Lema: state
# Sufijo: tes
# Análisis morfológico: Number=Plur
#
# Token: .
# Lema: .
# Sufijo: .
# Análisis morfológico: PunctType=Peri
#
# Token:
#
# Lema:
#
# Sufijo:
#
# Análisis morfológico:
#
# Token: We
# Lema: we
# Sufijo: We
# Análisis morfológico: Case=Nom|Number=Plur|Person=1|PronType=Prs
#
# Token: are
# Lema: be
# Sufijo: are
# Análisis morfológico: Mood=Ind|Tense=Pres|VerbForm=Fin
#
# Token: ,
# Lema: ,
# Sufijo: ,
# Análisis morfológico: PunctType=Comm
#
# Token: and
# Lema: and
# Sufijo: and
# Análisis morfológico: ConjType=Cmp
#
# Token: always
# Lema: always
# Sufijo: ays
# Análisis morfológico:
#
# Token: will
# Lema: will
# Sufijo: ill
# Análisis morfológico: VerbForm=Fin
#
# Token: be
# Lema: be
# Sufijo: be
# Análisis morfológico: VerbForm=Inf
#
# Token: ,
# Lema: ,
# Sufijo: ,
# Análisis morfológico: PunctType=Comm
#
# Token: the
# Lema: the
# Sufijo: the
# Análisis morfológico: Definite=Def|PronType=Art
#
# Token: United
# Lema: United
# Sufijo: ted
# Análisis morfológico: Number=Sing
#
# Token: States
# Lema: States
# Sufijo: tes
# Análisis morfológico: Number=Sing
#
# Token: of
# Lema: of
# Sufijo: of
# Análisis morfológico:
#
# Token: America
# Lema: America
# Sufijo: ica
# Análisis morfológico: Number=Sing
#
# Token: .
# Lema: .
# Sufijo: .
# Análisis morfológico: PunctType=Peri
#
# Token:
#
# Lema:
#
# Sufijo:
#
# Análisis morfológico:
#
# Token: It
# Lema: it
# Sufijo: It
# Análisis morfológico: Case=Nom|Gender=Neut|Number=Sing|Person=3|PronType=Prs
#
# Token: ’s
# Lema: ’
# Sufijo: ’s
# Análisis morfológico: Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
#
# Token: the
# Lema: the
# Sufijo: the
# Análisis morfológico: Definite=Def|PronType=Art
#
# Token: answer
# Lema: answer
# Sufijo: wer
# Análisis morfológico: Number=Sing
#
# Token: that
# Lema: that
# Sufijo: hat
# Análisis morfológico: PronType=Rel
#
# Token: led
# Lema: lead
# Sufijo: led
# Análisis morfológico: Tense=Past|VerbForm=Fin
#
# Token: those
# Lema: those
# Sufijo: ose
# Análisis morfológico: Number=Plur|PronType=Dem
#
# Token: who
# Lema: who
# Sufijo: who
# Análisis morfológico:
#
# Token: ’ve
# Lema: ’ve
# Sufijo: ’ve
# Análisis morfológico: Tense=Pres|VerbForm=Fin
#
# Token: been
# Lema: been
# Sufijo: een
# Análisis morfológico: Tense=Past|VerbForm=Fin
#
# Token: told
# Lema: tell
# Sufijo: old
# Análisis morfológico: Aspect=Perf|Tense=Past|VerbForm=Part
#
# Token: for
# Lema: for
# Sufijo: for
# Análisis morfológico:
#
# Token: so
# Lema: so
# Sufijo: so
# Análisis morfológico:
#
# Token: long
# Lema: long
# Sufijo: ong
# Análisis morfológico:
#
# Token: by
# Lema: by
# Sufijo: by
# Análisis morfológico:
#
# Token: so
# Lema: so
# Sufijo: so
# Análisis morfológico:
#
# Token: many
# Lema: many
# Sufijo: any
# Análisis morfológico: Degree=Pos
#
# Token: to
# Lema: to
# Sufijo: to
# Análisis morfológico:
#
# Token: be
# Lema: be
# Sufijo: be
# Análisis morfológico: VerbForm=Inf
#
# Token: cynical
# Lema: cynical
# Sufijo: cal
# Análisis morfológico: Degree=Pos
#
# Token: and
# Lema: and
# Sufijo: and
# Análisis morfológico: ConjType=Cmp
#
# Token: fearful
# Lema: fearful
# Sufijo: ful
# Análisis morfológico: Degree=Pos
#
# Token: and
# Lema: and
# Sufijo: and
# Análisis morfológico: ConjType=Cmp
#
# Token: doubtful
# Lema: doubtful
# Sufijo: ful
# Análisis morfológico: Degree=Pos
#
# Token: about
# Lema: about
# Sufijo: out
# Análisis morfológico:
#
# Token: what
# Lema: what
# Sufijo: hat
# Análisis morfológico:
#
# Token: we
# Lema: we
# Sufijo: we
# Análisis morfológico: Case=Nom|Number=Plur|Person=1|PronType=Prs
#
# Token: can
# Lema: can
# Sufijo: can
# Análisis morfológico: VerbForm=Fin
#
# Token: achieve
# Lema: achieve
# Sufijo: eve
# Análisis morfológico: VerbForm=Inf
#
# Token: to
# Lema: to
# Sufijo: to
# Análisis morfológico:
#
# Token: put
# Lema: put
# Sufijo: put
# Análisis morfológico: VerbForm=Inf
#
# Token: their
# Lema: their
# Sufijo: eir
# Análisis morfológico: Number=Plur|Person=3|Poss=Yes|PronType=Prs
#
# Token: hands
# Lema: hand
# Sufijo: nds
# Análisis morfológico: Number=Plur
#
# Token: on
# Lema: on
# Sufijo: on
# Análisis morfológico:
#
# Token: the
# Lema: the
# Sufijo: the
# Análisis morfológico: Definite=Def|PronType=Art
#
# Token: arc
# Lema: arc
# Sufijo: arc
# Análisis morfológico: Number=Sing
#
# Token: of
# Lema: of
# Sufijo: of
# Análisis morfológico:
#
# Token: history
# Lema: history
# Sufijo: ory
# Análisis morfológico: Number=Sing
#
# Token: and
# Lema: and
# Sufijo: and
# Análisis morfológico: ConjType=Cmp
#
# Token: bend
# Lema: bend
# Sufijo: end
# Análisis morfológico: VerbForm=Inf
#
# Token: it
# Lema: it
# Sufijo: it
# Análisis morfológico: Case=Acc|Gender=Neut|Number=Sing|Person=3|PronType=Prs
#
# Token: once
# Lema: once
# Sufijo: nce
# Análisis morfológico: NumType=Mult
#
# Token: more
# Lema: more
# Sufijo: ore
# Análisis morfológico: Degree=Cmp
#
# Token: toward
# Lema: toward
# Sufijo: ard
# Análisis morfológico:
#
# Token: the
# Lema: the
# Sufijo: the
# Análisis morfológico: Definite=Def|PronType=Art
#
# Token: hope
# Lema: hope
# Sufijo: ope
# Análisis morfológico: Number=Sing
#
# Token: of
# Lema: of
# Sufijo: of
# Análisis morfológico:
#
# Token: a
# Lema: a
# Sufijo: a
# Análisis morfológico: Definite=Ind|PronType=Art
#
# Token: better
# Lema: well
# Sufijo: ter
# Análisis morfológico: Degree=Cmp
#
# Token: day
# Lema: day
# Sufijo: day
# Análisis morfológico: Number=Sing
#
# Token: .
# Lema: .
# Sufijo: .
# Análisis morfológico: PunctType=Peri
#
# Token:
#
# Lema:
#
# Sufijo:
#
# Análisis morfológico:
#
# Token: It
# Lema: it
# Sufijo: It
# Análisis morfológico: Gender=Neut|Number=Sing|Person=3|PronType=Prs
#
# Token: ’s
# Lema: ’s
# Sufijo: ’s
# Análisis morfológico: Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
#
# Token: been
# Lema: be
# Sufijo: een
# Análisis morfológico: Tense=Past|VerbForm=Part
#
# Token: a
# Lema: a
# Sufijo: a
# Análisis morfológico: Definite=Ind|PronType=Art
#
# Token: long
# Lema: long
# Sufijo: ong
# Análisis morfológico: Degree=Pos
#
# Token: time
# Lema: time
# Sufijo: ime
# Análisis morfológico: Number=Sing
#
# Token: coming
# Lema: come
# Sufijo: ing
# Análisis morfológico: Aspect=Prog|Tense=Pres|VerbForm=Part
#
# Token: ,
# Lema: ,
# Sufijo: ,
# Análisis morfológico: PunctType=Comm
#
# Token: but
# Lema: but
# Sufijo: but
# Análisis morfológico: ConjType=Cmp
#
# Token: tonight
# Lema: tonight
# Sufijo: ght
# Análisis morfológico: Number=Sing
#
# Token: ,
# Lema: ,
# Sufijo: ,
# Análisis morfológico: PunctType=Comm
#
# Token: because
# Lema: because
# Sufijo: use
# Análisis morfológico:
#
# Token: of
# Lema: of
# Sufijo: of
# Análisis morfológico:
#
# Token: what
# Lema: what
# Sufijo: hat
# Análisis morfológico:
#
# Token: we
# Lema: we
# Sufijo: we
# Análisis morfológico: Case=Nom|Number=Plur|Person=1|PronType=Prs
#
# Token: did
# Lema: do
# Sufijo: did
# Análisis morfológico: Tense=Past|VerbForm=Fin
#
# Token: on
# Lema: on
# Sufijo: on
# Análisis morfológico:
#
# Token: this
# Lema: this
# Sufijo: his
# Análisis morfológico: Number=Sing|PronType=Dem
#
# Token: date
# Lema: date
# Sufijo: ate
# Análisis morfológico: Number=Sing
#
# Token: in
# Lema: in
# Sufijo: in
# Análisis morfológico:
#
# Token: this
# Lema: this
# Sufijo: his
# Análisis morfológico: Number=Sing|PronType=Dem
#
# Token: election
# Lema: election
# Sufijo: ion
# Análisis morfológico: Number=Sing
#
# Token: at
# Lema: at
# Sufijo: at
# Análisis morfológico:
#
# Token: this
# Lema: this
# Sufijo: his
# Análisis morfológico: Number=Sing|PronType=Dem
#
# Token: defining
# Lema: define
# Sufijo: ing
# Análisis morfológico: Aspect=Prog|Tense=Pres|VerbForm=Part
#
# Token: moment
# Lema: moment
# Sufijo: ent
# Análisis morfológico: Number=Sing
#
# Token: change
# Lema: change
# Sufijo: nge
# Análisis morfológico: Number=Sing
#
# Token: has
# Lema: have
# Sufijo: has
# Análisis morfológico: Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
#
# Token: come
# Lema: come
# Sufijo: ome
# Análisis morfológico: Aspect=Perf|Tense=Past|VerbForm=Part
#
# Token: to
# Lema: to
# Sufijo: to
# Análisis morfológico:
#
# Token: America
# Lema: America
# Sufijo: ica
# Análisis morfológico: Number=Sing
#
# Token: .
# Lema: .
# Sufijo: .
# Análisis morfológico: PunctType=Peri
#
# Token:
#
# Lema:
#
# Sufijo:
#
# Análisis morfológico:
#
# Token: [
# Lema: [
# Sufijo: [
# Análisis morfológico: PunctSide=Ini|PunctType=Brck
#
# Token: read
# Lema: read
# Sufijo: ead
# Análisis morfológico: VerbForm=Inf
#
# Token: more
# Lema: more
# Sufijo: ore
# Análisis morfológico: Degree=Cmp
#
# Token: ]
# Lema: ]
# Sufijo: ]
# Análisis morfológico: PunctSide=Fin|PunctType=Brck
#
# Token:
#
#
# Lema:
#
#
# Sufijo:
#
#
# Análisis morfológico:
#
# Token: We
# Lema: we
# Sufijo: We
# Análisis morfológico: Case=Nom|Number=Plur|Person=1|PronType=Prs
#
# Token: did
# Lema: do
# Sufijo: did
# Análisis morfológico: Tense=Past|VerbForm=Fin
#
# Token: n’t
# Lema: not
# Sufijo: n’t
# Análisis morfológico: Polarity=Neg
#
# Token: start
# Lema: start
# Sufijo: art
# Análisis morfológico: VerbForm=Inf
#
# Token: with
# Lema: with
# Sufijo: ith
# Análisis morfológico:
#
# Token: much
# Lema: much
# Sufijo: uch
# Análisis morfológico: Degree=Pos
#
# Token: money
# Lema: money
# Sufijo: ney
# Análisis morfológico: Number=Sing
#
# Token: or
# Lema: or
# Sufijo: or
# Análisis morfológico: ConjType=Cmp
#
# Token: many
# Lema: many
# Sufijo: any
# Análisis morfológico: Degree=Pos
#
# Token: endorsements
# Lema: endorsement
# Sufijo: nts
# Análisis morfológico: Number=Plur
#
# Token: .
# Lema: .
# Sufijo: .
# Análisis morfológico: PunctType=Peri
#
# Token: Our
# Lema: our
# Sufijo: Our
# Análisis morfológico: Number=Plur|Person=1|Poss=Yes|PronType=Prs
#
# Token: campaign
# Lema: campaign
# Sufijo: ign
# Análisis morfológico: Number=Sing
#
# Token: was
# Lema: be
# Sufijo: was
# Análisis morfológico: Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin
#
# Token: not
# Lema: not
# Sufijo: not
# Análisis morfológico: Polarity=Neg
#
# Token: hatched
# Lema: hatch
# Sufijo: hed
# Análisis morfológico: Aspect=Perf|Tense=Past|VerbForm=Part
#
# Token: in
# Lema: in
# Sufijo: in
# Análisis morfológico:
#
# Token: the
# Lema: the
# Sufijo: the
# Análisis morfológico: Definite=Def|PronType=Art
#
# Token: halls
# Lema: hall
# Sufijo: lls
# Análisis morfológico: Number=Plur
#
# Token: of
# Lema: of
# Sufijo: of
# Análisis morfológico:
#
# Token: Washington
# Lema: Washington
# Sufijo: ton
# Análisis morfológico: Number=Sing
#
# Token: .
# Lema: .
# Sufijo: .
# Análisis morfológico: PunctType=Peri
#
# Token: It
# Lema: it
# Sufijo: It
# Análisis morfológico: Case=Nom|Gender=Neut|Number=Sing|Person=3|PronType=Prs
#
# Token: began
# Lema: begin
# Sufijo: gan
# Análisis morfológico: Tense=Past|VerbForm=Fin
#
# Token: in
# Lema: in
# Sufijo: in
# Análisis morfológico:
#
# Token: the
# Lema: the
# Sufijo: the
# Análisis morfológico: Definite=Def|PronType=Art
#
# Token: backyards
# Lema: backyard
# Sufijo: rds
# Análisis morfológico: Number=Plur
#
# Token: of
# Lema: of
# Sufijo: of
# Análisis morfológico:
#
# Token: Des
# Lema: Des
# Sufijo: Des
# Análisis morfológico: Number=Sing
#
# Token: Moines
# Lema: Moines
# Sufijo: nes
# Análisis morfológico: Number=Sing
#
# Token: and
# Lema: and
# Sufijo: and
# Análisis morfológico: ConjType=Cmp
#
# Token: the
# Lema: the
# Sufijo: the
# Análisis morfológico: Definite=Def|PronType=Art
#
# Token: living
# Lema: live
# Sufijo: ing
# Análisis morfológico: Aspect=Prog|Tense=Pres|VerbForm=Part
#
# Token: rooms
# Lema: room
# Sufijo: oms
# Análisis morfológico: Number=Plur
#
# Token: of
# Lema: of
# Sufijo: of
# Análisis morfológico:
#
# Token: Concord
# Lema: Concord
# Sufijo: ord
# Análisis morfológico: Number=Sing
#
# Token: and
# Lema: and
# Sufijo: and
# Análisis morfológico: ConjType=Cmp
#
# Token: the
# Lema: the
# Sufijo: the
# Análisis morfológico: Definite=Def|PronType=Art
#
# Token: front
# Lema: front
# Sufijo: ont
# Análisis morfológico: Degree=Pos
#
# Token: porches
# Lema: porch
# Sufijo: hes
# Análisis morfológico: Number=Plur
#
# Token: of
# Lema: of
# Sufijo: of
# Análisis morfológico:
#
# Token: Charleston
# Lema: Charleston
# Sufijo: ton
# Análisis morfológico: Number=Sing
#
# Token: .
# Lema: .
# Sufijo: .
# Análisis morfológico: PunctType=Peri
#
# Token: It
# Lema: it
# Sufijo: It
# Análisis morfológico: Gender=Neut|Number=Sing|Person=3|PronType=Prs
#
# Token: was
# Lema: be
# Sufijo: was
# Análisis morfológico: Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin
#
# Token: built
# Lema: build
# Sufijo: ilt
# Análisis morfológico: Aspect=Perf|Tense=Past|VerbForm=Part
#
# Token: by
# Lema: by
# Sufijo: by
# Análisis morfológico:
#
# Token: working
# Lema: work
# Sufijo: ing
# Análisis morfológico: Aspect=Prog|Tense=Pres|VerbForm=Part
#
# Token: men
# Lema: man
# Sufijo: men
# Análisis morfológico: Number=Plur
#
# Token: and
# Lema: and
# Sufijo: and
# Análisis morfológico: ConjType=Cmp
#
# Token: women
# Lema: woman
# Sufijo: men
# Análisis morfológico: Number=Plur
#
# Token: who
# Lema: who
# Sufijo: who
# Análisis morfológico:
#
# Token: dug
# Lema: dig
# Sufijo: dug
# Análisis morfológico: Tense=Past|VerbForm=Fin
#
# Token: into
# Lema: into
# Sufijo: nto
# Análisis morfológico:
#
# Token: what
# Lema: what
# Sufijo: hat
# Análisis morfológico:
#
# Token: little
# Lema: little
# Sufijo: tle
# Análisis morfológico: Degree=Pos
#
# Token: savings
# Lema: saving
# Sufijo: ngs
# Análisis morfológico: Number=Plur
#
# Token: they
# Lema: they
# Sufijo: hey
# Análisis morfológico: Case=Nom|Number=Plur|Person=3|PronType=Prs
#
# Token: had
# Lema: have
# Sufijo: had
# Análisis morfológico: Tense=Past|VerbForm=Fin
#
# Token: to
# Lema: to
# Sufijo: to
# Análisis morfológico:
#
# Token: give
# Lema: give
# Sufijo: ive
# Análisis morfológico: VerbForm=Inf
#
# Token: $
# Lema: $
# Sufijo: $
# Análisis morfológico:
#
# Token: 5
# Lema: 5
# Sufijo: 5
# Análisis morfológico: NumType=Card
#
# Token: and
# Lema: and
# Sufijo: and
# Análisis morfológico: ConjType=Cmp
#
# Token: $
# Lema: $
# Sufijo: $
# Análisis morfológico:
#
# Token: 10
# Lema: 10
# Sufijo: 10
# Análisis morfológico: NumType=Card
#
# Token: and
# Lema: and
# Sufijo: and
# Análisis morfológico: ConjType=Cmp
#
# Token: $
# Lema: $
# Sufijo: $
# Análisis morfológico:
#
# Token: 20
# Lema: 20
# Sufijo: 20
# Análisis morfológico: NumType=Card
#
# Token: to
# Lema: to
# Sufijo: to
# Análisis morfológico:
#
# Token: the
# Lema: the
# Sufijo: the
# Análisis morfológico: Definite=Def|PronType=Art
#
# Token: cause
# Lema: cause
# Sufijo: use
# Análisis morfológico: Number=Sing
#
# Token: .
# Lema: .
# Sufijo: .
# Análisis morfológico: PunctType=Peri
#
# Token:
#
# Lema:
#
# Sufijo:
#
# Análisis morfológico:
#
# Token: It
# Lema: it
# Sufijo: It
# Análisis morfológico: Case=Nom|Gender=Neut|Number=Sing|Person=3|PronType=Prs
#
# Token: grew
# Lema: grow
# Sufijo: rew
# Análisis morfológico: Tense=Past|VerbForm=Fin
#
# Token: strength
# Lema: strength
# Sufijo: gth
# Análisis morfológico: Number=Sing
#
# Token: from
# Lema: from
# Sufijo: rom
# Análisis morfológico:
#
# Token: the
# Lema: the
# Sufijo: the
# Análisis morfológico: Definite=Def|PronType=Art
#
# Token: young
# Lema: young
# Sufijo: ung
# Análisis morfológico: Degree=Pos
#
# Token: people
# Lema: people
# Sufijo: ple
# Análisis morfológico: Number=Plur
#
# Token: who
# Lema: who
# Sufijo: who
# Análisis morfológico:
#
# Token: rejected
# Lema: reject
# Sufijo: ted
# Análisis morfológico: Tense=Past|VerbForm=Fin
#
# Token: the
# Lema: the
# Sufijo: the
# Análisis morfológico: Definite=Def|PronType=Art
#
# Token: myth
# Lema: myth
# Sufijo: yth
# Análisis morfológico: Number=Sing
#
# Token: of
# Lema: of
# Sufijo: of
# Análisis morfológico:
#
# Token: their
# Lema: their
# Sufijo: eir
# Análisis morfológico: Number=Plur|Person=3|Poss=Yes|PronType=Prs
#
# Token: generation
# Lema: generation
# Sufijo: ion
# Análisis morfológico: Number=Sing
#
# Token: ’s
# Lema: ’s
# Sufijo: ’s
# Análisis morfológico:
#
# Token: apathy
# Lema: apathy
# Sufijo: thy
# Análisis morfológico: Degree=Pos
#
# Token: who
# Lema: who
# Sufijo: who
# Análisis morfológico:
#
# Token: left
# Lema: leave
# Sufijo: eft
# Análisis morfológico: Tense=Past|VerbForm=Fin
#
# Token: their
# Lema: their
# Sufijo: eir
# Análisis morfológico: Number=Plur|Person=3|Poss=Yes|PronType=Prs
#
# Token: homes
# Lema: home
# Sufijo: mes
# Análisis morfológico: Number=Plur
#
# Token: and
# Lema: and
# Sufijo: and
# Análisis morfológico: ConjType=Cmp
#
# Token: their
# Lema: their
# Sufijo: eir
# Análisis morfológico: Number=Plur|Person=3|Poss=Yes|PronType=Prs
#
# Token: families
# Lema: family
# Sufijo: ies
# Análisis morfológico: Number=Plur
#
# Token: for
# Lema: for
# Sufijo: for
# Análisis morfológico:
#
# Token: jobs
# Lema: job
# Sufijo: obs
# Análisis morfológico: Number=Plur
#
# Token: that
# Lema: that
# Sufijo: hat
# Análisis morfológico: PronType=Rel
#
# Token: offered
# Lema: offer
# Sufijo: red
# Análisis morfológico: Tense=Past|VerbForm=Fin
#
# Token: little
# Lema: little
# Sufijo: tle
# Análisis morfológico: Degree=Pos
#
# Token: pay
# Lema: pay
# Sufijo: pay
# Análisis morfológico: Number=Sing
#
# Token: and
# Lema: and
# Sufijo: and
# Análisis morfológico: ConjType=Cmp
#
# Token: less
# Lema: less
# Sufijo: ess
# Análisis morfológico: Degree=Cmp
#
# Token: sleep
# Lema: sleep
# Sufijo: eep
# Análisis morfológico: Number=Sing
#
# Token: .
# Lema: .
# Sufijo: .
# Análisis morfológico: PunctType=Peri
#
# Token:
#
# Lema:
#
# Sufijo:
#
# Análisis morfológico:
#
# Token: It
# Lema: it
# Sufijo: It
# Análisis morfológico: Case=Nom|Gender=Neut|Number=Sing|Person=3|PronType=Prs
#
# Token: drew
# Lema: draw
# Sufijo: rew
# Análisis morfológico: Tense=Past|VerbForm=Fin
#
# Token: strength
# Lema: strength
# Sufijo: gth
# Análisis morfológico: Number=Sing
#
# Token: from
# Lema: from
# Sufijo: rom
# Análisis morfológico:
#
# Token: the
# Lema: the
# Sufijo: the
# Análisis morfológico: Definite=Def|PronType=Art
#
# Token: not
# Lema: not
# Sufijo: not
# Análisis morfológico: Polarity=Neg
#
# Token: -
# Lema: -
# Sufijo: -
# Análisis morfológico: PunctType=Dash
#
# Token: so
# Lema: so
# Sufijo: so
# Análisis morfológico:
#
# Token: -
# Lema: -
# Sufijo: -
# Análisis morfológico: PunctType=Dash
#
# Token: young
# Lema: young
# Sufijo: ung
# Análisis morfológico: Degree=Pos
#
# Token: people
# Lema: people
# Sufijo: ple
# Análisis morfológico: Number=Plur
#
# Token: who
# Lema: who
# Sufijo: who
# Análisis morfológico:
#
# Token: braved
# Lema: brave
# Sufijo: ved
# Análisis morfológico: Tense=Past|VerbForm=Fin
#
# Token: the
# Lema: the
# Sufijo: the
# Análisis morfológico: Definite=Def|PronType=Art
#
# Token: bitter
# Lema: bitter
# Sufijo: ter
# Análisis morfológico: Degree=Pos
#
# Token: cold
# Lema: cold
# Sufijo: old
# Análisis morfológico: Number=Sing
#
# Token: and
# Lema: and
# Sufijo: and
# Análisis morfológico: ConjType=Cmp
#
# Token: scorching
# Lema: scorch
# Sufijo: ing
# Análisis morfológico: Aspect=Prog|Tense=Pres|VerbForm=Part
#
# Token: heat
# Lema: heat
# Sufijo: eat
# Análisis morfológico: Number=Sing
#
# Token: to
# Lema: to
# Sufijo: to
# Análisis morfológico:
#
# Token: knock
# Lema: knock
# Sufijo: ock
# Análisis morfológico: VerbForm=Inf
#
# Token: on
# Lema: on
# Sufijo: on
# Análisis morfológico:
#
# Token: doors
# Lema: door
# Sufijo: ors
# Análisis morfológico: Number=Plur
#
# Token: of
# Lema: of
# Sufijo: of
# Análisis morfológico:
#
# Token: perfect
# Lema: perfect
# Sufijo: ect
# Análisis morfológico: Degree=Pos
#
# Token: strangers
# Lema: stranger
# Sufijo: ers
# Análisis morfológico: Number=Plur
#
# Token: ,
# Lema: ,
# Sufijo: ,
# Análisis morfológico: PunctType=Comm
#
# Token: and
# Lema: and
# Sufijo: and
# Análisis morfológico: ConjType=Cmp
#
# Token: from
# Lema: from
# Sufijo: rom
# Análisis morfológico:
#
# Token: the
# Lema: the
# Sufijo: the
# Análisis morfológico: Definite=Def|PronType=Art
#
# Token: millions
# Lema: million
# Sufijo: ons
# Análisis morfológico: Number=Plur
#
# Token: of
# Lema: of
# Sufijo: of
# Análisis morfológico:
#
# Token: Americans
# Lema: Americans
# Sufijo: ans
# Análisis morfológico: Number=Plur
#
# Token: who
# Lema: who
# Sufijo: who
# Análisis morfológico:
#
# Token: volunteered
# Lema: volunteer
# Sufijo: red
# Análisis morfológico: Tense=Past|VerbForm=Fin
#
# Token: and
# Lema: and
# Sufijo: and
# Análisis morfológico: ConjType=Cmp
#
# Token: organized
# Lema: organize
# Sufijo: zed
# Análisis morfológico: Tense=Past|VerbForm=Fin
#
# Token: and
# Lema: and
# Sufijo: and
# Análisis morfológico: ConjType=Cmp
#
# Token: proved
# Lema: prove
# Sufijo: ved
# Análisis morfológico: Tense=Past|VerbForm=Fin
#
# Token: that
# Lema: that
# Sufijo: hat
# Análisis morfológico:
#
# Token: more
# Lema: more
# Sufijo: ore
# Análisis morfológico: Degree=Cmp
#
# Token: than
# Lema: than
# Sufijo: han
# Análisis morfológico:
#
# Token: two
# Lema: two
# Sufijo: two
# Análisis morfológico: NumType=Card
#
# Token: centuries
# Lema: century
# Sufijo: ies
# Análisis morfológico: Number=Plur
#
# Token: later
# Lema: later
# Sufijo: ter
# Análisis morfológico:
#
# Token: a
# Lema: a
# Sufijo: a
# Análisis morfológico: Definite=Ind|PronType=Art
#
# Token: government
# Lema: government
# Sufijo: ent
# Análisis morfológico: Number=Sing
#
# Token: of
# Lema: of
# Sufijo: of
# Análisis morfológico:
#
# Token: the
# Lema: the
# Sufijo: the
# Análisis morfológico: Definite=Def|PronType=Art
#
# Token: people
# Lema: people
# Sufijo: ple
# Análisis morfológico: Number=Plur
#
# Token: ,
# Lema: ,
# Sufijo: ,
# Análisis morfológico: PunctType=Comm
#
# Token: by
# Lema: by
# Sufijo: by
# Análisis morfológico:
#
# Token: the
# Lema: the
# Sufijo: the
# Análisis morfológico: Definite=Def|PronType=Art
#
# Token: people
# Lema: people
# Sufijo: ple
# Análisis morfológico: Number=Plur
#
# Token: ,
# Lema: ,
# Sufijo: ,
# Análisis morfológico: PunctType=Comm
#
# Token: and
# Lema: and
# Sufijo: and
# Análisis morfológico: ConjType=Cmp
#
# Token: for
# Lema: for
# Sufijo: for
# Análisis morfológico:
#
# Token: the
# Lema: the
# Sufijo: the
# Análisis morfológico: Definite=Def|PronType=Art
#
# Token: people
# Lema: people
# Sufijo: ple
# Análisis morfológico: Number=Plur
#
# Token: has
# Lema: have
# Sufijo: has
# Análisis morfológico: Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
#
# Token: not
# Lema: not
# Sufijo: not
# Análisis morfológico: Polarity=Neg
#
# Token: perished
# Lema: perish
# Sufijo: hed
# Análisis morfológico: Aspect=Perf|Tense=Past|VerbForm=Part
#
# Token: from
# Lema: from
# Sufijo: rom
# Análisis morfológico:
#
# Token: the
# Lema: the
# Sufijo: the
# Análisis morfológico: Definite=Def|PronType=Art
#
# Token: Earth
# Lema: Earth
# Sufijo: rth
# Análisis morfológico: Number=Sing
#
# Token: .
# Lema: .
# Sufijo: .
# Análisis morfológico: PunctType=Peri
#
# Token:
#
# Lema:
#
# Sufijo:
#
# Análisis morfológico:
#
# Token: This
# Lema: this
# Sufijo: his
# Análisis morfológico: Number=Sing|PronType=Dem
#
# Token: is
# Lema: be
# Sufijo: is
# Análisis morfológico: Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
#
# Token: your
# Lema: your
# Sufijo: our
# Análisis morfológico: Person=2|Poss=Yes|PronType=Prs
#
# Token: victory
# Lema: victory
# Sufijo: ory
# Análisis morfológico: Number=Sing
#
# Token: .
# Lema: .
# Sufijo: .
# Análisis morfológico: PunctType=Peri
#
# Token:
#
# Lema:
#
# Sufijo:
#
# Análisis morfológico:
#
# Token: And
# Lema: and
# Sufijo: And
# Análisis morfológico: ConjType=Cmp
#
# Token: I
# Lema: I
# Sufijo: I
# Análisis morfológico: Case=Nom|Number=Sing|Person=1|PronType=Prs
#
# Token: know
# Lema: know
# Sufijo: now
# Análisis morfológico: Tense=Pres|VerbForm=Fin
#
# Token: you
# Lema: you
# Sufijo: you
# Análisis morfológico: Case=Nom|Person=2|PronType=Prs
#
# Token: did
# Lema: do
# Sufijo: did
# Análisis morfológico: Tense=Past|VerbForm=Fin
#
# Token: n’t
# Lema: not
# Sufijo: n’t
# Análisis morfológico: Polarity=Neg
#
# Token: do
# Lema: do
# Sufijo: do
# Análisis morfológico: VerbForm=Inf
#
# Token: this
# Lema: this
# Sufijo: his
# Análisis morfológico: Number=Sing|PronType=Dem
#
# Token: just
# Lema: just
# Sufijo: ust
# Análisis morfológico:
#
# Token: to
# Lema: to
# Sufijo: to
# Análisis morfológico:
#
# Token: win
# Lema: win
# Sufijo: win
# Análisis morfológico: VerbForm=Inf
#
# Token: an
# Lema: an
# Sufijo: an
# Análisis morfológico: Definite=Ind|PronType=Art
#
# Token: election
# Lema: election
# Sufijo: ion
# Análisis morfológico: Number=Sing
#
# Token: .
# Lema: .
# Sufijo: .
# Análisis morfológico: PunctType=Peri
#
# Token: And
# Lema: and
# Sufijo: And
# Análisis morfológico: ConjType=Cmp
#
# Token: I
# Lema: I
# Sufijo: I
# Análisis morfológico: Case=Nom|Number=Sing|Person=1|PronType=Prs
#
# Token: know
# Lema: know
# Sufijo: now
# Análisis morfológico: Tense=Pres|VerbForm=Fin
#
# Token: you
# Lema: you
# Sufijo: you
# Análisis morfológico: Case=Nom|Person=2|PronType=Prs
#
# Token: did
# Lema: do
# Sufijo: did
# Análisis morfológico: Tense=Past|VerbForm=Fin
#
# Token: n’t
# Lema: not
# Sufijo: n’t
# Análisis morfológico: Polarity=Neg
#
# Token: do
# Lema: do
# Sufijo: do
# Análisis morfológico: VerbForm=Inf
#
# Token: it
# Lema: it
# Sufijo: it
# Análisis morfológico: Case=Acc|Gender=Neut|Number=Sing|Person=3|PronType=Prs
#
# Token: for
# Lema: for
# Sufijo: for
# Análisis morfológico:
#
# Token: me
# Lema: I
# Sufijo: me
# Análisis morfológico: Case=Acc|Number=Sing|Person=1|PronType=Prs
#
# Token: .
# Lema: .
# Sufijo: .
# Análisis morfológico: PunctType=Peri
#
# Token:
#
# Lema:
#
# Sufijo:
#
# Análisis morfológico:
#
# Token: You
# Lema: you
# Sufijo: You
# Análisis morfológico: Case=Nom|Person=2|PronType=Prs
#
# Token: did
# Lema: do
# Sufijo: did
# Análisis morfológico: Tense=Past|VerbForm=Fin
#
# Token: it
# Lema: it
# Sufijo: it
# Análisis morfológico: Case=Acc|Gender=Neut|Number=Sing|Person=3|PronType=Prs
#
# Token: because
# Lema: because
# Sufijo: use
# Análisis morfológico:
#
# Token: you
# Lema: you
# Sufijo: you
# Análisis morfológico: Case=Nom|Person=2|PronType=Prs
#
# Token: understand
# Lema: understand
# Sufijo: and
# Análisis morfológico: Tense=Pres|VerbForm=Fin
#
# Token: the
# Lema: the
# Sufijo: the
# Análisis morfológico: Definite=Def|PronType=Art
#
# Token: enormity
# Lema: enormity
# Sufijo: ity
# Análisis morfológico: Number=Sing
#
# Token: of
# Lema: of
# Sufijo: of
# Análisis morfológico:
#
# Token: the
# Lema: the
# Sufijo: the
# Análisis morfológico: Definite=Def|PronType=Art
#
# Token: task
# Lema: task
# Sufijo: ask
# Análisis morfológico: Number=Sing
#
# Token: that
# Lema: that
# Sufijo: hat
# Análisis morfológico: PronType=Rel
#
# Token: lies
# Lema: lie
# Sufijo: ies
# Análisis morfológico: Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
#
# Token: ahead
# Lema: ahead
# Sufijo: ead
# Análisis morfológico:
#
# Token: .
# Lema: .
# Sufijo: .
# Análisis morfológico: PunctType=Peri
#
# Token: For
# Lema: for
# Sufijo: For
# Análisis morfológico:
#
# Token: even
# Lema: even
# Sufijo: ven
# Análisis morfológico:
#
# Token: as
# Lema: as
# Sufijo: as
# Análisis morfológico:
#
# Token: we
# Lema: we
# Sufijo: we
# Análisis morfológico: Case=Nom|Number=Plur|Person=1|PronType=Prs
#
# Token: celebrate
# Lema: celebrate
# Sufijo: ate
# Análisis morfológico: Tense=Pres|VerbForm=Fin
#
# Token: tonight
# Lema: tonight
# Sufijo: ght
# Análisis morfológico: Number=Sing
#
# Token: ,
# Lema: ,
# Sufijo: ,
# Análisis morfológico: PunctType=Comm
#
# Token: we
# Lema: we
# Sufijo: we
# Análisis morfológico: Case=Nom|Number=Plur|Person=1|PronType=Prs
#
# Token: know
# Lema: know
# Sufijo: now
# Análisis morfológico: Tense=Pres|VerbForm=Fin
#
# Token: the
# Lema: the
# Sufijo: the
# Análisis morfológico: Definite=Def|PronType=Art
#
# Token: challenges
# Lema: challenge
# Sufijo: ges
# Análisis morfológico: Number=Plur
#
# Token: that
# Lema: that
# Sufijo: hat
# Análisis morfológico: PronType=Rel
#
# Token: tomorrow
# Lema: tomorrow
# Sufijo: row
# Análisis morfológico: Number=Sing
#
# Token: will
# Lema: will
# Sufijo: ill
# Análisis morfológico: VerbForm=Fin
#
# Token: bring
# Lema: bring
# Sufijo: ing
# Análisis morfológico: VerbForm=Inf
#
# Token: are
# Lema: be
# Sufijo: are
# Análisis morfológico: Mood=Ind|Tense=Pres|VerbForm=Fin
#
# Token: the
# Lema: the
# Sufijo: the
# Análisis morfológico: Definite=Def|PronType=Art
#
# Token: greatest
# Lema: great
# Sufijo: est
# Análisis morfológico: Degree=Sup
#
# Token: of
# Lema: of
# Sufijo: of
# Análisis morfológico:
#
# Token: our
# Lema: our
# Sufijo: our
# Análisis morfológico: Number=Plur|Person=1|Poss=Yes|PronType=Prs
#
# Token: lifetime
# Lema: lifetime
# Sufijo: ime
# Análisis morfológico: Number=Sing
#
# Token: —
# Lema: —
# Sufijo: —
# Análisis morfológico:
#
# Token: two
# Lema: two
# Sufijo: two
# Análisis morfológico: NumType=Card
#
# Token: wars
# Lema: war
# Sufijo: ars
# Análisis morfológico: Number=Plur
#
# Token: ,
# Lema: ,
# Sufijo: ,
# Análisis morfológico: PunctType=Comm
#
# Token: a
# Lema: a
# Sufijo: a
# Análisis morfológico: Definite=Ind|PronType=Art
#
# Token: planet
# Lema: planet
# Sufijo: net
# Análisis morfológico: Number=Sing
#
# Token: in
# Lema: in
# Sufijo: in
# Análisis morfológico:
#
# Token: peril
# Lema: peril
# Sufijo: ril
# Análisis morfológico: Number=Sing
#
# Token: ,
# Lema: ,
# Sufijo: ,
# Análisis morfológico: PunctType=Comm
#
# Token: the
# Lema: the
# Sufijo: the
# Análisis morfológico: Definite=Def|PronType=Art
#
# Token: worst
# Lema: bad
# Sufijo: rst
# Análisis morfológico: Degree=Sup
#
# Token: financial
# Lema: financial
# Sufijo: ial
# Análisis morfológico: Degree=Pos
#
# Token: crisis
# Lema: crisis
# Sufijo: sis
# Análisis morfológico: Number=Sing
#
# Token: in
# Lema: in
# Sufijo: in
# Análisis morfológico:
#
# Token: a
# Lema: a
# Sufijo: a
# Análisis morfológico: Definite=Ind|PronType=Art
#
# Token: century
# Lema: century
# Sufijo: ury
# Análisis morfológico: Number=Sing
#
# Token: .
# Lema: .
# Sufijo: .
# Análisis morfológico: PunctType=Peri
#
# Token:
#
# Lema:
#
# Sufijo:
#
# Análisis morfológico:
#
# Token: Even
# Lema: even
# Sufijo: ven
# Análisis morfológico:
#
# Token: as
# Lema: as
# Sufijo: as
# Análisis morfológico:
#
# Token: we
# Lema: we
# Sufijo: we
# Análisis morfológico: Case=Nom|Number=Plur|Person=1|PronType=Prs
#
# Token: stand
# Lema: stand
# Sufijo: and
# Análisis morfológico: Tense=Pres|VerbForm=Fin
#
# Token: here
# Lema: here
# Sufijo: ere
# Análisis morfológico: PronType=Dem
#
# Token: tonight
# Lema: tonight
# Sufijo: ght
# Análisis morfológico: Number=Sing
#
# Token: ,
# Lema: ,
# Sufijo: ,
# Análisis morfológico: PunctType=Comm
#
# Token: we
# Lema: we
# Sufijo: we
# Análisis morfológico: Case=Nom|Number=Plur|Person=1|PronType=Prs
#
# Token: know
# Lema: know
# Sufijo: now
# Análisis morfológico: Tense=Pres|VerbForm=Fin
#
# Token: there
# Lema: there
# Sufijo: ere
# Análisis morfológico:
#
# Token: are
# Lema: be
# Sufijo: are
# Análisis morfológico: Mood=Ind|Tense=Pres|VerbForm=Fin
#
# Token: brave
# Lema: brave
# Sufijo: ave
# Análisis morfológico: Degree=Pos
#
# Token: Americans
# Lema: Americans
# Sufijo: ans
# Análisis morfológico: Number=Plur
#
# Token: waking
# Lema: wake
# Sufijo: ing
# Análisis morfológico: Aspect=Prog|Tense=Pres|VerbForm=Part
#
# Token: up
# Lema: up
# Sufijo: up
# Análisis morfológico:
#
# Token: in
# Lema: in
# Sufijo: in
# Análisis morfológico:
#
# Token: the
# Lema: the
# Sufijo: the
# Análisis morfológico: Definite=Def|PronType=Art
#
# Token: deserts
# Lema: desert
# Sufijo: rts
# Análisis morfológico: Number=Plur
#
# Token: of
# Lema: of
# Sufijo: of
# Análisis morfológico:
#
# Token: Iraq
# Lema: Iraq
# Sufijo: raq
# Análisis morfológico: Number=Sing
#
# Token: and
# Lema: and
# Sufijo: and
# Análisis morfológico: ConjType=Cmp
#
# Token: the
# Lema: the
# Sufijo: the
# Análisis morfológico: Definite=Def|PronType=Art
#
# Token: mountains
# Lema: mountain
# Sufijo: ins
# Análisis morfológico: Number=Plur
#
# Token: of
# Lema: of
# Sufijo: of
# Análisis morfológico:
#
# Token: Afghanistan
# Lema: Afghanistan
# Sufijo: tan
# Análisis morfológico: Number=Sing
#
# Token: to
# Lema: to
# Sufijo: to
# Análisis morfológico:
#
# Token: risk
# Lema: risk
# Sufijo: isk
# Análisis morfológico: VerbForm=Inf
#
# Token: their
# Lema: their
# Sufijo: eir
# Análisis morfológico: Number=Plur|Person=3|Poss=Yes|PronType=Prs
#
# Token: lives
# Lema: life
# Sufijo: ves
# Análisis morfológico: Number=Plur
#
# Token: for
# Lema: for
# Sufijo: for
# Análisis morfológico:
#
# Token: us
# Lema: we
# Sufijo: us
# Análisis morfológico: Case=Acc|Number=Plur|Person=1|PronType=Prs
#
# Token: .
# Lema: .
# Sufijo: .
# Análisis morfológico: PunctType=Peri
#
# Token:
#
# Lema:
#
# Sufijo:
#
# Análisis morfológico:
#
# Token: There
# Lema: there
# Sufijo: ere
# Análisis morfológico:
#
# Token: are
# Lema: be
# Sufijo: are
# Análisis morfológico: Mood=Ind|Tense=Pres|VerbForm=Fin
#
# Token: mothers
# Lema: mother
# Sufijo: ers
# Análisis morfológico: Number=Plur
#
# Token: and
# Lema: and
# Sufijo: and
# Análisis morfológico: ConjType=Cmp
#
# Token: fathers
# Lema: father
# Sufijo: ers
# Análisis morfológico: Number=Plur
#
# Token: who
# Lema: who
# Sufijo: who
# Análisis morfológico:
#
# Token: will
# Lema: will
# Sufijo: ill
# Análisis morfológico: VerbForm=Fin
#
# Token: lie
# Lema: lie
# Sufijo: lie
# Análisis morfológico: VerbForm=Inf
#
# Token: awake
# Lema: awake
# Sufijo: ake
# Análisis morfológico: Degree=Pos
#
# Token: after
# Lema: after
# Sufijo: ter
# Análisis morfológico:
#
# Token: the
# Lema: the
# Sufijo: the
# Análisis morfológico: Definite=Def|PronType=Art
#
# Token: children
# Lema: child
# Sufijo: ren
# Análisis morfológico: Number=Plur
#
# Token: fall
# Lema: fall
# Sufijo: all
# Análisis morfológico: Tense=Pres|VerbForm=Fin
#
# Token: asleep
# Lema: asleep
# Sufijo: eep
# Análisis morfológico: Degree=Pos
#
# Token: and
# Lema: and
# Sufijo: and
# Análisis morfológico: ConjType=Cmp
#
# Token: wonder
# Lema: wonder
# Sufijo: der
# Análisis morfológico: Tense=Pres|VerbForm=Fin
#
# Token: how
# Lema: how
# Sufijo: how
# Análisis morfológico:
#
# Token: they
# Lema: they
# Sufijo: hey
# Análisis morfológico: Case=Nom|Number=Plur|Person=3|PronType=Prs
#
# Token: ’ll
# Lema: ’ll
# Sufijo: ’ll
# Análisis morfológico: VerbType=Mod
#
# Token: make
# Lema: make
# Sufijo: ake
# Análisis morfológico: VerbForm=Inf
#
# Token: the
# Lema: the
# Sufijo: the
# Análisis morfológico: Definite=Def|PronType=Art
#
# Token: mortgage
# Lema: mortgage
# Sufijo: age
# Análisis morfológico: Number=Sing
#
# Token: or
# Lema: or
# Sufijo: or
# Análisis morfológico: ConjType=Cmp
#
# Token: pay
# Lema: pay
# Sufijo: pay
# Análisis morfológico: VerbForm=Inf
#
# Token: their
# Lema: their
# Sufijo: eir
# Análisis morfológico: Number=Plur|Person=3|Poss=Yes|PronType=Prs
#
# Token: doctors
# Lema: doctor
# Sufijo: ors
# Análisis morfológico: Number=Plur
#
# Token: ’
# Lema: ’
# Sufijo: ’
# Análisis morfológico:
#
# Token: bills
# Lema: bill
# Sufijo: lls
# Análisis morfológico: Number=Plur
#
# Token: or
# Lema: or
# Sufijo: or
# Análisis morfológico: ConjType=Cmp
#
# Token: save
# Lema: save
# Sufijo: ave
# Análisis morfológico: VerbForm=Inf
#
# Token: enough
# Lema: enough
# Sufijo: ugh
# Análisis morfológico: Degree=Pos
#
# Token: for
# Lema: for
# Sufijo: for
# Análisis morfológico:
#
# Token: their
# Lema: their
# Sufijo: eir
# Análisis morfológico: Number=Plur|Person=3|Poss=Yes|PronType=Prs
#
# Token: child
# Lema: child
# Sufijo: ild
# Análisis morfológico: Number=Sing
#
# Token: ’s
# Lema: ’s
# Sufijo: ’s
# Análisis morfológico:
#
# Token: college
# Lema: college
# Sufijo: ege
# Análisis morfológico: Number=Sing
#
# Token: education
# Lema: education
# Sufijo: ion
# Análisis morfológico: Number=Sing
#
# Token: .
# Lema: .
# Sufijo: .
# Análisis morfológico: PunctType=Peri
#
# Token:
#
# Lema:
#
# Sufijo:
#
# Análisis morfológico:
#
# Token: There
# Lema: there
# Sufijo: ere
# Análisis morfológico:
#
# Token: ’s
# Lema: ’
# Sufijo: ’s
# Análisis morfológico: Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
#
# Token: new
# Lema: new
# Sufijo: new
# Análisis morfológico: Degree=Pos
#
# Token: energy
# Lema: energy
# Sufijo: rgy
# Análisis morfológico: Number=Sing
#
# Token: to
# Lema: to
# Sufijo: to
# Análisis morfológico:
#
# Token: harness
# Lema: harness
# Sufijo: ess
# Análisis morfológico: Number=Sing
#
# Token: ,
# Lema: ,
# Sufijo: ,
# Análisis morfológico: PunctType=Comm
#
# Token: new
# Lema: new
# Sufijo: new
# Análisis morfológico: Degree=Pos
#
# Token: jobs
# Lema: job
# Sufijo: obs
# Análisis morfológico: Number=Plur
#
# Token: to
# Lema: to
# Sufijo: to
# Análisis morfológico:
#
# Token: be
# Lema: be
# Sufijo: be
# Análisis morfológico: VerbForm=Inf
#
# Token: created
# Lema: create
# Sufijo: ted
# Análisis morfológico: Aspect=Perf|Tense=Past|VerbForm=Part
#
# Token: ,
# Lema: ,
# Sufijo: ,
# Análisis morfológico: PunctType=Comm
#
# Token: new
# Lema: new
# Sufijo: new
# Análisis morfológico: Degree=Pos
#
# Token: schools
# Lema: school
# Sufijo: ols
# Análisis morfológico: Number=Plur
#
# Token: to
# Lema: to
# Sufijo: to
# Análisis morfológico:
#
# Token: build
# Lema: build
# Sufijo: ild
# Análisis morfológico: VerbForm=Inf
#
# Token: ,
# Lema: ,
# Sufijo: ,
# Análisis morfológico: PunctType=Comm
#
# Token: and
# Lema: and
# Sufijo: and
# Análisis morfológico: ConjType=Cmp
#
# Token: threats
# Lema: threat
# Sufijo: ats
# Análisis morfológico: Number=Plur
#
# Token: to
# Lema: to
# Sufijo: to
# Análisis morfológico:
#
# Token: meet
# Lema: meet
# Sufijo: eet
# Análisis morfológico: VerbForm=Inf
#
# Token: ,
# Lema: ,
# Sufijo: ,
# Análisis morfológico: PunctType=Comm
#
# Token: alliances
# Lema: alliance
# Sufijo: ces
# Análisis morfológico: Number=Plur
#
# Token: to
# Lema: to
# Sufijo: to
# Análisis morfológico:
#
# Token: repair
# Lema: repair
# Sufijo: air
# Análisis morfológico: VerbForm=Inf
#
# Token: .
# Lema: .
# Sufijo: .
# Análisis morfológico: PunctType=Peri
#
# Token:
#
# Lema:
#
# Sufijo:
#
# Análisis morfológico:
#
# Token: The
# Lema: the
# Sufijo: The
# Análisis morfológico: Definite=Def|PronType=Art
#
# Token: road
# Lema: road
# Sufijo: oad
# Análisis morfológico: Number=Sing
#
# Token: ahead
# Lema: ahead
# Sufijo: ead
# Análisis morfológico:
#
# Token: will
# Lema: will
# Sufijo: ill
# Análisis morfológico: VerbForm=Fin
#
# Token: be
# Lema: be
# Sufijo: be
# Análisis morfológico: VerbForm=Inf
#
# Token: long
# Lema: long
# Sufijo: ong
# Análisis morfológico: Degree=Pos
#
# Token: .
# Lema: .
# Sufijo: .
# Análisis morfológico: PunctType=Peri
#
# Token: Our
# Lema: our
# Sufijo: Our
# Análisis morfológico: Number=Plur|Person=1|Poss=Yes|PronType=Prs
#
# Token: climb
# Lema: climb
# Sufijo: imb
# Análisis morfológico: Number=Sing
#
# Token: will
# Lema: will
# Sufijo: ill
# ...
#
# Token: vote
# Lema: vote
# Sufijo: ote
# Análisis morfológico: Number=Sing
#
# Token: ,
# Lema: ,
# Sufijo: ,
# Análisis morfológico: PunctType=Comm
#
# Token: because
# Lema: because
# Sufijo: use
# Análisis morfológico:
#
# Token: after
# Lema: after
# Sufijo: ter
# Análisis morfológico:
#
# Token: 106
# Lema: 106
# Sufijo: 106
# Análisis morfológico: NumType=Card
#
# Token: years
# Lema: year
# Sufijo: ars
# Análisis morfológico: Number=Plur
#
# Token: in
# Lema: in
# Sufijo: in
# Análisis morfológico:
#
# Token: America
# Lema: America
# Sufijo: ica
# Análisis morfológico: Number=Sing
#
# Token: ,
# Lema: ,
# Sufijo: ,
# Análisis morfológico: PunctType=Comm
#
# Token: through
# Lema: through
# Sufijo: ugh
# Análisis morfológico:
#
# Token: the
# Lema: the
# Sufijo: the
# Análisis morfológico: Definite=Def|PronType=Art
#
# Token: best
# Lema: good
# Sufijo: est
# Análisis morfológico: Degree=Sup
#
# Token: of
# Lema: of
# Sufijo: of
# Análisis morfológico:
#
# Token: times
# Lema: time
# Sufijo: mes
# Análisis morfológico: Number=Plur
#
# Token: and
# Lema: and
# Sufijo: and
# Análisis morfológico: ConjType=Cmp
#
# Token: the
# Lema: the
# Sufijo: the
# Análisis morfológico: Definite=Def|PronType=Art
#
# Token: darkest
# Lema: darkest
# Sufijo: est
# Análisis morfológico: Number=Sing
#
# Token: of
# Lema: of
# Sufijo: of
# Análisis morfológico:
#
# Token: hours
# Lema: hour
# Sufijo: urs
# Análisis morfológico: Number=Plur
#
# Token: ,
# Lema: ,
# Sufijo: ,
# Análisis morfológico: PunctType=Comm
#
# Token: she
# Lema: she
# Sufijo: she
# Análisis morfológico: Case=Nom|Gender=Fem|Number=Sing|Person=3|PronType=Prs
#
# Token: knows
# Lema: know
# Sufijo: ows
# Análisis morfológico: Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
#
# Token: how
# Lema: how
# Sufijo: how
# Análisis morfológico:
#
# Token: America
# Lema: America
# Sufijo: ica
# Análisis morfológico: Number=Sing
#
# Token: can
# Lema: can
# Sufijo: can
# Análisis morfológico: VerbForm=Fin
#
# Token: change
# Lema: change
# Sufijo: nge
# Análisis morfológico: VerbForm=Inf
#
# Token: .
# Lema: .
# Sufijo: .
# Análisis morfológico: PunctType=Peri
#
# Token:
#
# Lema:
#
# Sufijo:
#
# Análisis morfológico:
#
# Token: Yes
# Lema: yes
# Sufijo: Yes
# Análisis morfológico:
#
# Token: we
# Lema: we
# Sufijo: we
# Análisis morfológico: Case=Nom|Number=Plur|Person=1|PronType=Prs
#
# Token: can
# Lema: can
# Sufijo: can
# Análisis morfológico: VerbForm=Fin
#
# Token: .
# Lema: .
# Sufijo: .
# Análisis morfológico: PunctType=Peri
#
# Token:
#
# Lema:
#
# Sufijo:
#
# Análisis morfológico:
#
# Token: America
# Lema: America
# Sufijo: ica
# Análisis morfológico: Number=Sing
#
# Token: ,
# Lema: ,
# Sufijo: ,
# Análisis morfológico: PunctType=Comm
#
# Token: we
# Lema: we
# Sufijo: we
# Análisis morfológico: Case=Nom|Number=Plur|Person=1|PronType=Prs
#
# Token: have
# Lema: have
# Sufijo: ave
# Análisis morfológico: Mood=Ind|Tense=Pres|VerbForm=Fin
#
# Token: come
# Lema: come
# Sufijo: ome
# Análisis morfológico: Aspect=Perf|Tense=Past|VerbForm=Part
#
# Token: so
# Lema: so
# Sufijo: so
# Análisis morfológico:
#
# Token: far
# Lema: far
# Sufijo: far
# Análisis morfológico:
#
# Token: .
# Lema: .
# Sufijo: .
# Análisis morfológico: PunctType=Peri
#
# Token: We
# Lema: we
# Sufijo: We
# Análisis morfológico: Case=Nom|Number=Plur|Person=1|PronType=Prs
#
# Token: have
# Lema: have
# Sufijo: ave
# Análisis morfológico: Mood=Ind|Tense=Pres|VerbForm=Fin
#
# Token: seen
# Lema: see
# Sufijo: een
# Análisis morfológico: Aspect=Perf|Tense=Past|VerbForm=Part
#
# Token: so
# Lema: so
# Sufijo: so
# Análisis morfológico:
#
# Token: much
# Lema: much
# Sufijo: uch
# Análisis morfológico: Degree=Pos
#
# Token: .
# Lema: .
# Sufijo: .
# Análisis morfológico: PunctType=Peri
#
# Token: But
# Lema: but
# Sufijo: But
# Análisis morfológico: ConjType=Cmp
#
# Token: there
# Lema: there
# Sufijo: ere
# Análisis morfológico:
#
# Token: is
# Lema: be
# Sufijo: is
# Análisis morfológico: Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
#
# Token: so
# Lema: so
# Sufijo: so
# Análisis morfológico:
#
# Token: much
# Lema: much
# Sufijo: uch
# Análisis morfológico:
#
# Token: more
# Lema: more
# Sufijo: ore
# Análisis morfológico: Degree=Cmp
#
# Token: to
# Lema: to
# Sufijo: to
# Análisis morfológico:
#
# Token: do
# Lema: do
# Sufijo: do
# Análisis morfológico: VerbForm=Inf
#
# Token: .
# Lema: .
# Sufijo: .
# Análisis morfológico: PunctType=Peri
#
# Token: So
# Lema: so
# Sufijo: So
# Análisis morfológico:
#
# Token: tonight
# Lema: tonight
# Sufijo: ght
# Análisis morfológico: Number=Sing
#
# Token: ,
# Lema: ,
# Sufijo: ,
# Análisis morfológico: PunctType=Comm
#
# Token: let
# Lema: let
# Sufijo: let
# Análisis morfológico: VerbForm=Inf
#
# Token: us
# Lema: we
# Sufijo: us
# Análisis morfológico: Case=Acc|Number=Plur|Person=1|PronType=Prs
#
# Token: ask
# Lema: ask
# Sufijo: ask
# Análisis morfológico: VerbForm=Inf
#
# Token: ourselves
# Lema: ourselves
# Sufijo: ves
# Análisis morfológico: Case=Acc|Number=Plur|Person=1|PronType=Prs|Reflex=Yes
#
# Token: —
# Lema: —
# Sufijo: —
# Análisis morfológico:
#
# Token: if
# Lema: if
# Sufijo: if
# Análisis morfológico:
#
# Token: our
# Lema: our
# Sufijo: our
# Análisis morfológico: Number=Plur|Person=1|Poss=Yes|PronType=Prs
#
# Token: children
# Lema: child
# Sufijo: ren
# Análisis morfológico: Number=Plur
#
# Token: should
# Lema: should
# Sufijo: uld
# Análisis morfológico: VerbForm=Fin
#
# Token: live
# Lema: live
# Sufijo: ive
# Análisis morfológico: VerbForm=Inf
#
# Token: to
# Lema: to
# Sufijo: to
# Análisis morfológico:
#
# Token: see
# Lema: see
# Sufijo: see
# Análisis morfológico: VerbForm=Inf
#
# Token: the
# Lema: the
# Sufijo: the
# Análisis morfológico: Definite=Def|PronType=Art
#
# Token: next
# Lema: next
# Sufijo: ext
# Análisis morfológico: Degree=Pos
#
# Token: century
# Lema: century
# Sufijo: ury
# Análisis morfológico: Number=Sing
#
# Token: ;
# Lema: ;
# Sufijo: ;
# Análisis morfológico:
#
# Token: if
# Lema: if
# Sufijo: if
# Análisis morfológico:
#
# Token: my
# Lema: my
# Sufijo: my
# Análisis morfológico: Number=Sing|Person=1|Poss=Yes|PronType=Prs
#
# Token: daughters
# Lema: daughter
# Sufijo: ers
# Análisis morfológico: Number=Plur
#
# Token: should
# Lema: should
# Sufijo: uld
# Análisis morfológico: VerbForm=Fin
#
# Token: be
# Lema: be
# Sufijo: be
# Análisis morfológico: VerbForm=Inf
#
# Token: so
# Lema: so
# Sufijo: so
# Análisis morfológico:
#
# Token: lucky
# Lema: lucky
# Sufijo: cky
# Análisis morfológico: Degree=Pos
#
# Token: to
# Lema: to
# Sufijo: to
# Análisis morfológico:
#
# Token: live
# Lema: live
# Sufijo: ive
# Análisis morfológico: VerbForm=Inf
#
# Token: as
# Lema: as
# Sufijo: as
# Análisis morfológico:
#
# Token: long
# Lema: long
# Sufijo: ong
# Análisis morfológico:
#
# Token: as
# Lema: as
# Sufijo: as
# Análisis morfológico:
#
# Token: Ann
# Lema: Ann
# Sufijo: Ann
# Análisis morfológico: Number=Sing
#
# Token: Nixon
# Lema: Nixon
# Sufijo: xon
# Análisis morfológico: Number=Sing
#
# Token: Cooper
# Lema: Cooper
# Sufijo: per
# Análisis morfológico: Number=Sing
#
# Token: ,
# Lema: ,
# Sufijo: ,
# Análisis morfológico: PunctType=Comm
#
# Token: what
# Lema: what
# Sufijo: hat
# Análisis morfológico:
#
# Token: change
# Lema: change
# Sufijo: nge
# Análisis morfológico: Number=Sing
#
# Token: will
# Lema: will
# Sufijo: ill
# Análisis morfológico: VerbForm=Fin
#
# Token: they
# Lema: they
# Sufijo: hey
# Análisis morfológico: Case=Nom|Number=Plur|Person=3|PronType=Prs
#
# Token: see
# Lema: see
# Sufijo: see
# Análisis morfológico: VerbForm=Inf
#
# Token: ?
# Lema: ?
# Sufijo: ?
# Análisis morfológico: PunctType=Peri
#
# Token: What
# Lema: what
# Sufijo: hat
# Análisis morfológico:
#
# Token: progress
# Lema: progress
# Sufijo: ess
# Análisis morfológico: Number=Sing
#
# Token: will
# Lema: will
# Sufijo: ill
# Análisis morfológico: VerbForm=Fin
#
# Token: we
# Lema: we
# Sufijo: we
# Análisis morfológico: Case=Nom|Number=Plur|Person=1|PronType=Prs
#
# Token: have
# Lema: have
# Sufijo: ave
# Análisis morfológico: VerbForm=Inf
#
# Token: made
# Lema: make
# Sufijo: ade
# Análisis morfológico: Aspect=Perf|Tense=Past|VerbForm=Part
#
# Token: ?
# Lema: ?
# Sufijo: ?
# Análisis morfológico: PunctType=Peri
#
# Token:
#
# Lema:
#
# Sufijo:
#
# Análisis morfológico:
#
# Token: This
# Lema: this
# Sufijo: his
# Análisis morfológico: Number=Sing|PronType=Dem
#
# Token: is
# Lema: be
# Sufijo: is
# Análisis morfológico: Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
#
# Token: our
# Lema: our
# Sufijo: our
# Análisis morfológico: Number=Plur|Person=1|Poss=Yes|PronType=Prs
#
# Token: chance
# Lema: chance
# Sufijo: nce
# Análisis morfológico: Number=Sing
#
# Token: to
# Lema: to
# Sufijo: to
# Análisis morfológico:
#
# Token: answer
# Lema: answer
# Sufijo: wer
# Análisis morfológico: VerbForm=Inf
#
# Token: that
# Lema: that
# Sufijo: hat
# Análisis morfológico: Number=Sing|PronType=Dem
#
# Token: call
# Lema: call
# Sufijo: all
# Análisis morfológico: Number=Sing
#
# Token: .
# Lema: .
# Sufijo: .
# Análisis morfológico: PunctType=Peri
#
# Token: This
# Lema: this
# Sufijo: his
# Análisis morfológico: Number=Sing|PronType=Dem
#
# Token: is
# Lema: be
# Sufijo: is
# Análisis morfológico: Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
#
# Token: our
# Lema: our
# Sufijo: our
# Análisis morfológico: Number=Plur|Person=1|Poss=Yes|PronType=Prs
#
# Token: moment
# Lema: moment
# Sufijo: ent
# Análisis morfológico: Number=Sing
#
# Token: .
# Lema: .
# Sufijo: .
# Análisis morfológico: PunctType=Peri
#
# Token:
#
# Lema:
#
# Sufijo:
#
# Análisis morfológico:
#
# Token: This
# Lema: this
# Sufijo: his
# Análisis morfológico: Number=Sing|PronType=Dem
#
# Token: is
# Lema: be
# Sufijo: is
# Análisis morfológico: Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
#
# Token: our
# Lema: our
# Sufijo: our
# Análisis morfológico: Number=Plur|Person=1|Poss=Yes|PronType=Prs
#
# Token: time
# Lema: time
# Sufijo: ime
# Análisis morfológico: Number=Sing
#
# Token: ,
# Lema: ,
# Sufijo: ,
# Análisis morfológico: PunctType=Comm
#
# Token: to
# Lema: to
# Sufijo: to
# Análisis morfológico:
#
# Token: put
# Lema: put
# Sufijo: put
# Análisis morfológico: VerbForm=Inf
#
# Token: our
# Lema: our
# Sufijo: our
# Análisis morfológico: Number=Plur|Person=1|Poss=Yes|PronType=Prs
#
# Token: people
# Lema: people
# Sufijo: ple
# Análisis morfológico: Number=Plur
#
# Token: back
# Lema: back
# Sufijo: ack
# Análisis morfológico:
#
# Token: to
# Lema: to
# Sufijo: to
# Análisis morfológico:
#
# Token: work
# Lema: work
# Sufijo: ork
# Análisis morfológico: Number=Sing
#
# Token: and
# Lema: and
# Sufijo: and
# Análisis morfológico: ConjType=Cmp
#
# Token: open
# Lema: open
# Sufijo: pen
# Análisis morfológico: Degree=Pos
#
# Token: doors
# Lema: door
# Sufijo: ors
# Análisis morfológico: Number=Plur
#
# Token: of
# Lema: of
# Sufijo: of
# Análisis morfológico:
#
# Token: opportunity
# Lema: opportunity
# Sufijo: ity
# Análisis morfológico: Number=Sing
#
# Token: for
# Lema: for
# Sufijo: for
# Análisis morfológico:
#
# Token: our
# Lema: our
# Sufijo: our
# Análisis morfológico: Number=Plur|Person=1|Poss=Yes|PronType=Prs
#
# Token: kids
# Lema: kid
# Sufijo: ids
# Análisis morfológico: Number=Plur
#
# Token: ;
# Lema: ;
# Sufijo: ;
# Análisis morfológico:
#
# Token: to
# Lema: to
# Sufijo: to
# Análisis morfológico:
#
# Token: restore
# Lema: restore
# Sufijo: ore
# Análisis morfológico: VerbForm=Inf
#
# Token: prosperity
# Lema: prosperity
# Sufijo: ity
# Análisis morfológico: Number=Sing
#
# Token: and
# Lema: and
# Sufijo: and
# Análisis morfológico: ConjType=Cmp
#
# Token: promote
# Lema: promote
# Sufijo: ote
# Análisis morfológico: VerbForm=Inf
#
# Token: the
# Lema: the
# Sufijo: the
# Análisis morfológico: Definite=Def|PronType=Art
#
# Token: cause
# Lema: cause
# Sufijo: use
# Análisis morfológico: Number=Sing
#
# Token: of
# Lema: of
# Sufijo: of
# Análisis morfológico:
#
# Token: peace
# Lema: peace
# Sufijo: ace
# Análisis morfológico: Number=Sing
#
# Token: ;
# Lema: ;
# Sufijo: ;
# Análisis morfológico:
#
# Token: to
# Lema: to
# Sufijo: to
# Análisis morfológico:
#
# Token: reclaim
# Lema: reclaim
# Sufijo: aim
# Análisis morfológico: VerbForm=Inf
#
# Token: the
# Lema: the
# Sufijo: the
# Análisis morfológico: Definite=Def|PronType=Art
#
# Token: American
# Lema: american
# Sufijo: can
# Análisis morfológico: Degree=Pos
#
# Token: dream
# Lema: dream
# Sufijo: eam
# Análisis morfológico: Number=Sing
#
# Token: and
# Lema: and
# Sufijo: and
# Análisis morfológico: ConjType=Cmp
#
# Token: reaffirm
# Lema: reaffirm
# Sufijo: irm
# Análisis morfológico: VerbForm=Inf
#
# Token: that
# Lema: that
# Sufijo: hat
# Análisis morfológico: Number=Sing|PronType=Dem
#
# Token: fundamental
# Lema: fundamental
# Sufijo: tal
# Análisis morfológico: Degree=Pos
#
# Token: truth
# Lema: truth
# Sufijo: uth
# Análisis morfológico: Number=Sing
#
# Token: ,
# Lema: ,
# Sufijo: ,
# Análisis morfológico: PunctType=Comm
#
# Token: that
# Lema: that
# Sufijo: hat
# Análisis morfológico:
#
# Token: ,
# Lema: ,
# Sufijo: ,
# Análisis morfológico: PunctType=Comm
#
# Token: out
# Lema: out
# Sufijo: out
# Análisis morfológico:
#
# Token: of
# Lema: of
# Sufijo: of
# Análisis morfológico:
#
# Token: many
# Lema: many
# Sufijo: any
# Análisis morfológico: Degree=Pos
#
# Token: ,
# Lema: ,
# Sufijo: ,
# Análisis morfológico: PunctType=Comm
#
# Token: we
# Lema: we
# Sufijo: we
# Análisis morfológico: Case=Nom|Number=Plur|Person=1|PronType=Prs
#
# Token: are
# Lema: be
# Sufijo: are
# Análisis morfológico: Mood=Ind|Tense=Pres|VerbForm=Fin
#
# Token: one
# Lema: one
# Sufijo: one
# Análisis morfológico: NumType=Card
#
# Token: ;
# Lema: ;
# Sufijo: ;
# Análisis morfológico:
#
# Token: that
# Lema: that
# Sufijo: hat
# Análisis morfológico:
#
# Token: while
# Lema: while
# Sufijo: ile
# Análisis morfológico:
#
# Token: we
# Lema: we
# Sufijo: we
# Análisis morfológico: Case=Nom|Number=Plur|Person=1|PronType=Prs
#
# Token: breathe
# Lema: breathe
# Sufijo: the
# Análisis morfológico: Tense=Pres|VerbForm=Fin
#
# Token: ,
# Lema: ,
# Sufijo: ,
# Análisis morfológico: PunctType=Comm
#
# Token: we
# Lema: we
# Sufijo: we
# Análisis morfológico: Case=Nom|Number=Plur|Person=1|PronType=Prs
#
# Token: hope
# Lema: hope
# Sufijo: ope
# Análisis morfológico: Tense=Pres|VerbForm=Fin
#
# Token: .
# Lema: .
# Sufijo: .
# Análisis morfológico: PunctType=Peri
#
# Token: And
# Lema: and
# Sufijo: And
# Análisis morfológico: ConjType=Cmp
#
# Token: where
# Lema: where
# Sufijo: ere
# Análisis morfológico:
#
# Token: we
# Lema: we
# Sufijo: we
# Análisis morfológico: Case=Nom|Number=Plur|Person=1|PronType=Prs
#
# Token: are
# Lema: be
# Sufijo: are
# Análisis morfológico: Mood=Ind|Tense=Pres|VerbForm=Fin
#
# Token: met
# Lema: meet
# Sufijo: met
# Análisis morfológico: Aspect=Perf|Tense=Past|VerbForm=Part
#
# Token: with
# Lema: with
# Sufijo: ith
# Análisis morfológico:
#
# Token: cynicism
# Lema: cynicism
# Sufijo: ism
# Análisis morfológico: Number=Sing
#
# Token: and
# Lema: and
# Sufijo: and
# Análisis morfológico: ConjType=Cmp
#
# Token: doubts
# Lema: doubt
# Sufijo: bts
# Análisis morfológico: Number=Plur
#
# Token: and
# Lema: and
# Sufijo: and
# Análisis morfológico: ConjType=Cmp
#
# Token: those
# Lema: those
# Sufijo: ose
# Análisis morfológico: Number=Plur|PronType=Dem
#
# Token: who
# Lema: who
# Sufijo: who
# Análisis morfológico:
#
# Token: tell
# Lema: tell
# Sufijo: ell
# Análisis morfológico: Tense=Pres|VerbForm=Fin
#
# Token: us
# Lema: we
# Sufijo: us
# Análisis morfológico: Case=Acc|Number=Plur|Person=1|PronType=Prs
#
# Token: that
# Lema: that
# Sufijo: hat
# Análisis morfológico:
#
# Token: we
# Lema: we
# Sufijo: we
# Análisis morfológico: Case=Nom|Number=Plur|Person=1|PronType=Prs
#
# Token: ca
# Lema: can
# Sufijo: ca
# Análisis morfológico: VerbType=Mod
#
# Token: n’t
# Lema: not
# Sufijo: n’t
# Análisis morfológico: Polarity=Neg
#
# Token: ,
# Lema: ,
# Sufijo: ,
# Análisis morfológico: PunctType=Comm
#
# Token: we
# Lema: we
# Sufijo: we
# Análisis morfológico: Case=Nom|Number=Plur|Person=1|PronType=Prs
#
# Token: will
# Lema: will
# Sufijo: ill
# Análisis morfológico: VerbForm=Fin
#
# Token: respond
# Lema: respond
# Sufijo: ond
# Análisis morfológico: VerbForm=Inf
#
# Token: with
# Lema: with
# Sufijo: ith
# Análisis morfológico:
#
# Token: that
# Lema: that
# Sufijo: hat
# Análisis morfológico: Number=Sing|PronType=Dem
#
# Token: timeless
# Lema: timeless
# Sufijo: ess
# Análisis morfológico: Number=Sing
#
# Token: creed
# Lema: creed
# Sufijo: eed
# Análisis morfológico: Number=Sing
#
# Token: that
# Lema: that
# Sufijo: hat
# Análisis morfológico: PronType=Rel
#
# Token: sums
# Lema: sum
# Sufijo: ums
# Análisis morfológico: Number=Sing|Person=3|Tense=Pres|VerbForm=Fin
#
# Token: up
# Lema: up
# Sufijo: up
# Análisis morfológico:
#
# Token: the
# Lema: the
# Sufijo: the
# Análisis morfológico: Definite=Def|PronType=Art
#
# Token: spirit
# Lema: spirit
# Sufijo: rit
# Análisis morfológico: Number=Sing
#
# Token: of
# Lema: of
# Sufijo: of
# Análisis morfológico:
#
# Token: a
# Lema: a
# Sufijo: a
# Análisis morfológico: Definite=Ind|PronType=Art
#
# Token: people
# Lema: people
# Sufijo: ple
# Análisis morfológico: Number=Plur
#
# Token: :
# Lema: :
# Sufijo: :
# Análisis morfológico:
#
# Token: Yes
# Lema: yes
# Sufijo: Yes
# Análisis morfológico:
#
# Token: ,
# Lema: ,
# Sufijo: ,
# Análisis morfológico: PunctType=Comm
#
# Token: we
# Lema: we
# Sufijo: we
# Análisis morfológico: Case=Nom|Number=Plur|Person=1|PronType=Prs
#
# Token: can
# Lema: can
# Sufijo: can
# Análisis morfológico: VerbForm=Fin
#
# Token: .
# Lema: .
# Sufijo: .
# Análisis morfológico: PunctType=Peri
#
# Token: [
# Lema: [
# Sufijo: [
# Análisis morfológico:

# %% [markdown]
# <b>Incluye aquí, debajo de la línea, la explicación de tu respuesta</b>
# <hr>

# %% [markdown]
# Itero en cada token del texto y uso las funciones text, lemma_, suffix_ y morph para visualizar los campos requeridos

# %% [markdown]
# <span style="font-size: 14pt; font-weight: bold; color: #0098cd;">Pregunta 5.</span>
# <span style="font-size: 14pt; font-weight: bold; color: #0098cd;">¿Cómo puedes identificar/eliminar las stop words?</span>

# %%
# Importa la lista de stop words desde spacy
from spacy.lang.en.stop_words import STOP_WORDS

# Define una lista de tokens sin las stop words
tokens_sin_stop_words = [token.text for token in doc if token.text.lower() not in STOP_WORDS]

# Imprime los tokens sin stop words
print("Tokens sin stop words:")
print(tokens_sin_stop_words)
# Out:
# Tokens sin stop words:
# ['“', 'Hello', ',', 'Chicago', '.', '\n', 'doubts', 'America', 'place', 'things', 'possible', ',', 'wonders', 'dream', 'founders', 'alive', 'time', ',', 'questions', 'power', 'democracy', ',', 'tonight', 'answer', '.', '\n', 'answer', 'told', 'lines', 'stretched', 'schools', 'churches', 'numbers', 'nation', 'seen', ',', 'people', 'waited', 'hours', 'hours', ',', 'time', 'lives', ',', 'believed', 'time', 'different', ',', 'voices', 'difference', '.', '\n', 'answer', 'spoken', 'young', 'old', ',', 'rich', 'poor', ',', 'Democrat', 'Republican', ',', 'black', ',', 'white', ',', 'Hispanic', ',', 'Asian', ',', 'Native', 'American', ',', 'gay', ',', 'straight', ',', 'disabled', 'disabled', '.', 'Americans', 'sent', 'message', 'world', 'collection', 'individuals', 'collection', 'red', 'states', 'blue', 'states', '.', '\n', ',', ',', 'United', 'States', 'America', '.', '\n', 'answer', 'led', 'told', 'long', 'cynical', 'fearful', 'doubtful', 'achieve', 'hands', 'arc', 'history', 'bend', 'hope', 'better', 'day', '.', '\n', 'long', 'time', 'coming', ',', 'tonight', ',', 'date', 'election', 'defining', 'moment', 'change', 'come', 'America', '.', '\n', '[', 'read', ']', '\n\n', 'start', 'money', 'endorsements', '.', 'campaign', 'hatched', 'halls', 'Washington', '.', 'began', 'backyards', 'Des', 'Moines', 'living', 'rooms', 'Concord', 'porches', 'Charleston', '.', 'built', 'working', 'men', 'women', 'dug', 'little', 'savings', '$', '5', '$', '10', '$', '20', 'cause', '.', '\n', 'grew', 'strength', 'young', 'people', 'rejected', 'myth', 'generation', 'apathy', 'left', 'homes', 'families', 'jobs', 'offered', 'little', 'pay', 'sleep', '.', '\n', 'drew', 'strength', '-', '-', 'young', 'people', 'braved', 'bitter', 'cold', 'scorching', 'heat', 'knock', 'doors', 'perfect', 'strangers', ',', 'millions', 'Americans', 'volunteered', 'organized', 'proved', 'centuries', 'later', 'government', 'people', ',', 'people', ',', 'people', 'perished', 'Earth', '.', '\n', 'victory', '.', '\n', 'know', 'win', 'election', '.', 'know', '.', '\n', 'understand', 'enormity', 'task', 'lies', 'ahead', '.', 'celebrate', 'tonight', ',', 'know', 'challenges', 'tomorrow', 'bring', 'greatest', 'lifetime', '—', 'wars', ',', 'planet', 'peril', ',', 'worst', 'financial', 'crisis', 'century', '.', '\n', 'stand', 'tonight', ',', 'know', 'brave', 'Americans', 'waking', 'deserts', 'Iraq', 'mountains', 'Afghanistan', 'risk', 'lives', '.', '\n', 'mothers', 'fathers', 'lie', 'awake', 'children', 'fall', 'asleep', 'wonder', 'mortgage', 'pay', 'doctors', '’', 'bills', 'save', 'child', 'college', 'education', '.', '\n', 'new', 'energy', 'harness', ',', 'new', 'jobs', 'created', ',', 'new', 'schools', 'build', ',', 'threats', 'meet', ',', 'alliances', 'repair', '.', '\n', 'road', 'ahead', 'long', '.', 'climb', 'steep', '.', 'year', 'term', '.', ',', 'America', ',', 'hopeful', 'tonight', '.', '\n', 'promise', ',', 'people', '.', '\n', 'setbacks', 'false', 'starts', '.', 'wo', 'agree', 'decision', 'policy', 'president', '.', 'know', 'government', 'solve', 'problem', '.', '\n', 'honest', 'challenges', 'face', '.', 'listen', ',', 'especially', 'disagree', '.', ',', ',', 'ask', 'join', 'work', 'remaking', 'nation', ',', 'way', 'America', '221', 'years', '—', 'block', 'block', ',', 'brick', 'brick', ',', 'calloused', 'hand', 'calloused', 'hand', '.', '\n', 'began', '21', 'months', 'ago', 'depths', 'winter', 'end', 'autumn', 'night', '.', '\n', 'victory', 'change', 'seek', '.', 'chance', 'change', '.', 'happen', 'way', 'things', '.', '\n', 'happen', ',', 'new', 'spirit', 'service', ',', 'new', 'spirit', 'sacrifice', '.', '\n', 'let', 'summon', 'new', 'spirit', 'patriotism', ',', 'responsibility', ',', 'resolves', 'pitch', 'work', 'harder', 'look', '.', '\n', 'Let', 'remember', ',', 'financial', 'crisis', 'taught', ',', 'thriving', 'Wall', 'Street', 'Main', 'Street', 'suffers', '.', '\n', 'country', ',', 'rise', 'fall', 'nation', ',', 'people', '.', 'Let', 'resist', 'temptation', 'fall', 'partis ...

# %% [markdown]
# <b>Incluye aquí, debajo de la línea, la explicación de tu respuesta</b>
# <hr>

# %% [markdown]
# Se carga la libreria de palabras que spacy considera stop words (palabras sin aporte al procesamiento del NLP) y se itera por cada token que no esté dentro de la libreria STOP_WORDS añadiendolo a la variable tokens_sin_stop_words

# %% [markdown]
# <span style="font-size: 14pt; font-weight: bold; color: #0098cd;">Pregunta 6.</span>
# <span style="font-size: 14pt; font-weight: bold; color: #0098cd;">¿Qué atributo del token contiene la etiqueta NER?</span>

# %%
for token in doc:
    print(token.text, token.ent_type_)
# Out:
# “
# Hello
# ,
# Chicago GPE
# .
#
#
# If
# there
# is
# anyone
# out
# there
# who
# still
# doubts
# that
# America GPE
# is
# a
# place
# where
# all
# things
# are
# possible
# ,
# who
# still
# wonders
# if
# the
# dream
# of
# our
# founders
# is
# alive
# in
# our
# time
# ,
# who
# still
# questions
# the
# power
# of
# our
# democracy
# ,
# tonight TIME
# is
# your
# answer
# .
#
#
# It
# ’s
# the
# answer
# told
# by
# lines
# that
# stretched
# around
# schools
# and
# churches
# in
# numbers
# this
# nation
# has
# never
# seen
# ,
# by
# people
# who
# waited
# three TIME
# hours TIME
# and
# four TIME
# hours TIME
# ,
# many
# for
# the
# first ORDINAL
# time
# in
# their
# lives
# ,
# because
# they
# believed
# that
# this
# time
# must
# be
# different
# ,
# that
# their
# voices
# could
# be
# that
# difference
# .
#
#
# It
# ’s
# the
# answer
# spoken
# by
# young
# and
# old
# ,
# rich
# and
# poor
# ,
# Democrat NORP
# and
# Republican NORP
# ,
# black
# ,
# white
# ,
# Hispanic NORP
# ,
# Asian NORP
# ,
# Native NORP
# American NORP
# ,
# gay
# ,
# straight
# ,
# disabled
# and
# not
# disabled
# .
# Americans NORP
# who
# sent
# a
# message
# to
# the
# world
# that
# we
# have
# never
# been
# just
# a
# collection
# of
# individuals
# or
# a
# collection
# of
# red
# states
# and
# blue
# states
# .
#
#
# We
# are
# ,
# and
# always
# will
# be
# ,
# the GPE
# United GPE
# States GPE
# of GPE
# America GPE
# .
#
#
# It
# ’s
# the
# answer
# that
# led
# those
# who
# ’ve
# been
# told
# for
# so
# long
# by
# so
# many
# to
# be
# cynical
# and
# fearful
# and
# doubtful
# about
# what
# we
# can
# achieve
# to
# put
# their
# hands
# on
# the
# arc
# of
# history
# and
# bend
# it
# once
# more
# toward
# the
# hope
# of
# a
# better
# day
# .
#
#
# It
# ’s
# been
# a
# long
# time
# coming
# ,
# but
# tonight TIME
# ,
# because
# of
# what
# we
# did
# on
# this
# date
# in
# this
# election
# at
# this
# defining
# moment
# change
# has
# come
# to
# America GPE
# .
#
#
# [
# read
# more
# ]
#
#
#
# We
# did
# n’t
# start
# with
# much
# money
# or
# many
# endorsements
# .
# Our
# campaign
# was
# not
# hatched
# in
# the
# halls
# of
# Washington GPE
# .
# It
# began
# in
# the
# backyards
# of
# Des GPE
# Moines GPE
# and
# the
# living
# rooms
# of
# Concord GPE
# and
# the
# front
# porches
# of
# Charleston GPE
# .
# It
# was
# built
# by
# working
# men
# and
# women
# who
# dug
# into
# what
# little
# savings
# they
# had
# to
# give
# $ MONEY
# 5 MONEY
# and MONEY
# $ MONEY
# 10 MONEY
# and MONEY
# $ MONEY
# 20 MONEY
# to
# the
# cause
# .
#
#
# It
# grew
# strength
# from
# the
# young
# people
# who
# rejected
# the
# myth
# of
# their
# generation
# ’s
# apathy
# who
# left
# their
# homes
# and
# their
# families
# for
# jobs
# that
# offered
# little
# pay
# and
# less
# sleep
# .
#
#
# It
# drew
# strength
# from
# the
# not
# -
# so
# -
# young
# people
# who
# braved
# the
# bitter
# cold
# and
# scorching
# heat
# to
# knock
# on
# doors
# of
# perfect
# strangers
# ,
# and
# from
# the
# millions CARDINAL
# of
# Americans NORP
# who
# volunteered
# and
# organized
# and
# proved
# that
# more DATE
# than DATE
# two DATE
# centuries DATE
# later DATE
# a
# government
# of
# the
# people
# ,
# by
# the
# people
# ,
# and
# for
# the
# people
# has
# not
# perished
# from
# the
# Earth LOC
# .
#
#
# This
# is
# your
# victory
# .
#
#
# And
# I
# know
# you
# did
# n’t
# do
# this
# just
# to
# win
# an
# election
# .
# And
# I
# know
# you
# did
# n’t
# do
# it
# for
# me
# .
#
#
# You
# did
# it
# because
# you
# understand
# the
# enormity
# of
# the
# task
# that
# lies
# ahead
# .
# For
# even
# as
# we
# celebrate
# tonight TIME
# ,
# we
# know
# the
# challenges
# that
# tomorrow DATE
# will
# bring
# are
# the
# greatest
# of
# our
# lifetime
# —
# two CARDINAL
# wars
# ,
# a
# planet
# in
# peril
# ,
# the
# worst
# financial
# crisis
# in
# a DATE
# century DATE
# .
#
#
# Even
# as
# we
# stand
# here
# tonight TIME
# ,
# we
# know
# there
# are
# brave
# Americans NORP
# waking
# up
# in
# the
# deserts
# of
# Iraq GPE
# and
# the
# mountains
# of
# Afghanistan GPE
# to
# risk
# their
# lives
# for
# us
# .
#
#
# There
# are
# mothers
# and
# fathers
# who
# will
# lie
# awake
# after
# the
# children
# fall
# asleep
# and
# wonder
# how
# they
# ’ll
# make
# the
# mortgage
# or
# pay
# their
# doctors
# ’
# bills
# or
# save
# enough
# for
# their
# child
# ’s
# college
# education
# .
#
#
# There
# ’s
# new
# energy
# to
# harness
# ,
# new
# jobs
# to
# be
# created
# ,
# new
# schools
# to
# build
# ,
# and
# threats
# to
# meet
# ,
# alliances
# to
# repair
# .
#
#
# The
# road
# ahead
# will
# be
# long
# .
# Our
# climb
# will
# be
# steep
# .
# We
# may
# not
# get
# there
# in
# one DATE
# year DATE
# or
# even
# in
# one CARDINAL
# term
# .
# But
# ,
# America GPE
# ,
# I
# have
# never
# been
# more
# hopeful
# than
# I
# am
# tonight TIME
# that
# we
# will
# get
# there
# .
#
#
# I
# promise
# you
# ,
# we
# as
# a
# people
# will
# get
# there
# .
#
#
# There
# will
# be
# setbacks
# and
# false
# starts
# .
# There
# are
# many
# who
# wo
# n’t
# agree
# with
# every
# decision
# or
# policy
# I
# make
# as
# president
# .
# And
# we
# know
# the
# government
# ca
# n’t
# solve
# every
# problem
# .
#
#
# But
# I
# will
# always
# be
# honest
# with
# you
# about
# the
# challenges
# we
# face
# .
# I
# will
# listen
# to
# you
# ,
# especially
# when
# we
# disagree
# .
# And
# ,
# above
# all
# ,
# I
# will
# ask
# you
# to
# join
# in
# the
# work
# of
# remaking
# this
# nation
# ,
# the
# only
# way
# it
# ’s
# been
# done
# in
# America GPE
# for
# 221 DATE
# years DATE
# —
# block
# by
# block
# ,
# brick
# by
# brick
# ,
# calloused
# hand
# by
# calloused
# hand
# .
#
#
# What
# began
# 21 DATE
# months DATE
# ago DATE
# in
# the
# depths
# of
# winter DATE
# can
# not
# end
# on
# this TIME
# autumn TIME
# night TIME
# .
#
#
# This
# victory
# alone
# is
# not
# the
# change
# we
# seek
# .
# It
# is
# only
# the
# chance
# for
# us
# to
# make
# that
# change
# .
# And
# that
# can
# not
# happen
# if
# we
# go
# back
# to
# the
# way
# things
# were
# .
#
#
# It
# ca
# n’t
# happen
# without
# you
# ,
# without
# a
# new
# spirit
# of
# service
# ,
# a
# new
# spirit
# of
# sacrifice
# .
#
#
# So
# let
# us
# summon
# a
# new
# spirit
# of
# patriotism
# ,
# of
# responsibility
# ,
# where
# each
# of
# us
# resolves
# to
# pitch
# in
# and
# work
# harder
# and
# look
# after
# not
# only
# ourselves
# but
# each
# other
# .
#
#
# Let
# us
# remember
# that
# ,
# if
# this
# financial
# crisis
# taught
# us
# anything
# ,
# it
# ’s
# that
# we
# can
# not
# have
# a
# thriving
# Wall
# Street
# while
# Main FAC
# Street FAC
# suffers
# .
#
#
# In
# this
# country
# ,
# we
# rise
# or
# fall
# as
# one CARDINAL
# nation
# ,
# as
# one CARDINAL
# people
# .
# Let
# ’s
# resist
# the
# temptation
# to
# fall
# back
# on
# the
# same
# partisanship
# and
# pettiness
# and
# immaturity
# that
# has
# poisoned
# our
# politics
# for
# so
# long
# .
#
#
# Let
# ’s
# remember
# that
# it
# was
# a
# man
# from
# this
# state
# who
# first ORDINAL
# carried
# the
# banner
# of
# the ORG
# Republican ORG
# Party ORG
# to
# the ORG
# White ORG
# House ORG
# ,
# a
# party
# founded
# on
# the
# values
# of
# self
# -
# reliance
# and
# individual
# liberty
# and
# national
# unity
# .
#
#
# Those
# are
# values
# that
# we
# all
# share
# .
# And
# while
# the ORG
# Democratic ORG
# Party ORG
# has
# won
# a
# great
# victory
# tonight TIME
# ,
# we
# do
# so
# with
# a
# measure
# of
# humility
# and
# determination
# to
# heal
# the
# divides
# that
# have
# held
# back
# our
# progress
# .
#
#
# As
# Lincoln ORG
# said
# to
# a
# nation
# far
# more
# divided
# than
# ours
# ,
# we
# are
# not
# enemies
# but
# friends
# .
# Though
# passion
# may
# have
# strained
# ,
# it
# must
# not
# break
# our
# bonds
# of
# affection
# .
#
#
# And
# to
# those
# Americans NORP
# whose
# support
# I
# have
# yet
# to
# earn
# ,
# I
# may
# not
# have
# won
# your
# vote
# tonight TIME
# ,
# but
# I
# hear
# your
# voices
# .
# I
# need
# your
# help
# .
# And
# I
# will
# be
# your
# president
# ,
# too
# .
#
#
# And
# to
# all
# those
# watching
# tonight TIME
# from
# beyond
# our
# shores
# ,
# from
# parliaments
# and
# palaces
# ,
# to
# those
# who
# are
# huddled
# around
# radios
# in
# the
# forgotten
# corners
# of
# the
# world
# ,
# our
# stories
# are
# singular
# ,
# but
# our
# destiny
# is
# shared
# ,
# and
# a
# new
# dawn
# of
# American NORP
# leadership
# is
# at
# hand
# .
#
#
# To
# those
# —
# to
# those
# who
# would
# tear
# the
# world
# down
# :
# We
# will
# defeat
# you
# .
# To
# those
# who
# seek
# peace
# and
# security
# :
# We
# support
# you
# .
# And
# to
# all
# those
# who
# have
# wondered
# if
# America GPE
# ’s
# beacon
# still
# burns
# as
# bright
# :
# Tonight TIME
# we
# proved
# once
# more
# that
# the
# true
# strength
# of
# our
# nation
# comes
# not
# from
# the
# might
# of
# our
# arms
# or
# the
# scale
# of
# our
# wealth
# ,
# but
# from
# the
# enduring
# power
# of
# our
# ideals
# :
# democracy
# ,
# liberty
# ,
# opportunity
# and
# unyielding
# hope
# .
#
#
# That
# ’s
# the
# true
# genius
# of
# America GPE
# :
# that
# America GPE
# can
# change
# .
# Our
# union
# can
# be
# perfected
# .
# What
# we
# ’ve
# already
# achieved
# gives
# us
# hope
# for
# what
# we
# can
# and
# must
# achieve
# tomorrow DATE
# .
#
#
# This
# election
# had
# many
# firsts
# and
# many
# stories
# that
# will
# be
# told
# for
# generations
# .
# But
# one
# that
# ’s
# on
# my
# mind
# tonight TIME
# ’s
# about
# a
# woman
# who
# cast
# her
# ballot
# in
# Atlanta GPE
# .
# She
# ’s
# a
# lot
# like
# the
# millions CARDINAL
# of
# others
# who
# stood
# in
# line
# to
# make
# their
# voice
# heard
# in
# this
# election
# except
# for
# one CARDINAL
# thing
# :
# Ann PERSON
# Nixon PERSON
# Cooper PERSON
# is
# 106 DATE
# years DATE
# old DATE
# .
#
#
# She
# was
# born
# just
# a
# generation
# past
# slavery
# ;
# a
# time
# when
# there
# were
# no
# cars
# on
# the
# road
# or
# planes
# in
# the
# sky
# ;
# when
# someone
# like
# her
# could
# n’t
# vote
# for
# two CARDINAL
# reasons
# —
# because
# she
# was
# a
# woman
# and
# because
# of
# the
# color
# of
# her
# skin
# .
#
#
# And
# tonight TIME
# ,
# I
# think
# about
# all
# that
# she
# ’s
# seen
# throughout
# her
# century
# in
# America GPE
# —
# the
# heartache
# and
# the
# hope
# ;
# the
# struggle
# and
# the
# progress
# ;
# the
# times
# we
# were
# told
# that
# we
# ca
# n’t
# ,
# and
# the
# people
# who
# pressed
# on
# with
# that
# American NORP
# creed
# :
# Yes
# we
# can
# .
#
#
# At
# a
# time
# when
# women
# ’s
# voices
# were
# silenced
# and
# their
# hopes
# dismissed
# ,
# she
# lived
# to
# see
# them
# stand
# up
# and
# speak
# out
# and
# reach
# for
# the
# ballot
# .
# Yes
# we
# can
# .
#
#
# When
# there
# was
# despair
# in
# the
# dust
# bowl
# and
# depression
# across
# the
# land
# ,
# she
# saw
# a
# nation
# conquer
# fear
# itself
# with
# a
# New
# Deal
# ,
# new
# jobs
# ,
# a
# new
# sense
# of
# common
# purpose
# .
# Yes
# we
# can
# .
#
#
# When
# the
# bombs
# fell
# on
# our
# harbor
# and
# tyranny
# threatened
# the
# world
# ,
# she
# was
# there
# to
# witness
# a
# generation
# rise
# to
# greatness
# and
# a
# democracy
# was
# saved
# .
# Yes
# we
# can
# .
#
#
# She
# was
# there
# for
# the
# buses
# in
# Montgomery ORG
# ,
# the
# hoses
# in
# Birmingham GPE
# ,
# a
# bridge
# in
# Selma GPE
# ,
# and
# a
# preacher
# from
# Atlanta GPE
# who
# told
# a
# people
# that
# “
# We
# Shall
# Overcome
# .
# ”
# Yes
# we
# can
# .
#
#
# A
# man
# touched
# down
# on
# the LOC
# moon LOC
# ,
# a
# wall
# came
# down
# in
# Berlin GPE
# ,
# a
# world
# was
# connected
# by
# our
# own
# science
# and
# imagination
# .
#
#
# And
# this DATE
# year DATE
# ,
# in
# this
# election
# ,
# she
# touched
# her
# finger
# to
# a
# screen
# ,
# and
# cast
# her
# vote
# ,
# because
# after
# 106 DATE
# years DATE
# in
# America GPE
# ,
# through
# the
# best
# of
# times
# and
# the
# darkest
# of
# hours TIME
# ,
# she
# knows
# how
# America GPE
# can
# change
# .
#
#
# Yes
# we
# can
# .
#
#
# America GPE
# ,
# we
# have
# come
# so
# far
# .
# We
# have
# seen
# so
# much
# .
# But
# there
# is
# so
# much
# more
# to
# do
# .
# So
# tonight TIME
# ,
# let
# us
# ask
# ourselves
# —
# if
# our
# children
# should
# live
# to
# see
# the DATE
# next DATE
# century DATE
# ;
# if
# my
# daughters
# should
# be
# so
# lucky
# to
# live
# as
# long
# as
# Ann PERSON
# Nixon PERSON
# Cooper PERSON
# ,
# what
# change
# will
# they
# see
# ?
# What
# progress
# will
# we
# have
# made
# ?
#
#
# This
# is
# our
# chance
# to
# answer
# that
# call
# .
# This
# is
# our
# moment
# .
#
#
# This
# is
# our
# time
# ,
# to
# put
# our
# people
# back
# to
# work
# and
# open
# doors
# of
# opportunity
# for
# our
# kids
# ;
# to
# restore
# prosperity
# and
# promote
# the
# cause
# of
# peace
# ;
# to
# reclaim
# the
# American NORP
# dream
# and
# reaffirm
# that
# fundamental
# truth
# ,
# that
# ,
# out
# of
# many
# ,
# we
# are
# one
# ;
# that
# while
# we
# breathe
# ,
# we
# hope
# .
# And
# where
# we
# are
# met
# with
# cynicism
# and
# doubts
# and
# those
# who
# tell
# us
# that
# we
# ca
# n’t
# ,
# we
# will
# respond
# with
# that
# timeless
# creed
# that
# sums
# up
# the
# spirit
# of
# a
# people
# :
# Yes
# ,
# we
# can
# .
# [

# %% [markdown]
# <b>Incluye aquí, debajo de la línea, la explicación de tu respuesta</b>
# <hr>

# %% [markdown]
# El atributo es ent_type_, en el código muestro la etiqueta NER de cada token con un bucle for. Cuando el token no tiene etiqueta NER aparece vacio el string

# %% [markdown]
# <span style="font-size: 14pt; font-weight: bold; color: #0098cd;">Pregunta 7.</span>
# <span style="font-size: 14pt; font-weight: bold; color: #0098cd;">¿Qué entidades nombradas soporta Spacy?, ¿Qué significa cada una?</span>
#
# <b>Nota</b>: Debes escribir el código que liste las entidades disponibles y la explicación de las mismas. El listado sin código se considerará respuesta incompleta.

# %%
for ent in doc.ents:
        print(f"Entidad: {ent.text}, Tipo: {ent.label_}, Explicación: {spacy.explain(ent.label_)}")
# Out:
# Entidad: Chicago, Tipo: GPE, Explicación: Countries, cities, states
# Entidad: America, Tipo: GPE, Explicación: Countries, cities, states
# Entidad: tonight, Tipo: TIME, Explicación: Times smaller than a day
# Entidad: three hours, Tipo: TIME, Explicación: Times smaller than a day
# Entidad: four hours, Tipo: TIME, Explicación: Times smaller than a day
# Entidad: first, Tipo: ORDINAL, Explicación: "first", "second", etc.
# Entidad: Democrat, Tipo: NORP, Explicación: Nationalities or religious or political groups
# Entidad: Republican, Tipo: NORP, Explicación: Nationalities or religious or political groups
# Entidad: Hispanic, Tipo: NORP, Explicación: Nationalities or religious or political groups
# Entidad: Asian, Tipo: NORP, Explicación: Nationalities or religious or political groups
# Entidad: Native American, Tipo: NORP, Explicación: Nationalities or religious or political groups
# Entidad: Americans, Tipo: NORP, Explicación: Nationalities or religious or political groups
# Entidad: the United States of America, Tipo: GPE, Explicación: Countries, cities, states
# Entidad: tonight, Tipo: TIME, Explicación: Times smaller than a day
# Entidad: America, Tipo: GPE, Explicación: Countries, cities, states
# Entidad: Washington, Tipo: GPE, Explicación: Countries, cities, states
# Entidad: Des Moines, Tipo: GPE, Explicación: Countries, cities, states
# Entidad: Concord, Tipo: GPE, Explicación: Countries, cities, states
# Entidad: Charleston, Tipo: GPE, Explicación: Countries, cities, states
# Entidad: $5 and $10 and $20, Tipo: MONEY, Explicación: Monetary values, including unit
# Entidad: millions, Tipo: CARDINAL, Explicación: Numerals that do not fall under another type
# Entidad: Americans, Tipo: NORP, Explicación: Nationalities or religious or political groups
# Entidad: more than two centuries later, Tipo: DATE, Explicación: Absolute or relative dates or periods
# Entidad: Earth, Tipo: LOC, Explicación: Non-GPE locations, mountain ranges, bodies of water
# Entidad: tonight, Tipo: TIME, Explicación: Times smaller than a day
# Entidad: tomorrow, Tipo: DATE, Explicación: Absolute or relative dates or periods
# Entidad: two, Tipo: CARDINAL, Explicación: Numerals that do not fall under another type
# Entidad: a century, Tipo: DATE, Explicación: Absolute or relative dates or periods
# Entidad: tonight, Tipo: TIME, Explicación: Times smaller than a day
# Entidad: Americans, Tipo: NORP, Explicación: Nationalities or religious or political groups
# Entidad: Iraq, Tipo: GPE, Explicación: Countries, cities, states
# Entidad: Afghanistan, Tipo: GPE, Explicación: Countries, cities, states
# Entidad: one year, Tipo: DATE, Explicación: Absolute or relative dates or periods
# Entidad: one, Tipo: CARDINAL, Explicación: Numerals that do not fall under another type
# Entidad: America, Tipo: GPE, Explicación: Countries, cities, states
# Entidad: tonight, Tipo: TIME, Explicación: Times smaller than a day
# Entidad: America, Tipo: GPE, Explicación: Countries, cities, states
# Entidad: 221 years, Tipo: DATE, Explicación: Absolute or relative dates or periods
# Entidad: 21 months ago, Tipo: DATE, Explicación: Absolute or relative dates or periods
# Entidad: winter, Tipo: DATE, Explicación: Absolute or relative dates or periods
# Entidad: this autumn night, Tipo: TIME, Explicación: Times smaller than a day
# Entidad: Main Street, Tipo: FAC, Explicación: Buildings, airports, highways, bridges, etc.
# Entidad: one, Tipo: CARDINAL, Explicación: Numerals that do not fall under another type
# Entidad: one, Tipo: CARDINAL, Explicación: Numerals that do not fall under another type
# Entidad: first, Tipo: ORDINAL, Explicación: "first", "second", etc.
# Entidad: the Republican Party, Tipo: ORG, Explicación: Companies, agencies, institutions, etc.
# Entidad: the White House, Tipo: ORG, Explicación: Companies, agencies, institutions, etc.
# Entidad: the Democratic Party, Tipo: ORG, Explicación: Companies, agencies, institutions, etc.
# Entidad: tonight, Tipo: TIME, Explicación: Times smaller than a day
# Entidad: Lincoln, Tipo: ORG, Explicación: Companies, agencies, institutions, etc.
# Entidad: Americans, Tipo: NORP, Explicación: Nationalities or religious or political groups
# Entidad: tonight, Tipo: TIME, Explicación: Times smaller than a day
# Entidad: tonight, Tipo: TIME, Explicación: Times smaller than a day
# Entidad: American, Tipo: NORP, Explicación: Nationalities or religious or political groups
# Entidad: America, Tipo: GPE, Explicación: Countries, cities, states
# Entidad: Tonight, Tipo: TIME, Explicación: Times smaller than a day
# Entidad: America, Tipo: GPE, Explicación: Countries, cities, states
# Entidad: America, Tipo: GPE, Explicación: Countries, cities, states
# Entidad: tomorrow, Tipo: DATE, Explicación: Absolute or relative dates or periods
# Entidad: tonight, Tipo: TIME, Explicación: Times smaller than a day
# Entidad: Atlanta, Tipo: GPE, Explicación: Countries, cities, states
# Entidad: millions, Tipo: CARDINAL, Explicación: Numerals that do not fall under another type
# Entidad: one, Tipo: CARDINAL, Explicación: Numerals that do not fall under another type
# Entidad: Ann Nixon Cooper, Tipo: PERSON, Explicación: People, including fictional
# Entidad: 106 years old, Tipo: DATE, Explicación: Absolute or relative dates or periods
# Entidad: two, Tipo: CARDINAL, Explicación: Numerals that do not fall under another type
# Entidad: tonight, Tipo: TIME, Explicación: Times smaller than a day
# Entidad: America, Tipo: GPE, Explicación: Countries, cities, states
# Entidad: American, Tipo: NORP, Explicación: Nationalities or religious or political groups
# Entidad: Montgomery, Tipo: ORG, Explicación: Companies, agencies, institutions, etc.
# Entidad: Birmingham, Tipo: GPE, Explicación: Countries, cities, states
# Entidad: Selma, Tipo: GPE, Explicación: Countries, cities, states
# Entidad: Atlanta, Tipo: GPE, Explicación: Countries, cities, states
# Entidad: the moon, Tipo: LOC, Explicación: Non-GPE locations, mountain ranges, bodies of water
# Entidad: Berlin, Tipo: GPE, Explicación: Countries, cities, states
# Entidad: this year, Tipo: DATE, Explicación: Absolute or relative dates or periods
# Entidad: 106 years, Tipo: DATE, Explicación: Absolute or relative dates or periods
# Entidad: America, Tipo: GPE, Explicación: Countries, cities, states
# Entidad: hours, Tipo: TIME, Explicación: Times smaller than a day
# Entidad: America, Tipo: GPE, Explicación: Countries, cities, states
# Entidad: America, Tipo: GPE, Explicación: Countries, cities, states
# Entidad: tonight, Tipo: TIME, Explicación: Times smaller than a day
# Entidad: the next century, Tipo: DATE, Explicación: Absolute or relative dates or periods
# Entidad: Ann Nixon Cooper, Tipo: PERSON, Explicación: People, including fictional
# Entidad: American, Tipo: NORP, Explicación: Nationalities or religious or political groups

# %% [markdown]
# <b>Incluye aquí, debajo de la línea, la explicación de tu respuesta</b>
# <hr>

# %% [markdown]
# El código muestra como se itera sobra las entidades y se obtienen las que hay en el texto (text_) junto con su tipo (label_) y su explicación (spacy.explain(label_)

# %% [markdown]
# <span style="font-size: 14pt; font-weight: bold; color: #0098cd;">Pregunta 8.</span>
# <span style="font-size: 14pt; font-weight: bold; color: #0098cd;">¿Qué entidades nombradas diferentes son reconocidas en el texto?, ¿cuántas hay de cada tipo?</span>

# %%
# Diccionario para almacenar el recuento de cada tipo de entidad + 1
entity_count = {}

# Itera sobre las entidades nombradas y cuenta cuántas hay de cada tipo
for ent in doc.ents:
    entity_label = ent.label_
    entity_count[entity_label] = entity_count.get(entity_label, 0) + 1

# Imprime el recuento de cada tipo de entidad
print("Entidades nombradas y su recuento:")
for label, count in entity_count.items():
    print(f"{label}: {count}")
# Out:
# Entidades nombradas y su recuento:
# GPE: 24
# TIME: 16
# ORDINAL: 2
# NORP: 12
# MONEY: 1
# CARDINAL: 8
# DATE: 12
# LOC: 2
# FAC: 1
# ORG: 5
# PERSON: 2

# %% [markdown]
# <b>Incluye aquí, debajo de la línea, la explicación de tu respuesta</b>
# <hr>

# %% [markdown]
# Creo un diccionario para almacenar cuantas entidades hay de cada tipo, con ello itero en cada entidad y subo el contador + 1 por cada una repetida. Una vez obtenidas, se imprime en el output las entidades con el recuento total de cada una de ellas.

# %% [markdown]
# <span style="font-size: 14pt; font-weight: bold; color: #0098cd;">Pregunta 9.</span>
# <span style="font-size: 14pt; font-weight: bold; color: #0098cd;">Explica con tus palabras qué es el código IOB para el reconocimiento de entiedades. Pon un ejemplo, sacado del texto, de una etiqueta de un único token y una etiqueta compuesta por varios tokens.</span>

# %%
# Obtiene las etiquetas IOB para cada token
iob_labels = [(token.text, token.ent_iob_, token.ent_type_) for token in doc]

# Saca en el ouptut las etiquetas IOB para cada token
print("Token       | Etiqueta IOB")
print("---------------------------")
for token, iob, ent_type in iob_labels:
    print(f"{token.ljust(11)}| {iob}-{ent_type if ent_type else 'O'}")
# Out:
# Token       | Etiqueta IOB
# ---------------------------
# “          | O-O
# Hello      | O-O
# ,          | O-O
# Chicago    | B-GPE
# .          | O-O
#
#           | O-O
# If         | O-O
# there      | O-O
# is         | O-O
# anyone     | O-O
# out        | O-O
# there      | O-O
# who        | O-O
# still      | O-O
# doubts     | O-O
# that       | O-O
# America    | B-GPE
# is         | O-O
# a          | O-O
# place      | O-O
# where      | O-O
# all        | O-O
# things     | O-O
# are        | O-O
# possible   | O-O
# ,          | O-O
# who        | O-O
# still      | O-O
# wonders    | O-O
# if         | O-O
# the        | O-O
# dream      | O-O
# of         | O-O
# our        | O-O
# founders   | O-O
# is         | O-O
# alive      | O-O
# in         | O-O
# our        | O-O
# time       | O-O
# ,          | O-O
# who        | O-O
# still      | O-O
# questions  | O-O
# the        | O-O
# power      | O-O
# of         | O-O
# our        | O-O
# democracy  | O-O
# ,          | O-O
# tonight    | B-TIME
# is         | O-O
# your       | O-O
# answer     | O-O
# .          | O-O
#
#           | O-O
# It         | O-O
# ’s         | O-O
# the        | O-O
# answer     | O-O
# told       | O-O
# by         | O-O
# lines      | O-O
# that       | O-O
# stretched  | O-O
# around     | O-O
# schools    | O-O
# and        | O-O
# churches   | O-O
# in         | O-O
# numbers    | O-O
# this       | O-O
# nation     | O-O
# has        | O-O
# never      | O-O
# seen       | O-O
# ,          | O-O
# by         | O-O
# people     | O-O
# who        | O-O
# waited     | O-O
# three      | B-TIME
# hours      | I-TIME
# and        | O-O
# four       | B-TIME
# hours      | I-TIME
# ,          | O-O
# many       | O-O
# for        | O-O
# the        | O-O
# first      | B-ORDINAL
# time       | O-O
# in         | O-O
# their      | O-O
# lives      | O-O
# ,          | O-O
# because    | O-O
# they       | O-O
# believed   | O-O
# that       | O-O
# this       | O-O
# time       | O-O
# must       | O-O
# be         | O-O
# different  | O-O
# ,          | O-O
# that       | O-O
# their      | O-O
# voices     | O-O
# could      | O-O
# be         | O-O
# that       | O-O
# difference | O-O
# .          | O-O
#
#           | O-O
# It         | O-O
# ’s         | O-O
# the        | O-O
# answer     | O-O
# spoken     | O-O
# by         | O-O
# young      | O-O
# and        | O-O
# old        | O-O
# ,          | O-O
# rich       | O-O
# and        | O-O
# poor       | O-O
# ,          | O-O
# Democrat   | B-NORP
# and        | O-O
# Republican | B-NORP
# ,          | O-O
# black      | O-O
# ,          | O-O
# white      | O-O
# ,          | O-O
# Hispanic   | B-NORP
# ,          | O-O
# Asian      | B-NORP
# ,          | O-O
# Native     | B-NORP
# American   | I-NORP
# ,          | O-O
# gay        | O-O
# ,          | O-O
# straight   | O-O
# ,          | O-O
# disabled   | O-O
# and        | O-O
# not        | O-O
# disabled   | O-O
# .          | O-O
# Americans  | B-NORP
# who        | O-O
# sent       | O-O
# a          | O-O
# message    | O-O
# to         | O-O
# the        | O-O
# world      | O-O
# that       | O-O
# we         | O-O
# have       | O-O
# never      | O-O
# been       | O-O
# just       | O-O
# a          | O-O
# collection | O-O
# of         | O-O
# individuals| O-O
# or         | O-O
# a          | O-O
# collection | O-O
# of         | O-O
# red        | O-O
# states     | O-O
# and        | O-O
# blue       | O-O
# states     | O-O
# .          | O-O
#
#           | O-O
# We         | O-O
# are        | O-O
# ,          | O-O
# and        | O-O
# always     | O-O
# will       | O-O
# be         | O-O
# ,          | O-O
# the        | B-GPE
# United     | I-GPE
# States     | I-GPE
# of         | I-GPE
# America    | I-GPE
# .          | O-O
#
#           | O-O
# It         | O-O
# ’s         | O-O
# the        | O-O
# answer     | O-O
# that       | O-O
# led        | O-O
# those      | O-O
# who        | O-O
# ’ve        | O-O
# been       | O-O
# told       | O-O
# for        | O-O
# so         | O-O
# long       | O-O
# by         | O-O
# so         | O-O
# many       | O-O
# to         | O-O
# be         | O-O
# cynical    | O-O
# and        | O-O
# fearful    | O-O
# and        | O-O
# doubtful   | O-O
# about      | O-O
# what       | O-O
# we         | O-O
# can        | O-O
# achieve    | O-O
# to         | O-O
# put        | O-O
# their      | O-O
# hands      | O-O
# on         | O-O
# the        | O-O
# arc        | O-O
# of         | O-O
# history    | O-O
# and        | O-O
# bend       | O-O
# it         | O-O
# once       | O-O
# more       | O-O
# toward     | O-O
# the        | O-O
# hope       | O-O
# of         | O-O
# a          | O-O
# better     | O-O
# day        | O-O
# .          | O-O
#
#           | O-O
# It         | O-O
# ’s         | O-O
# been       | O-O
# a          | O-O
# long       | O-O
# time       | O-O
# coming     | O-O
# ,          | O-O
# but        | O-O
# tonight    | B-TIME
# ,          | O-O
# because    | O-O
# of         | O-O
# what       | O-O
# we         | O-O
# did        | O-O
# on         | O-O
# this       | O-O
# date       | O-O
# in         | O-O
# this       | O-O
# election   | O-O
# at         | O-O
# this       | O-O
# defining   | O-O
# moment     | O-O
# change     | O-O
# has        | O-O
# come       | O-O
# to         | O-O
# America    | B-GPE
# .          | O-O
#
#           | O-O
# [          | O-O
# read       | O-O
# more       | O-O
# ]          | O-O
#
#
#          | O-O
# We         | O-O
# did        | O-O
# n’t        | O-O
# start      | O-O
# with       | O-O
# much       | O-O
# money      | O-O
# or         | O-O
# many       | O-O
# endorsements| O-O
# .          | O-O
# Our        | O-O
# campaign   | O-O
# was        | O-O
# not        | O-O
# hatched    | O-O
# in         | O-O
# the        | O-O
# halls      | O-O
# of         | O-O
# Washington | B-GPE
# .          | O-O
# It         | O-O
# began      | O-O
# in         | O-O
# the        | O-O
# backyards  | O-O
# of         | O-O
# Des        | B-GPE
# Moines     | I-GPE
# and        | O-O
# the        | O-O
# living     | O-O
# rooms      | O-O
# of         | O-O
# Concord    | B-GPE
# and        | O-O
# the        | O-O
# front      | O-O
# porches    | O-O
# of         | O-O
# Charleston | B-GPE
# .          | O-O
# It         | O-O
# was        | O-O
# built      | O-O
# by         | O-O
# working    | O-O
# men        | O-O
# and        | O-O
# women      | O-O
# who        | O-O
# dug        | O-O
# into       | O-O
# what       | O-O
# little     | O-O
# savings    | O-O
# they       | O-O
# had        | O-O
# to         | O-O
# give       | O-O
# $          | B-MONEY
# 5          | I-MONEY
# and        | I-MONEY
# $          | I-MONEY
# 10         | I-MONEY
# and        | I-MONEY
# $          | I-MONEY
# 20         | I-MONEY
# to         | O-O
# the        | O-O
# cause      | O-O
# .          | O-O
#
#           | O-O
# It         | O-O
# grew       | O-O
# strength   | O-O
# from       | O-O
# the        | O-O
# young      | O-O
# people     | O-O
# who        | O-O
# rejected   | O-O
# the        | O-O
# myth       | O-O
# of         | O-O
# their      | O-O
# generation | O-O
# ’s         | O-O
# apathy     | O-O
# who        | O-O
# left       | O-O
# their      | O-O
# homes      | O-O
# and        | O-O
# their      | O-O
# families   | O-O
# for        | O-O
# jobs       | O-O
# that       | O-O
# offered    | O-O
# little     | O-O
# pay        | O-O
# and        | O-O
# less       | O-O
# sleep      | O-O
# .          | O-O
#
#           | O-O
# It         | O-O
# drew       | O-O
# strength   | O-O
# from       | O-O
# the        | O-O
# not        | O-O
# -          | O-O
# so         | O-O
# -          | O-O
# young      | O-O
# people     | O-O
# who        | O-O
# braved     | O-O
# the        | O-O
# bitter     | O-O
# cold       | O-O
# and        | O-O
# scorching  | O-O
# heat       | O-O
# to         | O-O
# knock      | O-O
# on         | O-O
# doors      | O-O
# of         | O-O
# perfect    | O-O
# strangers  | O-O
# ,          | O-O
# and        | O-O
# from       | O-O
# the        | O-O
# millions   | B-CARDINAL
# of         | O-O
# Americans  | B-NORP
# who        | O-O
# volunteered| O-O
# and        | O-O
# organized  | O-O
# and        | O-O
# proved     | O-O
# that       | O-O
# more       | B-DATE
# than       | I-DATE
# two        | I-DATE
# centuries  | I-DATE
# later      | I-DATE
# a          | O-O
# government | O-O
# of         | O-O
# the        | O-O
# people     | O-O
# ,          | O-O
# by         | O-O
# the        | O-O
# people     | O-O
# ,          | O-O
# and        | O-O
# for        | O-O
# the        | O-O
# people     | O-O
# has        | O-O
# not        | O-O
# perished   | O-O
# from       | O-O
# the        | O-O
# Earth      | B-LOC
# .          | O-O
#
#           | O-O
# This       | O-O
# is         | O-O
# your       | O-O
# victory    | O-O
# .          | O-O
#
#           | O-O
# And        | O-O
# I          | O-O
# know       | O-O
# you        | O-O
# did        | O-O
# n’t        | O-O
# do         | O-O
# this       | O-O
# just       | O-O
# to         | O-O
# win        | O-O
# an         | O-O
# election   | O-O
# .          | O-O
# And        | O-O
# I          | O-O
# know       | O-O
# you        | O-O
# did        | O-O
# n’t        | O-O
# do         | O-O
# it         | O-O
# for        | O-O
# me         | O-O
# .          | O-O
#
#           | O-O
# You        | O-O
# did        | O-O
# it         | O-O
# because    | O-O
# you        | O-O
# understand | O-O
# the        | O-O
# enormity   | O-O
# of         | O-O
# the        | O-O
# task       | O-O
# that       | O-O
# lies       | O-O
# ahead      | O-O
# .          | O-O
# For        | O-O
# even       | O-O
# as         | O-O
# we         | O-O
# celebrate  | O-O
# tonight    | B-TIME
# ,          | O-O
# we         | O-O
# know       | O-O
# the        | O-O
# challenges | O-O
# that       | O-O
# tomorrow   | B-DATE
# will       | O-O
# bring      | O-O
# are        | O-O
# the        | O-O
# greatest   | O-O
# of         | O-O
# our        | O-O
# lifetime   | O-O
# —          | O-O
# two        | B-CARDINAL
# wars       | O-O
# ,          | O-O
# a          | O-O
# planet     | O-O
# in         | O-O
# peril      | O-O
# ,          | O-O
# the        | O-O
# worst      | O-O
# financial  | O-O
# crisis     | O-O
# in         | O-O
# a          | B-DATE
# century    | I-DATE
# .          | O-O
#
#           | O-O
# Even       | O-O
# as         | O-O
# we         | O-O
# stand      | O-O
# here       | O-O
# tonight    | B-TIME
# ,          | O-O
# we         | O-O
# know       | O-O
# there      | O-O
# are        | O-O
# brave      | O-O
# Americans  | B-NORP
# waking     | O-O
# up         | O-O
# in         | O-O
# the        | O-O
# deserts    | O-O
# of         | O-O
# Iraq       | B-GPE
# and        | O-O
# the        | O-O
# mountains  | O-O
# of         | O-O
# Afghanistan| B-GPE
# to         | O-O
# risk       | O-O
# their      | O-O
# lives      | O-O
# for        | O-O
# us         | O-O
# .          | O-O
#
#           | O-O
# There      | O-O
# are        | O-O
# mothers    | O-O
# and        | O-O
# fathers    | O-O
# who        | O-O
# will       | O-O
# lie        | O-O
# awake      | O-O
# after      | O-O
# the        | O-O
# children   | O-O
# fall       | O-O
# asleep     | O-O
# and        | O-O
# wonder     | O-O
# how        | O-O
# they       | O-O
# ’ll        | O-O
# make       | O-O
# the        | O-O
# mortgage   | O-O
# or         | O-O
# pay        | O-O
# their      | O-O
# doctors    | O-O
# ’          | O-O
# bills      | O-O
# or         | O-O
# save       | O-O
# enough     | O-O
# for        | O-O
# their      | O-O
# child      | O-O
# ’s         | O-O
# college    | O-O
# education  | O-O
# .          | O-O
#
#           | O-O
# There      | O-O
# ’s         | O-O
# new        | O-O
# energy     | O-O
# to         | O-O
# harness    | O-O
# ,          | O-O
# new        | O-O
# jobs       | O-O
# to         | O-O
# be         | O-O
# created    | O-O
# ,          | O-O
# new        | O-O
# schools    | O-O
# to         | O-O
# build      | O-O
# ,          | O-O
# and        | O-O
# threats    | O-O
# to         | O-O
# meet       | O-O
# ,          | O-O
# alliances  | O-O
# to         | O-O
# repair     | O-O
# .          | O-O
#
#           | O-O
# The        | O-O
# road       | O-O
# ahead      | O-O
# will       | O-O
# be         | O-O
# long       | O-O
# .          | O-O
# Our        | O-O
# climb      | O-O
# will       | O-O
# be         | O-O
# steep      | O-O
# .          | O-O
# We         | O-O
# may        | O-O
# not        | O-O
# get        | O-O
# there      | O-O
# in         | O-O
# one        | B-DATE
# year       | I-DATE
# or         | O-O
# even       | O-O
# in         | O-O
# one        | B-CARDINAL
# term       | O-O
# .          | O-O
# But        | O-O
# ,          | O-O
# America    | B-GPE
# ,          | O-O
# I          | O-O
# have       | O-O
# never      | O-O
# been       | O-O
# more       | O-O
# hopeful    | O-O
# than       | O-O
# I          | O-O
# am         | O-O
# tonight    | B-TIME
# that       | O-O
# we         | O-O
# will       | O-O
# get        | O-O
# there      | O-O
# .          | O-O
#
#           | O-O
# I          | O-O
# promise    | O-O
# you        | O-O
# ,          | O-O
# we         | O-O
# as         | O-O
# a          | O-O
# people     | O-O
# will       | O-O
# get        | O-O
# there      | O-O
# .          | O-O
#
#           | O-O
# There      | O-O
# will       | O-O
# be         | O-O
# setbacks   | O-O
# and        | O-O
# false      | O-O
# starts     | O-O
# .          | O-O
# There      | O-O
# are        | O-O
# many       | O-O
# who        | O-O
# wo         | O-O
# n’t        | O-O
# agree      | O-O
# with       | O-O
# every      | O-O
# decision   | O-O
# or         | O-O
# policy     | O-O
# I          | O-O
# make       | O-O
# as         | O-O
# president  | O-O
# .          | O-O
# And        | O-O
# we         | O-O
# know       | O-O
# the        | O-O
# government | O-O
# ca         | O-O
# n’t        | O-O
# solve      | O-O
# every      | O-O
# problem    | O-O
# .          | O-O
#
#           | O-O
# But        | O-O
# I          | O-O
# will       | O-O
# always     | O-O
# be         | O-O
# honest     | O-O
# with       | O-O
# you        | O-O
# about      | O-O
# the        | O-O
# challenges | O-O
# we         | O-O
# face       | O-O
# .          | O-O
# I          | O-O
# will       | O-O
# listen     | O-O
# to         | O-O
# you        | O-O
# ,          | O-O
# especially | O-O
# when       | O-O
# we         | O-O
# disagree   | O-O
# .          | O-O
# And        | O-O
# ,          | O-O
# above      | O-O
# all        | O-O
# ,          | O-O
# I          | O-O
# will       | O-O
# ask        | O-O
# you        | O-O
# to         | O-O
# join       | O-O
# in         | O-O
# the        | O-O
# work       | O-O
# of         | O-O
# remaking   | O-O
# this       | O-O
# nation     | O-O
# ,          | O-O
# the        | O-O
# only       | O-O
# way        | O-O
# it         | O-O
# ’s         | O-O
# been       | O-O
# done       | O-O
# in         | O-O
# America    | B-GPE
# for        | O-O
# 221        | B-DATE
# years      | I-DATE
# —          | O-O
# block      | O-O
# by         | O-O
# block      | O-O
# ,          | O-O
# brick      | O-O
# by         | O-O
# brick      | O-O
# ,          | O-O
# calloused  | O-O
# hand       | O-O
# by         | O-O
# calloused  | O-O
# hand       | O-O
# .          | O-O
#
#           | O-O
# What       | O-O
# began      | O-O
# 21         | B-DATE
# months     | I-DATE
# ago        | I-DATE
# in         | O-O
# the        | O-O
# depths     | O-O
# of         | O-O
# winter     | B-DATE
# can        | O-O
# not        | O-O
# end        | O-O
# on         | O-O
# this       | B-TIME
# autumn     | I-TIME
# night      | I-TIME
# .          | O-O
#
#           | O-O
# This       | O-O
# victory    | O-O
# alone      | O-O
# is         | O-O
# not        | O-O
# the        | O-O
# change     | O-O
# we         | O-O
# seek       | O-O
# .          | O-O
# It         | O-O
# is         | O-O
# only       | O-O
# the        | O-O
# chance     | O-O
# for        | O-O
# us         | O-O
# to         | O-O
# make       | O-O
# that       | O-O
# change     | O-O
# .          | O-O
# And        | O-O
# that       | O-O
# can        | O-O
# not        | O-O
# happen     | O-O
# if         | O-O
# we         | O-O
# go         | O-O
# back       | O-O
# to         | O-O
# the        | O-O
# way        | O-O
# things     | O-O
# were       | O-O
# .          | O-O
#
#           | O-O
# It         | O-O
# ca         | O-O
# n’t        | O-O
# happen     | O-O
# without    | O-O
# you        | O-O
# ,          | O-O
# without    | O-O
# a          | O-O
# new        | O-O
# spirit     | O-O
# of         | O-O
# service    | O-O
# ,          | O-O
# a          | O-O
# new        | O-O
# spirit     | O-O
# of         | O-O
# sacrifice  | O-O
# .          | O-O
#
#           | O-O
# So         | O-O
# let        | O-O
# us         | O-O
# summon     | O-O
# a          | O-O
# new        | O-O
# spirit     | O-O
# of         | O-O
# patriotism | O-O
# ,          | O-O
# of         | O-O
# responsibility| O-O
# ,          | O-O
# where      | O-O
# each       | O-O
# of         | O-O
# us         | O-O
# resolves   | O-O
# to         | O-O
# pitch      | O-O
# in         | O-O
# and        | O-O
# work       | O-O
# harder     | O-O
# and        | O-O
# look       | O-O
# after      | O-O
# not        | O-O
# only       | O-O
# ourselves  | O-O
# but        | O-O
# each       | O-O
# other      | O-O
# .          | O-O
#
#           | O-O
# Let        | O-O
# us         | O-O
# remember   | O-O
# that       | O-O
# ,          | O-O
# if         | O-O
# this       | O-O
# financial  | O-O
# crisis     | O-O
# taught     | O-O
# us         | O-O
# anything   | O-O
# ,          | O-O
# it         | O-O
# ’s         | O-O
# that       | O-O
# we         | O-O
# can        | O-O
# not        | O-O
# have       | O-O
# a          | O-O
# thriving   | O-O
# Wall       | O-O
# Street     | O-O
# while      | O-O
# Main       | B-FAC
# Street     | I-FAC
# suffers    | O-O
# .          | O-O
#
#           | O-O
# In         | O-O
# this       | O-O
# country    | O-O
# ,          | O-O
# we         | O-O
# rise       | O-O
# or         | O-O
# fall       | O-O
# as         | O-O
# one        | B-CARDINAL
# nation     | O-O
# ,          | O-O
# as         | O-O
# one        | B-CARDINAL
# people     | O-O
# .          | O-O
# Let        | O-O
# ’s         | O-O
# resist     | O-O
# the        | O-O
# temptation | O-O
# to         | O-O
# fall       | O-O
# back       | O-O
# on         | O-O
# the        | O-O
# same       | O-O
# partisanship| O-O
# and        | O-O
# pettiness  | O-O
# and        | O-O
# immaturity | O-O
# that       | O-O
# has        | O-O
# poisoned   | O-O
# our        | O-O
# politics   | O-O
# for        | O-O
# so         | O-O
# long       | O-O
# .          | O-O
#
#           | O-O
# Let        | O-O
# ’s         | O-O
# remember   | O-O
# that       | O-O
# it         | O-O
# was        | O-O
# a          | O-O
# man        | O-O
# from       | O-O
# this       | O-O
# state      | O-O
# who        | O-O
# first      | B-ORDINAL
# carried    | O-O
# the        | O-O
# banner     | O-O
# of         | O-O
# the        | B-ORG
# Republican | I-ORG
# Party      | I-ORG
# to         | O-O
# the        | B-ORG
# White      | I-ORG
# House      | I-ORG
# ,          | O-O
# a          | O-O
# party      | O-O
# founded    | O-O
# on         | O-O
# the        | O-O
# values     | O-O
# of         | O-O
# self       | O-O
# -          | O-O
# reliance   | O-O
# and        | O-O
# individual | O-O
# liberty    | O-O
# and        | O-O
# national   | O-O
# unity      | O-O
# .          | O-O
#
#           | O-O
# Those      | O-O
# are        | O-O
# values     | O-O
# that       | O-O
# we         | O-O
# all        | O-O
# share      | O-O
# .          | O-O
# And        | O-O
# while      | O-O
# the        | B-ORG
# Democratic | I-ORG
# Party      | I-ORG
# has        | O-O
# won        | O-O
# a          | O-O
# great      | O-O
# victory    | O-O
# tonight    | B-TIME
# ,          | O-O
# we         | O-O
# do         | O-O
# so         | O-O
# with       | O-O
# a          | O-O
# measure    | O-O
# of         | O-O
# humility   | O-O
# and        | O-O
# determination| O-O
# to         | O-O
# heal       | O-O
# the        | O-O
# divides    | O-O
# that       | O-O
# have       | O-O
# held       | O-O
# back       | O-O
# our        | O-O
# progress   | O-O
# .          | O-O
#
#           | O-O
# As         | O-O
# Lincoln    | B-ORG
# said       | O-O
# to         | O-O
# a          | O-O
# nation     | O-O
# far        | O-O
# more       | O-O
# divided    | O-O
# than       | O-O
# ours       | O-O
# ,          | O-O
# we         | O-O
# are        | O-O
# not        | O-O
# enemies    | O-O
# but        | O-O
# friends    | O-O
# .          | O-O
# Though     | O-O
# passion    | O-O
# may        | O-O
# have       | O-O
# strained   | O-O
# ,          | O-O
# it         | O-O
# must       | O-O
# not        | O-O
# break      | O-O
# our        | O-O
# bonds      | O-O
# of         | O-O
# affection  | O-O
# .          | O-O
#
#           | O-O
# And        | O-O
# to         | O-O
# those      | O-O
# Americans  | B-NORP
# whose      | O-O
# support    | O-O
# I          | O-O
# have       | O-O
# yet        | O-O
# to         | O-O
# earn       | O-O
# ,          | O-O
# I          | O-O
# may        | O-O
# not        | O-O
# have       | O-O
# won        | O-O
# your       | O-O
# vote       | O-O
# tonight    | B-TIME
# ,          | O-O
# but        | O-O
# I          | O-O
# hear       | O-O
# your       | O-O
# voices     | O-O
# .          | O-O
# I          | O-O
# need       | O-O
# your       | O-O
# help       | O-O
# .          | O-O
# And        | O-O
# I          | O-O
# will       | O-O
# be         | O-O
# your       | O-O
# president  | O-O
# ,          | O-O
# too        | O-O
# .          | O-O
#
#           | O-O
# And        | O-O
# to         | O-O
# all        | O-O
# those      | O-O
# watching   | O-O
# tonight    | B-TIME
# from       | O-O
# beyond     | O-O
# our        | O-O
# shores     | O-O
# ,          | O-O
# from       | O-O
# parliaments| O-O
# and        | O-O
# palaces    | O-O
# ,          | O-O
# to         | O-O
# those      | O-O
# who        | O-O
# are        | O-O
# huddled    | O-O
# around     | O-O
# radios     | O-O
# in         | O-O
# the        | O-O
# forgotten  | O-O
# corners    | O-O
# of         | O-O
# the        | O-O
# world      | O-O
# ,          | O-O
# our        | O-O
# stories    | O-O
# are        | O-O
# singular   | O-O
# ,          | O-O
# but        | O-O
# our        | O-O
# destiny    | O-O
# is         | O-O
# shared     | O-O
# ,          | O-O
# and        | O-O
# a          | O-O
# new        | O-O
# dawn       | O-O
# of         | O-O
# American   | B-NORP
# leadership | O-O
# is         | O-O
# at         | O-O
# hand       | O-O
# .          | O-O
#
#           | O-O
# To         | O-O
# those      | O-O
# —          | O-O
# to         | O-O
# those      | O-O
# who        | O-O
# would      | O-O
# tear       | O-O
# the        | O-O
# world      | O-O
# down       | O-O
# :          | O-O
# We         | O-O
# will       | O-O
# defeat     | O-O
# you        | O-O
# .          | O-O
# To         | O-O
# those      | O-O
# who        | O-O
# seek       | O-O
# peace      | O-O
# and        | O-O
# security   | O-O
# :          | O-O
# We         | O-O
# support    | O-O
# you        | O-O
# .          | O-O
# And        | O-O
# to         | O-O
# all        | O-O
# those      | O-O
# who        | O-O
# have       | O-O
# wondered   | O-O
# if         | O-O
# America    | B-GPE
# ’s         | O-O
# beacon     | O-O
# still      | O-O
# burns      | O-O
# as         | O-O
# bright     | O-O
# :          | O-O
# Tonight    | B-TIME
# we         | O-O
# proved     | O-O
# once       | O-O
# more       | O-O
# that       | O-O
# the        | O-O
# true       | O-O
# strength   | O-O
# of         | O-O
# our        | O-O
# nation     | O-O
# comes      | O-O
# not        | O-O
# from       | O-O
# the        | O-O
# might      | O-O
# of         | O-O
# our        | O-O
# arms       | O-O
# or         | O-O
# the        | O-O
# scale      | O-O
# of         | O-O
# our        | O-O
# wealth     | O-O
# ,          | O-O
# but        | O-O
# from       | O-O
# the        | O-O
# enduring   | O-O
# power      | O-O
# of         | O-O
# our        | O-O
# ideals     | O-O
# :          | O-O
# democracy  | O-O
# ,          | O-O
# liberty    | O-O
# ,          | O-O
# opportunity| O-O
# and        | O-O
# unyielding | O-O
# hope       | O-O
# .          | O-O
#
#           | O-O
# That       | O-O
# ’s         | O-O
# the        | O-O
# true       | O-O
# genius     | O-O
# of         | O-O
# America    | B-GPE
# :          | O-O
# that       | O-O
# America    | B-GPE
# can        | O-O
# change     | O-O
# .          | O-O
# Our        | O-O
# union      | O-O
# can        | O-O
# be         | O-O
# perfected  | O-O
# .          | O-O
# What       | O-O
# we         | O-O
# ’ve        | O-O
# already    | O-O
# achieved   | O-O
# gives      | O-O
# us         | O-O
# hope       | O-O
# for        | O-O
# what       | O-O
# we         | O-O
# can        | O-O
# and        | O-O
# must       | O-O
# achieve    | O-O
# tomorrow   | B-DATE
# .          | O-O
#
#           | O-O
# This       | O-O
# election   | O-O
# had        | O-O
# many       | O-O
# firsts     | O-O
# and        | O-O
# many       | O-O
# stories    | O-O
# that       | O-O
# will       | O-O
# be         | O-O
# told       | O-O
# for        | O-O
# generations| O-O
# .          | O-O
# But        | O-O
# one        | O-O
# that       | O-O
# ’s         | O-O
# on         | O-O
# my         | O-O
# mind       | O-O
# tonight    | B-TIME
# ’s         | O-O
# about      | O-O
# a          | O-O
# woman      | O-O
# who        | O-O
# cast       | O-O
# her        | O-O
# ballot     | O-O
# in         | O-O
# Atlanta    | B-GPE
# .          | O-O
# She        | O-O
# ’s         | O-O
# a          | O-O
# lot        | O-O
# like       | O-O
# the        | O-O
# millions   | B-CARDINAL
# of         | O-O
# others     | O-O
# who        | O-O
# stood      | O-O
# in         | O-O
# line       | O-O
# to         | O-O
# make       | O-O
# their      | O-O
# voice      | O-O
# heard      | O-O
# in         | O-O
# this       | O-O
# election   | O-O
# except     | O-O
# for        | O-O
# one        | B-CARDINAL
# thing      | O-O
# :          | O-O
# Ann        | B-PERSON
# Nixon      | I-PERSON
# Cooper     | I-PERSON
# is         | O-O
# 106        | B-DATE
# years      | I-DATE
# old        | I-DATE
# .          | O-O
#
#           | O-O
# She        | O-O
# was        | O-O
# born       | O-O
# just       | O-O
# a          | O-O
# generation | O-O
# past       | O-O
# slavery    | O-O
# ;          | O-O
# a          | O-O
# time       | O-O
# when       | O-O
# there      | O-O
# were       | O-O
# no         | O-O
# cars       | O-O
# on         | O-O
# the        | O-O
# road       | O-O
# or         | O-O
# planes     | O-O
# in         | O-O
# the        | O-O
# sky        | O-O
# ;          | O-O
# when       | O-O
# someone    | O-O
# like       | O-O
# her        | O-O
# could      | O-O
# n’t        | O-O
# vote       | O-O
# for        | O-O
# two        | B-CARDINAL
# reasons    | O-O
# —          | O-O
# because    | O-O
# she        | O-O
# was        | O-O
# a          | O-O
# woman      | O-O
# and        | O-O
# because    | O-O
# of         | O-O
# the        | O-O
# color      | O-O
# of         | O-O
# her        | O-O
# skin       | O-O
# .          | O-O
#
#           | O-O
# And        | O-O
# tonight    | B-TIME
# ,          | O-O
# I          | O-O
# think      | O-O
# about      | O-O
# all        | O-O
# that       | O-O
# she        | O-O
# ’s         | O-O
# seen       | O-O
# throughout | O-O
# her        | O-O
# century    | O-O
# in         | O-O
# America    | B-GPE
# —          | O-O
# the        | O-O
# heartache  | O-O
# and        | O-O
# the        | O-O
# hope       | O-O
# ;          | O-O
# the        | O-O
# struggle   | O-O
# and        | O-O
# the        | O-O
# progress   | O-O
# ;          | O-O
# the        | O-O
# times      | O-O
# we         | O-O
# were       | O-O
# told       | O-O
# that       | O-O
# we         | O-O
# ca         | O-O
# n’t        | O-O
# ,          | O-O
# and        | O-O
# the        | O-O
# people     | O-O
# who        | O-O
# pressed    | O-O
# on         | O-O
# with       | O-O
# that       | O-O
# American   | B-NORP
# creed      | O-O
# :          | O-O
# Yes        | O-O
# we         | O-O
# can        | O-O
# .          | O-O
#
#           | O-O
# At         | O-O
# a          | O-O
# time       | O-O
# when       | O-O
# women      | O-O
# ’s         | O-O
# voices     | O-O
# were       | O-O
# silenced   | O-O
# and        | O-O
# their      | O-O
# hopes      | O-O
# dismissed  | O-O
# ,          | O-O
# she        | O-O
# lived      | O-O
# to         | O-O
# see        | O-O
# them       | O-O
# stand      | O-O
# up         | O-O
# and        | O-O
# speak      | O-O
# out        | O-O
# and        | O-O
# reach      | O-O
# for        | O-O
# the        | O-O
# ballot     | O-O
# .          | O-O
# Yes        | O-O
# we         | O-O
# can        | O-O
# .          | O-O
#
#           | O-O
# When       | O-O
# there      | O-O
# was        | O-O
# despair    | O-O
# in         | O-O
# the        | O-O
# dust       | O-O
# bowl       | O-O
# and        | O-O
# depression | O-O
# across     | O-O
# the        | O-O
# land       | O-O
# ,          | O-O
# she        | O-O
# saw        | O-O
# a          | O-O
# nation     | O-O
# conquer    | O-O
# fear       | O-O
# itself     | O-O
# with       | O-O
# a          | O-O
# New        | O-O
# Deal       | O-O
# ,          | O-O
# new        | O-O
# jobs       | O-O
# ,          | O-O
# a          | O-O
# new        | O-O
# sense      | O-O
# of         | O-O
# common     | O-O
# purpose    | O-O
# .          | O-O
# Yes        | O-O
# we         | O-O
# can        | O-O
# .          | O-O
#
#           | O-O
# When       | O-O
# the        | O-O
# bombs      | O-O
# fell       | O-O
# on         | O-O
# our        | O-O
# harbor     | O-O
# and        | O-O
# tyranny    | O-O
# threatened | O-O
# the        | O-O
# world      | O-O
# ,          | O-O
# she        | O-O
# was        | O-O
# there      | O-O
# to         | O-O
# witness    | O-O
# a          | O-O
# generation | O-O
# rise       | O-O
# to         | O-O
# greatness  | O-O
# and        | O-O
# a          | O-O
# democracy  | O-O
# was        | O-O
# saved      | O-O
# .          | O-O
# Yes        | O-O
# we         | O-O
# can        | O-O
# .          | O-O
#
#           | O-O
# She        | O-O
# was        | O-O
# there      | O-O
# for        | O-O
# the        | O-O
# buses      | O-O
# in         | O-O
# Montgomery | B-ORG
# ,          | O-O
# the        | O-O
# hoses      | O-O
# in         | O-O
# Birmingham | B-GPE
# ,          | O-O
# a          | O-O
# bridge     | O-O
# in         | O-O
# Selma      | B-GPE
# ,          | O-O
# and        | O-O
# a          | O-O
# preacher   | O-O
# from       | O-O
# Atlanta    | B-GPE
# who        | O-O
# told       | O-O
# a          | O-O
# people     | O-O
# that       | O-O
# “          | O-O
# We         | O-O
# Shall      | O-O
# Overcome   | O-O
# .          | O-O
# ”          | O-O
# Yes        | O-O
# we         | O-O
# can        | O-O
# .          | O-O
#
#           | O-O
# A          | O-O
# man        | O-O
# touched    | O-O
# down       | O-O
# on         | O-O
# the        | B-LOC
# moon       | I-LOC
# ,          | O-O
# a          | O-O
# wall       | O-O
# came       | O-O
# down       | O-O
# in         | O-O
# Berlin     | B-GPE
# ,          | O-O
# a          | O-O
# world      | O-O
# was        | O-O
# connected  | O-O
# by         | O-O
# our        | O-O
# own        | O-O
# science    | O-O
# and        | O-O
# imagination| O-O
# .          | O-O
#
#           | O-O
# And        | O-O
# this       | B-DATE
# year       | I-DATE
# ,          | O-O
# in         | O-O
# this       | O-O
# election   | O-O
# ,          | O-O
# she        | O-O
# touched    | O-O
# her        | O-O
# finger     | O-O
# to         | O-O
# a          | O-O
# screen     | O-O
# ,          | O-O
# and        | O-O
# cast       | O-O
# her        | O-O
# vote       | O-O
# ,          | O-O
# because    | O-O
# after      | O-O
# 106        | B-DATE
# years      | I-DATE
# in         | O-O
# America    | B-GPE
# ,          | O-O
# through    | O-O
# the        | O-O
# best       | O-O
# of         | O-O
# times      | O-O
# and        | O-O
# the        | O-O
# darkest    | O-O
# of         | O-O
# hours      | B-TIME
# ,          | O-O
# she        | O-O
# knows      | O-O
# how        | O-O
# America    | B-GPE
# can        | O-O
# change     | O-O
# .          | O-O
#
#           | O-O
# Yes        | O-O
# we         | O-O
# can        | O-O
# .          | O-O
#
#           | O-O
# America    | B-GPE
# ,          | O-O
# we         | O-O
# have       | O-O
# come       | O-O
# so         | O-O
# far        | O-O
# .          | O-O
# We         | O-O
# have       | O-O
# seen       | O-O
# so         | O-O
# much       | O-O
# .          | O-O
# But        | O-O
# there      | O-O
# is         | O-O
# so         | O-O
# much       | O-O
# more       | O-O
# to         | O-O
# do         | O-O
# .          | O-O
# So         | O-O
# tonight    | B-TIME
# ,          | O-O
# let        | O-O
# us         | O-O
# ask        | O-O
# ourselves  | O-O
# —          | O-O
# if         | O-O
# our        | O-O
# children   | O-O
# should     | O-O
# live       | O-O
# to         | O-O
# see        | O-O
# the        | B-DATE
# next       | I-DATE
# century    | I-DATE
# ;          | O-O
# if         | O-O
# my         | O-O
# daughters  | O-O
# should     | O-O
# be         | O-O
# so         | O-O
# lucky      | O-O
# to         | O-O
# live       | O-O
# as         | O-O
# long       | O-O
# as         | O-O
# Ann        | B-PERSON
# Nixon      | I-PERSON
# Cooper     | I-PERSON
# ,          | O-O
# what       | O-O
# change     | O-O
# will       | O-O
# they       | O-O
# see        | O-O
# ?          | O-O
# What       | O-O
# progress   | O-O
# will       | O-O
# we         | O-O
# have       | O-O
# made       | O-O
# ?          | O-O
#
#           | O-O
# This       | O-O
# is         | O-O
# our        | O-O
# chance     | O-O
# to         | O-O
# answer     | O-O
# that       | O-O
# call       | O-O
# .          | O-O
# This       | O-O
# is         | O-O
# our        | O-O
# moment     | O-O
# .          | O-O
#
#           | O-O
# This       | O-O
# is         | O-O
# our        | O-O
# time       | O-O
# ,          | O-O
# to         | O-O
# put        | O-O
# our        | O-O
# people     | O-O
# back       | O-O
# to         | O-O
# work       | O-O
# and        | O-O
# open       | O-O
# doors      | O-O
# of         | O-O
# opportunity| O-O
# for        | O-O
# our        | O-O
# kids       | O-O
# ;          | O-O
# to         | O-O
# restore    | O-O
# prosperity | O-O
# and        | O-O
# promote    | O-O
# the        | O-O
# cause      | O-O
# of         | O-O
# peace      | O-O
# ;          | O-O
# to         | O-O
# reclaim    | O-O
# the        | O-O
# American   | B-NORP
# dream      | O-O
# and        | O-O
# reaffirm   | O-O
# that       | O-O
# fundamental| O-O
# truth      | O-O
# ,          | O-O
# that       | O-O
# ,          | O-O
# out        | O-O
# of         | O-O
# many       | O-O
# ,          | O-O
# we         | O-O
# are        | O-O
# one        | O-O
# ;          | O-O
# that       | O-O
# while      | O-O
# we         | O-O
# breathe    | O-O
# ,          | O-O
# we         | O-O
# hope       | O-O
# .          | O-O
# And        | O-O
# where      | O-O
# we         | O-O
# are        | O-O
# met        | O-O
# with       | O-O
# cynicism   | O-O
# and        | O-O
# doubts     | O-O
# and        | O-O
# those      | O-O
# who        | O-O
# tell       | O-O
# us         | O-O
# that       | O-O
# we         | O-O
# ca         | O-O
# n’t        | O-O
# ,          | O-O
# we         | O-O
# will       | O-O
# respond    | O-O
# with       | O-O
# that       | O-O
# timeless   | O-O
# creed      | O-O
# that       | O-O
# sums       | O-O
# up         | O-O
# the        | O-O
# spirit     | O-O
# of         | O-O
# a          | O-O
# people     | O-O
# :          | O-O
# Yes        | O-O
# ,          | O-O
# we         | O-O
# can        | O-O
# .          | O-O
# [          | O-O

# %% [markdown]
# <b>Incluye aquí, debajo de la línea, la explicación de tu respuesta</b>
# <hr>

# %% [markdown]
# Lo que entiendo por esquema IOB es que es un sistema estandard de etiquetado para el reconocimento de entidades que se asignan a cada token. Según la [documentacion](https://en.wikipedia.org/wiki/Inside%E2%80%93outside%E2%80%93beginning_(tagging)):
#
# * B (Beginning): Indica el inicio de una entidad nombrada.
# * I (Inside): Indica que un token está dentro de una entidad nombrada que ya ha comenzado.
# * O (Outside): Indica que un token no forma parte de una entidad nombrada.

# %% [markdown]
# <span style="font-size: 14pt; font-weight: bold; color: #0098cd;">Pregunta 10.</span>
# <span style="font-size: 14pt; font-weight: bold; color: #0098cd;">¿Qué POS Tags aparecen en el texto, y cuántos hay tokens hay de cada uno?</span>

# %%
# Diccionario para almacenar el recuento de cada POS tag
pos_counts = {}

# Itera sobre los tokens y cuenta cuántos hay de cada POS tag
for token in doc:
    pos = token.pos_
    pos_counts[pos] = pos_counts.get(pos, 0) + 1

# Imprime el recuento de cada POS tag
print("Partes del discurso (POS tags) y su recuento:")
for pos, count in pos_counts.items():
    print(f"{pos}: {count}")
# Out:
# Partes del discurso (POS tags) y su recuento:
# PUNCT: 205
# PROPN: 56
# SPACE: 46
# SCONJ: 51
# PRON: 243
# VERB: 211
# ADV: 63
# AUX: 125
# DET: 153
# NOUN: 330
# ADJ: 93
# ADP: 189
# CCONJ: 92
# NUM: 18
# PART: 53
# SYM: 3
# INTJ: 7
# X: 1

# %% [markdown]
# <b>Incluye aquí, debajo de la línea, la explicación de tu respuesta</b>
# <hr>

# %% [markdown]
# Las etiquetas gramaticales que podemos observar en el texto son el output del código. Para ello creo un diccionario para hacer lo mismo que en la pregunta 8. Se itera sobre los tokens y obtenemos la cantidad de POS tags que hay por cada uno.
